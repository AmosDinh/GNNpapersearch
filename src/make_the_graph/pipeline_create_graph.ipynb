# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Read

# %%
import pandas as pd
import re
import spacy

import torch
from torch_geometric.data import HeteroData

import networkx as nx
import matplotlib.pyplot as plt
from torch_geometric.utils import to_networkx

# %%
filename = 'data/arxiv-metadata-oai-snapshot-10000.csv'
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#          id           submitter  \
# 0  704.0001      Pavel Nadolsky
# 1  704.0002        Louis Theran
# 2  704.0003         Hongjun Pan
# 3  704.0004        David Callan
# 4  704.0005  Alberto Torchinsky
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
# 3                                       David Callan
# 4           Wael Abu-Shammala and Alberto Torchinsky
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# 1    To appear in Graphs and Combinatorics
# 2                      23 pages, 3 figures
# 3                                 11 pages
# 4                                      NaN
#
#                                  journal-ref                         doi  \
# 0                   Phys.Rev.D76:013009,2007  10.1103/PhysRevD.76.013009
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4  Illinois J. Math. 52 (2008) no.2, 681-689                         NaN
#
#           report-no       categories  \
# 0  ANL-HEP-PR-07-12           hep-ph
# 1               NaN    math.CO cs.CG
# 2               NaN   physics.gen-ph
# 3               NaN          math.CO
# 4               NaN  math.CA math.FA
#
#                                              license  \
# 0                                                NaN
# 1  http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             abstract  \
# 0    A fully differential calculation in perturba...
# 1    We describe a new algorithm, the $(k,\ell)$-...
# 2    The evolution of Earth-Moon system is descri...
# 3    We show that a determinant of Stirling cycle...
# 4    In this paper we show how to compute the $\L...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
#
#                                       authors_parsed
# 0  [['Balázs', 'C.', ''], ['Berger', 'E. L.', '']...
# 1  [['Streinu', 'Ileana', ''], ['Theran', 'Louis'...
# 2                           [['Pan', 'Hongjun', '']]
# 3                          [['Callan', 'David', '']]
# 4  [['Abu-Shammala', 'Wael', ''], ['Torchinsky', ...

# %% [markdown]
# ### Transform columns

# %%
# extract number of pages from string: e.g. "37 pages, 15 figures; published version"

def extract_pages(s):
    match = re.search(r"(\d+)\s*pages", s)
    if match:
        return int(match.group(1))
    else:
        return None

# %%
# format columns to right format and extract information
# Quelle warum genau die neuen Spalten fürPaper suchen

df['authors_parsed'] = df['authors_parsed'].apply(lambda x: [" ".join(i).strip() for i in eval(x)]) # authors to name, first name and list
df['versions'] = df['versions'].apply(lambda x: eval(x)[0]["created"]) # first version / created
df['timestamp'] = pd.to_datetime(df['versions'], format="%a, %d %b %Y %H:%M:%S %Z") # 
df['timestamp'] = df['timestamp'].apply(lambda x: x.timestamp())
df["categories"] = df["categories"].apply(lambda x: x.split(" ")) # sdeperate categories by comma
df.drop(columns=["submitter", "versions", "update_date", "authors"], inplace=True)
df["pages"] = df.comments.apply(lambda x: extract_pages(str(x))) # extract page number
df.head()
# Out:
#          id                                              title  \
# 0  704.0001  Calculation of prompt diphoton production cros...
# 1  704.0002           Sparsity-certifying Graph Decompositions
# 2  704.0003  The evolution of the Earth-Moon system based o...
# 3  704.0004  A determinant of Stirling cycle numbers counts...
# 4  704.0005  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# 1    To appear in Graphs and Combinatorics
# 2                      23 pages, 3 figures
# 3                                 11 pages
# 4                                      NaN
#
#                                  journal-ref                         doi  \
# 0                   Phys.Rev.D76:013009,2007  10.1103/PhysRevD.76.013009
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4  Illinois J. Math. 52 (2008) no.2, 681-689                         NaN
#
#           report-no          categories  \
# 0  ANL-HEP-PR-07-12            [hep-ph]
# 1               NaN    [math.CO, cs.CG]
# 2               NaN    [physics.gen-ph]
# 3               NaN           [math.CO]
# 4               NaN  [math.CA, math.FA]
#
#                                              license  \
# 0                                                NaN
# 1  http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             abstract  \
# 0    A fully differential calculation in perturba...
# 1    We describe a new algorithm, the $(k,\ell)$-...
# 2    The evolution of Earth-Moon system is descri...
# 3    We show that a determinant of Stirling cycle...
# 4    In this paper we show how to compute the $\L...
#
#                                       authors_parsed     timestamp  pages
# 0  [Balázs C., Berger E. L., Nadolsky P. M., Yuan...  1.175542e+09   37.0
# 1                     [Streinu Ileana, Theran Louis]  1.175308e+09    NaN
# 2                                      [Pan Hongjun]  1.175460e+09   23.0
# 3                                     [Callan David]  1.175311e+09   11.0
# 4            [Abu-Shammala Wael, Torchinsky Alberto]  1.175537e+09    NaN

# %% [markdown]
# ### Define size of dataset

# %%
df_short = df[:40]

# %% [markdown]
# ### Lemmatization

# %%
nlp = spacy.load("en_core_web_sm")

def lemm(text):
    doc = nlp(text)
    return [token.lemma_ for token in doc if not token.is_punct and not token.is_space]

# %%
# create lists that contain lemmatized words from abstracts, titles, and lists of authors and categories for each entry in the DataFrame


all_words, all_authors, all_categories, all_title_words = [], [], [], []

for index, row in df_short.iterrows():
    text = row['abstract']
    title = row['title']
    author = row['authors_parsed']
    category = row['categories'] 
    # tokenized_words = tokenize_and_normalize(text)
    lemm_words = lemm(text)
    lemm_title_words = lemm(title)
    # tokenized_words_list.append(tokenized_words)
    all_words.append(lemm_words)
    all_authors.append(author)
    all_categories.append(category)
    all_title_words.append(lemm_title_words)



print(all_words)
print(all_authors)
print(all_categories)
print(all_title_words)
# Out:
# [['a', 'fully', 'differential', 'calculation', 'in', 'perturbative', 'quantum', 'chromodynamic', 'be', 'present', 'for', 'the', 'production', 'of', 'massive', 'photon', 'pair', 'at', 'hadron', 'collider', 'all', 'next', 'to', 'lead', 'order', 'perturbative', 'contribution', 'from', 'quark', 'antiquark', 'gluon-(anti)quark', 'and', 'gluon', 'gluon', 'subprocesse', 'be', 'include', 'as', 'well', 'as', 'all', 'order', 'resummation', 'of', 'initial', 'state', 'gluon', 'radiation', 'valid', 'at', 'next', 'to', 'next', 'to', 'lead', 'logarithmic', 'accuracy', 'the', 'region', 'of', 'phase', 'space', 'be', 'specify', 'in', 'which', 'the', 'calculation', 'be', 'most', 'reliable', 'good', 'agreement', 'be', 'demonstrate', 'with', 'datum', 'from', 'the', 'Fermilab', 'Tevatron', 'and', 'prediction', 'be', 'make', 'for', 'more', 'detailed', 'test', 'with', 'CDF', 'and', 'do', 'datum', 'prediction', 'be', 'show', 'for', 'distribution', 'of', 'diphoton', 'pair', 'produce', 'at', 'the', 'energy', 'of', 'the', 'Large', 'Hadron', 'Collider', 'LHC', 'distribution', 'of', 'the', 'diphoton', 'pair', 'from', 'the', 'decay', 'of', 'a', 'Higgs', 'boson', 'be', 'contrast', 'with', 'those', 'produce', 'from', 'QCD', 'process', 'at', 'the', 'LHC', 'show', 'that', 'enhance', 'sensitivity', 'to', 'the', 'signal', 'can', 'be', 'obtain', 'with', 'judicious', 'selection', 'of', 'event'], ['we', 'describe', 'a', 'new', 'algorithm', 'the', '$', 'k,\\ell)$-pebble', 'game', 'with', 'color', 'and', 'use', 'it', 'obtain', 'a', 'characterization', 'of', 'the', 'family', 'of', '$', 'k,\\ell)$-sparse', 'graph', 'and', 'algorithmic', 'solution', 'to', 'a', 'family', 'of', 'problem', 'concern', 'tree', 'decomposition', 'of', 'graph', 'special', 'instance', 'of', 'sparse', 'graph', 'appear', 'in', 'rigidity', 'theory', 'and', 'have', 'receive', 'increase', 'attention', 'in', 'recent', 'year', 'in', 'particular', 'our', 'colored', 'pebble', 'generalize', 'and', 'strengthen', 'the', 'previous', 'result', 'of', 'Lee', 'and', 'Streinu', 'and', 'give', 'a', 'new', 'proof', 'of', 'the', 'Tutte', 'Nash', 'Williams', 'characterization', 'of', 'arboricity', 'we', 'also', 'present', 'a', 'new', 'decomposition', 'that', 'certify', 'sparsity', 'base', 'on', 'the', '$', 'k,\\ell)$-pebble', 'game', 'with', 'color', 'our', 'work', 'also', 'expose', 'connection', 'between', 'pebble', 'game', 'algorithm', 'and', 'previous', 'sparse', 'graph', 'algorithm', 'by', 'Gabow', 'Gabow', 'and', 'Westermann', 'and', 'Hendrickson'], ['the', 'evolution', 'of', 'Earth', 'Moon', 'system', 'be', 'describe', 'by', 'the', 'dark', 'matter', 'field', 'fluid', 'model', 'propose', 'in', 'the', 'Meeting', 'of', 'Division', 'of', 'Particle', 'and', 'Field', '2004', 'American', 'Physical', 'Society', 'the', 'current', 'behavior', 'of', 'the', 'Earth', 'Moon', 'system', 'agree', 'with', 'this', 'model', 'very', 'well', 'and', 'the', 'general', 'pattern', 'of', 'the', 'evolution', 'of', 'the', 'Moon', 'Earth', 'system', 'describe', 'by', 'this', 'model', 'agree', 'with', 'geological', 'and', 'fossil', 'evidence', 'the', 'close', 'distance', 'of', 'the', 'Moon', 'to', 'Earth', 'be', 'about', '259000', 'km', 'at', '4.5', 'billion', 'year', 'ago', 'which', 'be', 'far', 'beyond', 'the', 'Roche', "'s", 'limit', 'the', 'result', 'suggest', 'that', 'the', 'tidal', 'friction', 'may', 'not', 'be', 'the', 'primary', 'cause', 'for', 'the', 'evolution', 'of', 'the', 'Earth', 'Moon', 'system', 'the', 'average', 'dark', 'matter', 'field', 'fluid', 'constant', 'derive', 'from', 'Earth', 'Moon', 'system', 'datum', 'be', '4.39', 'x', '10^(-22', 's^(-1)m^(-1', 'this', 'model', 'predict', 'that', 'the', 'Mars', "'s", 'rotation', 'be', 'also', 'slow', 'with', 'the', 'angular', 'acceleration', 'rate', 'about', '-4.38', 'x', '10^(-22', 'rad', 's^(-2'], ['we', 'show', 'that', 'a', 'determinant', 'of', 'Stirling', 'cycle', 'number', 'count', 'unlabeled', 'acyclic', 'single', 'source', 'automata', 'the', 'proof', 'involve', 'a', 'bijec ...
# [['Balázs C.', 'Berger E. L.', 'Nadolsky P. M.', 'Yuan C. -P.'], ['Streinu Ileana', 'Theran Louis'], ['Pan Hongjun'], ['Callan David'], ['Abu-Shammala Wael', 'Torchinsky Alberto'], ['Pong Y. H.', 'Law C. K.'], ['Corichi Alejandro', 'Vukasinac Tatjana', 'Zapata Jose A.'], ['Swift Damian C.'], ['Harvey Paul', 'Merin Bruno', 'Huard Tracy L.', 'Rebull Luisa M.', 'Chapman Nicholas', 'Evans Neal J. II', 'Myers Philip C.'], ['Ovchinnikov Sergei'], ['Cunningham Clifton', 'Dembele Lassina'], ['Choi Dohoon'], ['Choi Dohoon', 'Choie YoungJu'], ['Fujii Koichi'], ['Stahn Christian'], ['Chang Chao-Hsi', 'Li Tong', 'Li Xue-Qian', 'Wang Yu-Ming'], ['Mhlahlo Nceba', 'Buckley David H.', 'Dhillon Vikram S.', 'Potter Steven B.', 'Warner Brian', 'Woudt Patric A.'], ['Gustavsson Andreas'], ['Konno Norio'], ['The BABAR Collaboration', 'Aubert B.'], ['Casagrande Vanessa', 'Togashi Yuichi', 'Mikhailov Alexander S.'], ['Malham Simon J. A.', 'Wiese Anke'], ['Loukitcheva M. A.', 'Solanki S. K.', 'White S.'], ['Serga A. A.', 'Kostylev M.', 'Hillebrands B.'], ['Mishchenko A. S.  1 and 2', 'Nagaosa N.  1 and 3'], ['de Marrais Robert P. C.'], ['Goerbig M. O.', 'Fuchs J. -N.', 'Kechedzhi K.', "Fal'ko Vladimir I."], ['Frenkel Péter E.'], ['Shu Zhan', 'Chen Xiao-Lin', 'Deng Wei-Zhen'], ['Hague J. P.', "d'Ambrumenil N."], ['Biryukov V. M.  Serpukhov, IHEP'], ['Esteban-Pretel A.', 'Tomàs R.', 'Valle J. W. F.'], ['Yurkin Maxim A.', 'Maltsev Valeri P.', 'Hoekstra Alfons G.'], ['Ogryzko Vasily'], ['Yurkin Maxim A.', 'Maltsev Valeri P.', 'Hoekstra Alfons G.'], ['Wang Liming', 'Sontag Eduardo D.'], ['Yurkin Maxim A.', 'Maltsev Valeri P.', 'Hoekstra Alfons G.'], ['Yurkin Maxim A.', 'Hoekstra Alfons G.'], ['Oller Jose A.', 'Roca Luis'], ['Popa Mihai']]
# [['hep-ph'], ['math.CO', 'cs.CG'], ['physics.gen-ph'], ['math.CO'], ['math.CA', 'math.FA'], ['cond-mat.mes-hall'], ['gr-qc'], ['cond-mat.mtrl-sci'], ['astro-ph'], ['math.CO'], ['math.NT', 'math.AG'], ['math.NT'], ['math.NT'], ['math.CA', 'math.AT'], ['hep-th'], ['hep-ph'], ['astro-ph'], ['hep-th'], ['math.PR', 'math.AG'], ['hep-ex'], ['nlin.PS', 'physics.chem-ph', 'q-bio.MN'], ['math.NA'], ['astro-ph'], ['nlin.PS'], ['cond-mat.str-el', 'cond-mat.stat-mech'], ['math.RA'], ['cond-mat.mes-hall'], ['math.CA', 'math.PR'], ['hep-ph'], ['cond-mat.str-el'], ['hep-ph'], ['hep-ph'], ['physics.optics', 'physics.comp-ph'], ['q-bio.PE', 'q-bio.CB', 'quant-ph'], ['physics.optics', 'physics.comp-ph'], ['q-bio.QM', 'q-bio.MN'], ['physics.optics', 'physics.comp-ph'], ['physics.optics', 'physics.comp-ph'], ['hep-ph', 'hep-lat', 'nucl-th'], ['math.OA', 'math.FA']]
# [['calculation', 'of', 'prompt', 'diphoton', 'production', 'cross', 'section', 'at', 'Tevatron', 'and', 'LHC', 'energy'], ['sparsity', 'certify', 'Graph', 'Decompositions'], ['the', 'evolution', 'of', 'the', 'Earth', 'Moon', 'system', 'base', 'on', 'the', 'dark', 'matter', 'field', 'fluid', 'model'], ['a', 'determinant', 'of', 'stirling', 'cycle', 'number', 'count', 'unlabeled', 'acyclic', 'single', 'source', 'automata'], ['from', 'dyadic', '$', '\\Lambda_{\\alpha}$', 'to', '$', '\\Lambda_{\\alpha}$'], ['bosonic', 'character', 'of', 'atomic', 'Cooper', 'pair', 'across', 'resonance'], ['polymer', 'Quantum', 'Mechanics', 'and', 'its', 'Continuum', 'Limit'], ['numerical', 'solution', 'of', 'shock', 'and', 'ramp', 'compression', 'for', 'general', 'material', 'property'], ['the', 'Spitzer', 'c2d', 'Survey', 'of', 'large', 'nearby', 'Insterstellar', 'Clouds', 'IX', 'the', 'Serpens', 'YSO', 'Population', 'as', 'Observed', 'with', 'irac', 'and', 'MIPS'], ['partial', 'cube', 'structure', 'characterization', 'and', 'construction'], ['computing', 'genu', '2', 'Hilbert', 'Siegel', 'modular', 'form', 'over', '$', '\\q(\\sqrt{5})$', 'via', 'the', 'Jacquet', 'Langlands', 'correspondence'], ['distribution', 'of', 'integral', 'Fourier', 'Coefficients', 'of', 'a', 'Modular', 'form', 'of', 'Half', 'Integral', 'Weight', 'Modulo', 'prime'], ['$', 'p$-adic', 'Limit', 'of', 'Weakly', 'Holomorphic', 'Modular', 'Forms', 'of', 'Half', 'Integral', 'weight'], ['iterate', 'integral', 'and', 'the', 'loop', 'product'], ['fermionic', 'superstre', 'loop', 'amplitude', 'in', 'the', 'pure', 'spinor', 'formalism'], ['lifetime', 'of', 'doubly', 'charm', 'baryon'], ['Spectroscopic', 'Observations', 'of', 'the', 'Intermediate', 'Polar', 'EX', 'Hydrae', 'in', 'Quiescence'], ['in', 'quest', 'of', 'a', 'generalized', 'Callias', 'index', 'theorem'], ['approximation', 'for', 'extinction', 'probability', 'of', 'the', 'contact', 'process', 'base', 'on', 'the', 'gr\\"obner', 'basis'], ['Measurement', 'of', 'the', 'Hadronic', 'Form', 'Factor', 'in', 'D0', '>', 'K-', 'e+', 'nue', 'decay'], ['molecular', 'Synchronization', 'Waves', 'in', 'Arrays', 'of', 'allosterically', 'regulate', 'enzyme'], ['stochastic', 'lie', 'group', 'integrator'], ['alma', 'as', 'the', 'ideal', 'probe', 'of', 'the', 'solar', 'chromosphere'], ['formation', 'of', 'quasi', 'soliton', 'in', 'transverse', 'confine', 'ferromagnetic', 'film', 'medium'], ['Spectroscopic', 'Properties', 'of', 'Polarons', 'in', 'strongly', 'Correlated', 'Systems', 'by', 'Exact', 'Diagrammatic', 'Monte', 'Carlo', 'Method'], ['Placeholder', 'Substructures', 'II', 'Meta', 'Fractals', 'make', 'of', 'Box', 'Kites', 'Fill', 'Infinite', 'Dimensional', 'Skies'], ['Filling', 'Factor', 'Dependent', 'Magnetophonon', 'Resonance', 'in', 'Graphene'], ['Pfaffians', 'hafnian', 'and', 'product', 'of', 'real', 'linear', 'functional'], ['understand', 'the', 'Flavor', 'Symmetry', 'Breaking', 'and', 'Nucleon', 'Flavor', 'Spin', 'Structure', 'within', 'Chiral', 'Quark', 'Model'], ['tune', 'correlation', 'effect', 'with', 'electron', 'phonon', 'interaction'], ['crystal', 'channeling', 'of', 'LHC', 'forward', 'proton', 'with', 'preserve', 'distribution', 'in', 'phase', 'space'], ['probe', 'non', 'standard', 'neutrino', 'interaction', 'with', 'supernova', 'neutrino'], ['convergence', 'of', 'the', 'discrete', 'dipole', 'approximation', 'I.', 'theoretical', 'analysis'], ['Origin', 'of', 'adaptive', 'mutant', 'a', 'quantum', 'measurement'], ['convergence', 'of', 'the', 'discrete', 'dipole', 'approximation', 'ii', 'an', 'extrapolation', 'technique', 'to', 'increase', 'the', 'accuracy'], ['a', 'remark', 'on', 'the', 'number', 'of', 'steady', 'state', 'in', 'a', 'multiple', 'futile', 'cycle'], ['the', 'discrete', 'dipole', 'approximation', 'for', 'simulation', 'of', 'light', 'scatter', 'by', 'particle', 'much', 'large', 'than', 'the', 'wavelength'], ['the', 'discrete', 'dipole', 'approximation', 'an', 'overview', 'and', 'recent', 'development'], ['scalar', ' ...

# %% [markdown]
# ### Delete Stopwords

# %%
# !pip3 install nltk

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# Laden der Stoppwörter
stop_words = set(stopwords.words('english'))

# Entfernen der Stoppwörter aus jedem Dokument
filtered_all_words = []
for words in all_words:
    filtered_words = [word for word in words if word not in stop_words]
    filtered_all_words.append(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\F22RatHen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filtered_all_words
# Out:
# [['fully',
#   'differential',
#   'calculation',
#   'perturbative',
#   'quantum',
#   'chromodynamic',
#   'present',
#   'production',
#   'massive',
#   'photon',
#   'pair',
#   'hadron',
#   'collider',
#   'next',
#   'lead',
#   'order',
#   'perturbative',
#   'contribution',
#   'quark',
#   'antiquark',
#   'gluon-(anti)quark',
#   'gluon',
#   'gluon',
#   'subprocesse',
#   'include',
#   'well',
#   'order',
#   'resummation',
#   'initial',
#   'state',
#   'gluon',
#   'radiation',
#   'valid',
#   'next',
#   'next',
#   'lead',
#   'logarithmic',
#   'accuracy',
#   'region',
#   'phase',
#   'space',
#   'specify',
#   'calculation',
#   'reliable',
#   'good',
#   'agreement',
#   'demonstrate',
#   'datum',
#   'Fermilab',
#   'Tevatron',
#   'prediction',
#   'make',
#   'detailed',
#   'test',
#   'CDF',
#   'datum',
#   'prediction',
#   'show',
#   'distribution',
#   'diphoton',
#   'pair',
#   'produce',
#   'energy',
#   'Large',
#   'Hadron',
#   'Collider',
#   'LHC',
#   'distribution',
#   'diphoton',
#   'pair',
#   'decay',
#   'Higgs',
#   'boson',
#   'contrast',
#   'produce',
#   'QCD',
#   'process',
#   'LHC',
#   'show',
#   'enhance',
#   'sensitivity',
#   'signal',
#   'obtain',
#   'judicious',
#   'selection',
#   'event'],
#  ['describe',
#   'new',
#   'algorithm',
#   '$',
#   'k,\\ell)$-pebble',
#   'game',
#   'color',
#   'use',
#   'obtain',
#   'characterization',
#   'family',
#   '$',
#   'k,\\ell)$-sparse',
#   'graph',
#   'algorithmic',
#   'solution',
#   'family',
#   'problem',
#   'concern',
#   'tree',
#   'decomposition',
#   'graph',
#   'special',
#   'instance',
#   'sparse',
#   'graph',
#   'appear',
#   'rigidity',
#   'theory',
#   'receive',
#   'increase',
#   'attention',
#   'recent',
#   'year',
#   'particular',
#   'colored',
#   'pebble',
#   'generalize',
#   'strengthen',
#   'previous',
#   'result',
#   'Lee',
#   'Streinu',
#   'give',
#   'new',
#   'proof',
#   'Tutte',
#   'Nash',
#   'Williams',
#   'characterization',
#   'arboricity',
#   'also',
#   'present',
#   'new',
#   'decomposition',
#   'certify',
#   'sparsity',
#   'base',
#   '$',
#   'k,\\ell)$-pebble',
#   'game',
#   'color',
#   'work',
#   'also',
#   'expose',
#   'connection',
#   'pebble',
#   'game',
#   'algorithm',
#   'previous',
#   'sparse',
#   'graph',
#   'algorithm',
#   'Gabow',
#   'Gabow',
#   'Westermann',
#   'Hendrickson'],
#  ['evolution',
#   'Earth',
#   'Moon',
#   'system',
#   'describe',
#   'dark',
#   'matter',
#   'field',
#   'fluid',
#   'model',
#   'propose',
#   'Meeting',
#   'Division',
#   'Particle',
#   'Field',
#   '2004',
#   'American',
#   'Physical',
#   'Society',
#   'current',
#   'behavior',
#   'Earth',
#   'Moon',
#   'system',
#   'agree',
#   'model',
#   'well',
#   'general',
#   'pattern',
#   'evolution',
#   'Moon',
#   'Earth',
#   'system',
#   'describe',
#   'model',
#   'agree',
#   'geological',
#   'fossil',
#   'evidence',
#   'close',
#   'distance',
#   'Moon',
#   'Earth',
#   '259000',
#   'km',
#   '4.5',
#   'billion',
#   'year',
#   'ago',
#   'far',
#   'beyond',
#   'Roche',
#   "'s",
#   'limit',
#   'result',
#   'suggest',
#   'tidal',
#   'friction',
#   'may',
#   'primary',
#   'cause',
#   'evolution',
#   'Earth',
#   'Moon',
#   'system',
#   'average',
#   'dark',
#   'matter',
#   'field',
#   'fluid',
#   'constant',
#   'derive',
#   'Earth',
#   'Moon',
#   'system',
#   'datum',
#   '4.39',
#   'x',
#   '10^(-22',
#   's^(-1)m^(-1',
#   'model',
#   'predict',
#   'Mars',
#   "'s",
#   'rotation',
#   'also',
#   'slow',
#   'angular',
#   'acceleration',
#   'rate',
#   '-4.38',
#   'x',
#   '10^(-22',
#   'rad',
#   's^(-2'],
#  ['show',
#   'determinant',
#   'Stirling',
#   'cycle',
#   'number',
#   'count',
#   'unlabeled',
#   'acyclic',
#   'single',
#   'source',
#   'automata',
#   'proof',
#   'involve',
#   'bijection',
#   'automata',
#   'certain',
#   'marked',
#   'lattice',
#   'path',
#   'sign',
#   'reverse',
#   'involution',
#   'evaluate',
#   'determinant'],
#  ['paper',
#   'show',
#   'compute',
#   '$',
#   '\\Lambda_{\\alpha}$',
#   'norm',
#   '$',
#   '\\alpha\\ge',
#   '0',
#   '$',
#   'use',
#   'dyadic',
#   'grid',
#   'result',
#   'consequence',
#   'description',
#   'Hardy',
#   'space',
#   '$',
#   'h^p(r^n)$',
#   'term',
#   'dyadic',
#   'special',
#   'atom'],
#  ['study',
#   'two',
#   'particle',
#   'wave',
#   'function',
#   'pair',
#   'atom',
#   'Fermi',
#   'gas',
#   'tunable',
#   'interaction',
#   'strength',
#   'control',
#   'Feshbach',
#   'resonance',
#   'Cooper',
#   'pair',
#   'wave',
#   'function',
#   'examine',
#   'bosonic',
#   'character',
#   'quantify',
#   'correction',
#   'Bose',
#   'enhancement',
#   'factor',
#   'associate',
#   'creation',
#   'annihilation',
#   'composite',
#   'particle',
#   'operator',
#   'example',
#   'give',
#   'three',
#   'dimensional',
#   'uniform',
#   'gas',
#   'two',
#   'definition',
#   'cooper',
#   'pair',
#   'wave',
#   'function',
#   'examine',
#   'one',
#   'choose',
#   'reflect',
#   'diagonal',
#   'long',
#   'range',
#   'order',
#   'ODLRO',
#   'another',
#   'one',
#   'correspond',
#   'pair',
#   'projection',
#   'BCS',
#   'state',
#   'side',
#   'negative',
#   'scatter',
#   'length',
#   'find',
#   'pair',
#   'atom',
#   'describe',
#   'ODLRO',
#   'bosonic',
#   'pair',
#   'project',
#   'definition',
#   'also',
#   'find',
#   '$',
#   'k_f',
#   'a)^{-1',
#   '\\ge',
#   '1',
#   '$',
#   'definition',
#   'give',
#   'similar',
#   'result',
#   '90',
#   'atom',
#   'occupy',
#   'correspond',
#   'molecular',
#   'condensate'],
#  ['rather',
#   'non',
#   'standard',
#   'quantum',
#   'representation',
#   'canonical',
#   'commutation',
#   'relation',
#   'quantum',
#   'mechanic',
#   'system',
#   'know',
#   'polymer',
#   'representation',
#   'gain',
#   'attention',
#   'recent',
#   'year',
#   'due',
#   'possible',
#   'relation',
#   'planck',
#   'scale',
#   'physic',
#   'particular',
#   'approach',
#   'follow',
#   'symmetric',
#   'sector',
#   'loop',
#   'quantum',
#   'gravity',
#   'know',
#   'loop',
#   'quantum',
#   'cosmology',
#   'explore',
#   'different',
#   'aspect',
#   'relation',
#   'ordinary',
#   'Schroedinger',
#   'theory',
#   'polymer',
#   'description',
#   'paper',
#   'two',
#   'part',
#   'first',
#   'one',
#   'derive',
#   'polymer',
#   'quantum',
#   'mechanic',
#   'start',
#   'ordinary',
#   'Schroedinger',
#   'theory',
#   'show',
#   'polymer',
#   'description',
#   'arise',
#   'appropriate',
#   'limit',
#   'second',
#   'part',
#   'consider',
#   'continuum',
#   'limit',
#   'theory',
#   'namely',
#   'reverse',
#   'process',
#   'one',
#   'start',
#   'discrete',
#   'theory',
#   'try',
#   'recover',
#   'back',
#   'ordinary',
#   'Schroedinger',
#   'quantum',
#   'mechanic',
#   'consider',
#   'several',
#   'example',
#   'interest',
#   'include',
#   'harmonic',
#   'oscillator',
#   'free',
#   'particle',
#   'simple',
#   'cosmological',
#   'model'],
#  ['general',
#   'formulation',
#   'develop',
#   'represent',
#   'material',
#   'model',
#   'application',
#   'dynamic',
#   'loading',
#   'numerical',
#   'method',
#   'devise',
#   'calculate',
#   'response',
#   'shock',
#   'ramp',
#   'compression',
#   'ramp',
#   'decompression',
#   'generalize',
#   'previous',
#   'solution',
#   'scalar',
#   'equation',
#   'state',
#   'numerical',
#   'method',
#   'find',
#   'flexible',
#   'robust',
#   'match',
#   'analytic',
#   'result',
#   'high',
#   'accuracy',
#   'basic',
#   'ramp',
#   'shock',
#   'solution',
#   'method',
#   'couple',
#   'solve',
#   'composite',
#   'deformation',
#   'path',
#   'shock',
#   'induce',
#   'impact',
#   'shock',
#   'interaction',
#   'planar',
#   'interface',
#   'different',
#   'material',
#   'calculation',
#   'capture',
#   'much',
#   'physics',
#   'typical',
#   'material',
#   'dynamic',
#   'experiment',
#   'without',
#   'require',
#   'spatially',
#   'resolve',
#   'simulation',
#   'example',
#   'calculation',
#   'make',
#   'loading',
#   'history',
#   'metal',
#   'illustrate',
#   'effect',
#   'plastic',
#   'work',
#   'temperature',
#   'induce',
#   'quasi',
#   'isentropic',
#   'shock',
#   'release',
#   'experiment',
#   'effect',
#   'phase',
#   'transition'],
#  ['discuss',
#   'result',
#   'combined',
#   'irac',
#   'MIPS',
#   'c2d',
#   'Spitzer',
#   'Legacy',
#   'observation',
#   'Serpens',
#   'star',
#   'form',
#   'region',
#   'particular',
#   'present',
#   'set',
#   'criterion',
#   'isolate',
#   'bona',
#   'fide',
#   'young',
#   'stellar',
#   'object',
#   'YSO',
#   "'s",
#   'extensive',
#   'background',
#   'contamination',
#   'extra',
#   'galactic',
#   'object',
#   'discuss',
#   'property',
#   'result',
#   'high',
#   'confidence',
#   'set',
#   'YSO',
#   "'s",
#   'find',
#   '235',
#   'object',
#   '0.85',
#   'deg^2',
#   'field',
#   'cover',
#   'irac',
#   'MIPS',
#   'additional',
#   'set',
#   '51',
#   'low',
#   'confidence',
#   'YSO',
#   "'s",
#   'outside',
#   'area',
#   'identify',
#   'MIPS',
#   'datum',
#   'combine',
#   '2MASS',
#   'photometry',
#   'describe',
#   'two',
#   'set',
#   'result',
#   'color',
#   'color',
#   'diagram',
#   'compare',
#   'observe',
#   'source',
#   'property',
#   'theoretical',
#   'model',
#   'star',
#   'disk',
#   'envelope',
#   'system',
#   'modeling',
#   'subset',
#   'object',
#   'appear',
#   'star+disk',
#   'object',
#   'exhibit',
#   'wide',
#   'range',
#   'disk',
#   'property',
#   'many',
#   'fit',
#   'actively',
#   'accrete',
#   'disk',
#   'passive',
#   'disk',
#   'even',
#   'possibly',
#   'debris',
#   'disk',
#   'find',
#   'luminosity',
#   'function',
#   'YSO',
#   "'s",
#   'Serpens',
#   'extend',
#   'least',
#   'x',
#   '.001',
#   'Lsun',
#   'low',
#   'assumed',
#   'distance',
#   '260',
#   'pc',
#   'low',
#   'limit',
#   'may',
#   'set',
#   'inability',
#   'distinguish',
#   'YSO',
#   "'s",
#   'extra',
#   'galactic',
#   'source',
#   'lack',
#   'YSO',
#   "'s",
#   'low',
#   'luminosity',
#   'spatial',
#   'clustering',
#   'analysis',
#   'show',
#   'nominally',
#   'less',
#   'evolve',
#   'YSO',
#   "'s",
#   'highly',
#   'cluster',
#   'later',
#   'stage',
#   'background',
#   'extra',
#   'galactic',
#   'population',
#   'fit',
#   'two',
#   'point',
#   'correlation',
#   'function',
#   'see',
#   'extra',
#   'galactic',
#   'study',
#   'also',
#   'present',
#   'table',
#   'match',
#   'several',
#   'previous',
#   'infrared',
#   'x',
#   'ray',
#   'study',
#   'Serpens',
#   'YSO',
#   'population',
#   'Spitzer',
#   'datum',
#   'set'],
#  ['partial',
#   'cube',
#   'isometric',
#   'subgraph',
#   'hypercube',
#   'structure',
#   'graph',
#   'define',
#   'mean',
#   'semicube',
#   "Djokovi\\'{c",
#   "'s",
#   'Winkler',
#   "'s",
#   'relation',
#   'play',
#   'important',
#   'role',
#   'theory',
#   'partial',
#   'cube',
#   'structure',
#   'employ',
#   'paper',
#   'characterize',
#   'bipartite',
#   'graph',
#   'partial',
#   'cube',
#   'arbitrary',
#   'dimension',
#   'new',
#   'characterization',
#   'establish',
#   'new',
#   'proof',
#   'know',
#   'result',
#   'give',
#   'operation',
#   'cartesian',
#   'product',
#   'pasting',
#   'expansion',
#   'contraction',
#   'process',
#   'utilize',
#   'paper',
#   'construct',
#   'new',
#   'partial',
#   'cube',
#   'old',
#   'one',
#   'particular',
#   'isometric',
#   'lattice',
#   'dimension',
#   'finite',
#   'partial',
#   'cube',
#   'obtain',
#   'mean',
#   'operation',
#   'calculate'],
#  ['paper',
#   'present',
#   'algorithm',
#   'compute',
#   'Hecke',
#   'eigensystem',
#   'Hilbert',
#   'Siegel',
#   'cusp',
#   'form',
#   'real',
#   'quadratic',
#   'field',
#   'narrow',
#   'class',
#   'number',
#   'one',
#   'give',
#   'illustrative',
#   'example',
#   'use',
#   'quadratic',
#   'field',
#   '$',
#   '\\q(\\sqrt{5})$.',
#   'example',
#   'identify',
#   'Hilbert',
#   'Siegel',
#   'eigenform',
#   'possible',
#   'lift',
#   'Hilbert',
#   'eigenform'],
#  ['recently',
#   'Bruinier',
#   'Ono',
#   'classify',
#   'cusp',
#   'form',
#   '$',
#   'f(z',
#   '=',
#   '\\sum_{n=0}^{\\infty',
#   'a_f(n)q',
#   '^n',
#   '\\in',
#   'S_{\\lambda+1/2}(\\Gamma_0(N),\\chi)\\cap',
#   '\\mathbb{Z}[[q]]$',
#   'satisfy',
#   'certain',
#   'distribution',
#   'property',
#   'modulo',
#   'odd',
#   'prime',
#   '$',
#   'p$.',
#   'paper',
#   'use',
#   'Rankin',
#   'Cohen',
#   'Bracket',
#   'extend',
#   'result',
#   'modular',
#   'form',
#   'half',
#   'integral',
#   'weight',
#   'prime',
#   '$',
#   'p',
#   '\\geq',
#   '5$.',
#   'application',
#   'main',
#   'theorem',
#   'derive',
#   'distribution',
#   'property',
#   'modulo',
#   'prime',
#   '$',
#   'p\\geq5',
#   '$',
#   'trace',
#   'singular',
#   'modulus',
#   'Hurwitz',
#   'class',
#   'number',
#   'also',
#   'study',
#   'analogue',
#   'Newman',
#   "'s",
#   'conjecture',
#   'overpartition'],
#  ['Serre',
#   'obtain',
#   'p',
#   'adic',
#   'limit',
#   'integral',
#   'Fourier',
#   'coefficient',
#   'modular',
#   'form',
#   '$',
#   'sl_2(\\mathbb{z})$',
#   '$',
#   'p=2,3,5,7$.',
#   'paper',
#   'extend',
#   'result',
#   'Serre',
#   'weakly',
#   'holomorphic',
#   'modular',
#   'form',
#   'half',
#   'integral',
#   'weight',
#   '$',
#   '\\gamma_{0}(4n)$',
#   '$',
#   'n=1,2,4$.',
#   'proof',
#   'base',
#   'linear',
#   'relation',
#   'among',
#   'Fourier',
#   'coefficient',
#   'modular',
#   'form',
#   'half',
#   'integral',
#   'weight',
#   'application',
#   'obtain',
#   'congruence',
#   'Borcherds',
#   'exponent',
#   'congruence',
#   'quotient',
#   'Eisentein',
#   'series',
#   'congruence',
#   'value',
#   '$',
#   'l$-function',
#   'certain',
#   'point',
#   'also',
#   'study',
#   'furthermore',
#   'congruence',
#   'Fourier',
#   'coefficient',
#   'Siegel',
#   'modular',
#   'form',
#   'Maass',
#   'Space',
#   'obtain',
#   'use',
#   'Ikeda',
#   'lifting'],
#  ['article',
#   'discuss',
#   'relation',
#   'string',
#   'topology',
#   'differential',
#   'form',
#   'base',
#   'theory',
#   'Chen',
#   "'s",
#   'iterated',
#   'integral',
#   'cyclic',
#   'bar',
#   'complex'],
#  ['pure',
#   'spinor',
#   'formulation',
#   'ten',
#   'dimensional',
#   'superstring',
#   'lead',
#   'manifestly',
#   'supersymmetric',
#   'loop',
#   'amplitude',
#   'express',
#   'integral',
#   'pure',
#   'spinor',
#   'superspace',
#   'paper',
#   'explore',
#   'different',
#   'method',
#   'evaluate',
#   'integral',
#   'use',
#   'calculate',
#   'kinematic',
#   'factor',
#   'one',
#   'loop',
#   'two',
#   'loop',
#   'massless',
#   'four',
#   'point',
#   'amplitude',
#   'involve',
#   'two',
#   'four',
#   'Ramond',
#   'state'],
#  ['work',
#   'evaluate',
#   'lifetime',
#   'doubly',
#   'charm',
#   'baryon',
#   '$',
#   '\\xi_{cc}^{+}$',
#   '$',
#   '\\xi_{cc}^{++}$',
#   '$',
#   '\\Omega_{cc}^{+}$.',
#   'carefully',
#   'calculate',
#   'non',
#   'spectator',
#   'contribution',
#   'quark',
#   'level',
#   'Cabibbo',
#   'suppress',
#   'diagram',
#   'also',
#   'include',
#   'hadronic',
#   'matrix',
#   'element',
#   'evaluate',
#   'simple',
#   'non',
#   'relativistic',
#   'harmonic',
#   'oscillator',
#   'model',
#   'numerical',
#   'result',
#   'generally',
#   'consistent',
#   'obtain',
#   'author',
#   'use',
#   'diquark',
#   'model',
#   'however',
#   'theoretical',
#   'prediction',
#   'lifetime',
#   'one',
#   'order',
#   'large',
#   'upper',
#   'limit',
#   'set',
#   'recent',
#   'SELEX',
#   'measurement',
#   'discrepancy',
#   'would',
#   'clarify',
#   'future',
#   'experiment',
#   'accurate',
#   'experiment',
#   'still',
#   'confirm',
#   'value',
#   'SELEX',
#   'collaboration',
#   'must',
#   'unknown',
#   'mechanism',
#   'explore'],
#  ['result',
#   'spectroscopic',
#   'observation',
#   'Intermediate',
#   'Polar',
#   'IP',
#   'EX',
#   'Hya',
#   'quiescence',
#   '1991',
#   '2001',
#   'present',
#   'spin',
#   'modulate',
#   'radial',
#   'velocity',
#   'consistent',
#   'outer',
#   'disc',
#   'origin',
#   'detect',
#   'first',
#   'time',
#   'IP',
#   'spin',
#   'pulsation',
#   'modulate',
#   'velocity',
#   'near',
#   '~500',
#   '600',
#   'km',
#   's.',
#   'velocity',
#   'consistent',
#   'material',
#   'circulate',
#   'outer',
#   'edge',
#   'accretion',
#   'disc',
#   'suggest',
#   'corotation',
#   'accretion',
#   'curtain',
#   'material',
#   'near',
#   'Roche',
#   'lobe',
#   'radius',
#   'furthermore',
#   'spin',
#   'Doppler',
#   'tomogram',
#   'reveal',
#   'evidence',
#   'accretion',
#   'curtain',
#   'emission',
#   'extend',
#   'velocity',
#   '~500',
#   'km',
#   '~1000',
#   'km',
#   's.',
#   'finding',
#   'confirm',
#   'theoretical',
#   'model',
#   'prediction',
#   'King',
#   'Wynn',
#   '1999',
#   'Belle',
#   'et',
#   'al',
#   '2002',
#   'Norton',
#   'et',
#   'al',
#   '2004',
#   'EX',
#   'Hya',
#   'predict',
#   'large',
#   'accretion',
#   'curtain',
#   'extend',
#   'distance',
#   'close',
#   'Roche',
#   'lobe',
#   'radius',
#   'system',
#   'evidence',
#   'overflow',
#   'stream',
#   'material',
#   'fall',
#   'onto',
#   'magnetosphere',
#   'observe',
#   'confirm',
#   'result',
#   'Belle',
#   'et',
#   'al',
#   '2005',
#   'disc',
#   'overflow',
#   'EX',
#   'Hya',
#   'present',
#   'quiescence',
#   'well',
#   'outburst',
#   'appear',
#   'hbeta',
#   'hgamma',
#   'spin',
#   'radial',
#   'velocity',
#   'originate',
#   'rotation',
#   'funnel',
#   'outer',
#   'disc',
#   'edge',
#   'halpha',
#   'produce',
#   'due',
#   'flow',
#   'material',
#   'along',
#   'field',
#   'line',
#   'far',
#   'white',
#   'dwarf',
#   'narrow',
#   'component',
#   'close',
#   'white',
#   'dwarf',
#   'broad',
#   'base',
#   'component',
#   'agreement',
#   'accretion',
#   'curtain',
#   'model'],
#  ['give',
#   'prescription',
#   'compute',
#   'Callias',
#   'index',
#   'use',
#   'regulator',
#   'exponential',
#   'function',
#   'find',
#   'agreement',
#   'old',
#   'result',
#   'odd',
#   'dimension',
#   'show',
#   'problem',
#   'compute',
#   'dimension',
#   'modulus',
#   'space',
#   'self',
#   'dual',
#   'string',
#   'formulate',
#   'index',
#   'problem',
#   'even',
#   'dimensional',
#   'loop-)space',
#   'think',
#   'regulator',
#   'use',
#   'letter',
#   'apply',
#   'index',
#   'problem'],
#  ['note',
#   'give',
#   'new',
#   'method',
#   'get',
#   'series',
#   'approximation',
#   'extinction',
#   'probability',
#   'one',
#   'dimensional',
#   'contact',
#   'process',
#   'use',
#   'gr\\"obner',
#   'basis'],
#  ['shape',
#   'hadronic',
#   'form',
#   'factor',
#   'f+(q2',
#   'decay',
#   'D0',
#   '>',
#   'K-',
#   'e+',
#   'nue',
#   'measure',
#   'model',
#   'independent',
#   'analysis',
#   'compare',
#   'theoretical',
#   'calculation',
#   'use',
#   '75',
#   'fb(-1',
#   'datum',
#   'record',
#   'BABAR',
#   'detector',
#   'PEPII',
#   'electron',
#   'positron',
#   'collider',
#   'correspond',
#   'decay',
#   'branch',
#   'fraction',
#   'relative',
#   'decay',
#   'D0',
#   '>',
#   'K-',
#   'pi+',
#   'also',
#   'measure',
#   'RD',
#   '=',
#   'BR(D0',
#   '>',
#   'K-',
#   'e+',
#   'nue)/br(d0',
#   '>',
#   'K-',
#   'pi+',
#   '=',
#   '0.927',
#   '+',
#   '0.007',
#   '+',
#   '0.012',
#   'result',
#   'use',
#   'present',
#   'world',
#   'average',
#   'value',
#   'BR(D0',
#   '>',
#   'K-',
#   'pi+',
#   'normalization',
#   'form',
#   'factor',
#   'q2=0',
#   'determined',
#   'f+(0)=0.727',
#   '+',
#   '0.007',
#   '+',
#   '0.005',
#   '+',
#   '0.007',
#   'uncertainty',
#   'statistical',
#   'systematic',
#   'external',
#   'input',
#   'respectively'],
#  ['spatiotemporal',
#   'pattern',
#   'formation',
#   'product',
#   'activate',
#   'enzymic',
#   'reaction',
#   'high',
#   'enzyme',
#   'concentration',
#   'investigate',
#   'stochastic',
#   'simulation',
#   'show',
#   'catalytic',
#   'turnover',
#   'cycle',
#   'individual',
#   'enzyme',
#   'become',
#   'coherent',
#   'complex',
#   'wave',
#   'pattern',
#   'molecular',
#   'synchronization',
#   'develop',
#   'analysis',
#   'base',
#   'mean',
#   'field',
#   'approximation',
#   'indicate',
#   'observe',
#   'pattern',
#   'result',
#   'presence',
#   'Hopf',
#   'wave',
#   'bifurcation',
#   'consider',
#   'system'],
#  ['present',
#   'lie',
#   'group',
#   'integrator',
#   'nonlinear',
#   'stochastic',
#   'differential',
#   'equation',
#   'non',
#   'commutative',
#   'vector',
#   'field',
#   'whose',
#   'solution',
#   'evolve',
#   'smooth',
#   'finite',
#   'dimensional',
#   'manifold',
#   'give',
#   'lie',
#   'group',
#   'action',
#   'generate',
#   'transport',
#   'along',
#   'manifold',
#   'pull',
#   'back',
#   'stochastic',
#   'flow',
#   'manifold',
#   'lie',
#   'group',
#   'via',
#   'action',
#   'subsequently',
#   'pull',
#   'back',
#   'flow',
#   'corresponding',
#   'lie',
#   'algebra',
#   'via',
#   'exponential',
#   'map',
#   'construct',
#   'approximation',
#   'stochastic',
#   'flow',
#   'lie',
#   'algebra',
#   'via',
#   'closed',
#   'operation',
#   'push',
#   'back',
#   'lie',
#   'group',
#   'manifold',
#   'thus',
#   'ensure',
#   'approximation',
#   'lie',
#   'manifold',
#   'call',
#   'scheme',
#   'stochastic',
#   'Munthe',
#   'Kaas',
#   'method',
#   'deterministic',
#   'counterpart',
#   'also',
#   'present',
#   'stochastic',
#   'lie',
#   'group',
#   'integration',
#   'scheme',
#   'base',
#   'Castell',
#   'gaine',
#   'method',
#   'involve',
#   'use',
#   'underlying',
#   'ordinary',
#   'differential',
#   'integrator',
#   'approximate',
#   'flow',
#   'generate',
#   'truncate',
#   'stochastic',
#   'exponential',
#   'lie',
#   'series',
#   'become',
#   'stochastic',
#   'lie',
#   'group',
#   'integrator',
#   'scheme',
#   'use',
#   'Munthe',
#   'Kaas',
#   'method',
#   'underlie',
#   'ordinary',
#   'differential',
#   'integrator',
#   'far',
#   'show',
#   'Castell',
#   'gaine',
#   'method',
#   'uniformly',
#   'accurate',
#   'correspond',
#   'stochastic',
#   'Taylor',
#   'scheme',
#   'lastly',
#   'demonstrate',
#   'method',
#   'simulate',
#   'dynamic',
#   'free',
#   'rigid',
#   'body',
#   'satellite',
#   'autonomous',
#   'underwater',
#   'vehicle',
#   'perturb',
#   'two',
#   'independent',
#   'multiplicative',
#   'stochastic',
#   'noise',
#   'process'],
#  ['nature',
#   'solar',
#   'chromosphere',
#   'structuring',
#   'dynamic',
#   'remain',
#   'far',
#   'properly',
#   'understand',
#   'spite',
#   'intensive',
#   'research',
#   'point',
#   'potential',
#   'chromospheric',
#   'observation',
#   'millimeter',
#   'wavelength',
#   'resolve',
#   'long',
#   'stand',
#   'problem',
#   'computation',
#   'carry',
#   'sophisticated',
#   'dynamic',
#   'model',
#   'solar',
#   'chromosphere',
#   'due',
#   'Carlsson',
#   'Stein',
#   'demonstrate',
#   'millimeter',
#   'emission',
#   'extremely',
#   'sensitive',
#   'dynamic',
#   'process',
#   'chromosphere',
#   'appropriate',
#   'wavelength',
#   'look',
#   'dynamic',
#   'signature',
#   'range',
#   '0.8',
#   '5.0',
#   'mm',
#   'model',
#   'also',
#   'suggest',
#   'high',
#   'resolution',
#   'observation',
#   'mm',
#   'wavelength',
#   'provide',
#   'ALMA',
#   'unique',
#   'property',
#   'react',
#   'hot',
#   'cool',
#   'gas',
#   'thus',
#   'potential',
#   'distinguish',
#   'rival',
#   'model',
#   'solar',
#   'atmosphere',
#   'thus',
#   'initial',
#   'result',
#   'obtain',
#   'observation',
#   'quiet',
#   'Sun',
#   '3.5',
#   'mm',
#   'bima',
#   'array',
#   'resolution',
#   '12',
#   'arcsec',
#   'reveal',
#   'significant',
#   'oscillation',
#   'amplitude',
#   '50',
#   '150',
#   'k',
#   'frequency',
#   '1.5',
#   '8',
#   'mhz',
#   'tendency',
#   'toward',
#   'short',
#   'period',
#   'oscillation',
#   'internetwork',
#   'long',
#   'period',
#   'network',
#   'region',
#   'however',
#   'high',
#   'spatial',
#   'resolution',
#   'provide',
#   'ALMA',
#   'require',
#   'clean',
#   'separation',
#   'feature',
#   'within',
#   'solar',
#   'atmosphere',
#   'adequate',
#   'comparison',
#   'output',
#   'comprehensive',
#   'dynamic',
#   'simulation'],
#  ['formation',
#   'quasi-2d',
#   'spin',
#   'wave',
#   'waveform',
#   'longitudinally',
#   'magnetize',
#   'stripe',
#   'ferrimagnetic',
#   'film',
#   'observe',
#   'use',
#   'time-',
#   'space',
#   'resolve',
#   'Brillouin',
#   'light',
#   'scatter',
#   'technique',
#   'linear',
#   'regime',
#   'find',
#   'confinement',
#   'decrease',
#   'amplitude',
#   'dynamic',
#   'magnetization',
#   'near',
#   'lateral',
#   'stripe',
#   'edge',
#   'thus',
#   'call',
#   'effective',
#   'dipolar',
#   'pinning',
#   'dynamic',
#   'magnetization',
#   'take',
#   'place',
#   'edge',
#   'nonlinear',
#   'regime',
#   'new',
#   'stable',
#   'spin',
#   'wave',
#   'packet',
#   'propagate',
#   'along',
#   'waveguide',
#   'structure',
#   'transversal',
#   'instability',
#   'interaction',
#   'side',
#   'wall',
#   'waveguide',
#   'important',
#   'observe',
#   'experiment',
#   'numerical',
#   'simulation',
#   'pulse',
#   'evolution',
#   'show',
#   'shape',
#   'form',
#   'waveform',
#   'behavior',
#   'strongly',
#   'influence',
#   'confinement'],
#  ['present',
#   'recent',
#   'advance',
#   'understanding',
#   'ground',
#   'excited',
#   'state',
#   'electron',
#   'phonon',
#   'couple',
#   'system',
#   'obtain',
#   'novel',
#   'method',
#   'Diagrammatic',
#   'Monte',
#   'Carlo',
#   'Stochastic',
#   'Optimization',
#   'enable',
#   'approximation',
#   'free',
#   'calculation',
#   'Matsubara',
#   'Green',
#   'function',
#   'imaginary',
#   'time',
#   'perform',
#   'unbiased',
#   'analytic',
#   'continuation',
#   'real',
#   'frequency',
#   'present',
#   'exact',
#   'numeric',
#   'result',
#   'ground',
#   'state',
#   'property',
#   'Lehmann',
#   'spectral',
#   'function',
#   'optical',
#   'conductivity',
#   'different',
#   'strongly',
#   'correlate',
#   'system',
#   'frohlich',
#   'polaron',
#   'Rashba',
#   'Pekar',
#   'exciton',
#   'polaron',
#   'pseudo',
#   'Jahn',
#   'Teller',
#   'polaron',
#   'exciton',
#   'interact',
#   'phonon',
#   'hole',
#   'J',
#   'model'],
#  ['zero',
#   'divisor',
#   'ZDs',
#   'derive',
#   'Cayley',
#   'Dickson',
#   'Process',
#   'CDP',
#   'N',
#   'dimensional',
#   'hypercomplex',
#   'number',
#   'n',
#   'power',
#   '2',
#   'least',
#   '4',
#   'represent',
#   'singularity',
#   'N',
#   'approach',
#   'infinite',
#   'fractal',
#   'thereby',
#   'scale',
#   'free',
#   'network',
#   'integer',
#   'great',
#   '8',
#   'power',
#   '2',
#   'generate',
#   'meta',
#   'fractal',
#   'Sky',
#   'interpret',
#   'strut',
#   'constant',
#   'S',
#   'ensemble',
#   'octahedral',
#   'vertex',
#   'figure',
#   'call',
#   'Box',
#   'Kites',
#   'fundamental',
#   'building',
#   'block',
#   'zds',
#   'remarkably',
#   'simple',
#   'bit',
#   'manipulation',
#   'rule',
#   'recipe',
#   'provide',
#   'tool',
#   'transform',
#   'one',
#   'fractal',
#   'genus',
#   'within',
#   'context',
#   'Wolfram',
#   "'s",
#   'Class',
#   '4',
#   'complexity'],
#  ['describe',
#   'peculiar',
#   'fine',
#   'structure',
#   'acquire',
#   'plane',
#   'optical',
#   'phonon',
#   'Gamma',
#   'point',
#   'graphene',
#   'bring',
#   'resonance',
#   'one',
#   'inter',
#   'landau',
#   'level',
#   'transition',
#   'material',
#   'effect',
#   'pronounce',
#   'lattice',
#   'mode',
#   'associate',
#   'G',
#   'band',
#   'graphene',
#   'Raman',
#   'spectrum',
#   'resonance',
#   'inter',
#   'landau',
#   'level',
#   'transition',
#   '0',
#   '>',
#   '+',
#   '1',
#   '-,1',
#   '>',
#   '0',
#   'magnetic',
#   'field',
#   'b_0',
#   '~',
#   '30',
#   't.',
#   'use',
#   'measure',
#   'strength',
#   'electron',
#   'phonon',
#   'coupling',
#   'directly',
#   'fill',
#   'factor',
#   'dependence',
#   'use',
#   'experimentally',
#   'detect',
#   'circularly',
#   'polarize',
#   'lattice',
#   'mode'],
#  ['prove',
#   'pfaffian',
#   'hafnian',
#   'version',
#   'Lieb',
#   "'s",
#   'inequality',
#   'determinant',
#   'permanent',
#   'positive',
#   'semi',
#   'definite',
#   'matrix',
#   'use',
#   'hafnian',
#   'inequality',
#   'improve',
#   'low',
#   'bind',
#   "r\\'ev\\'esz",
#   'Sarantopoulos',
#   'norm',
#   'product',
#   'linear',
#   'functional',
#   'real',
#   'euclidean',
#   'space',
#   'subject',
#   'sometimes',
#   'call',
#   '`',
#   'real',
#   'linear',
#   'polarization',
#   'constant',
#   'problem'],
#  ['$',
#   '\\XQM$',
#   'quark',
#   'emit',
#   'goldstone',
#   'boson',
#   'flavor',
#   'symmetry',
#   'break',
#   'Goldstone',
#   'boson',
#   'emission',
#   'process',
#   'use',
#   'intepret',
#   'nucleon',
#   'flavor',
#   'spin',
#   'structure',
#   'paper',
#   'study',
#   'inner',
#   'structure',
#   'constituent',
#   'quark',
#   'imply',
#   '$',
#   '\\XQM$',
#   'cause',
#   'Goldstone',
#   'boson',
#   'emission',
#   'process',
#   'nucleon',
#   'simplified',
#   'model',
#   'Hamiltonian',
#   'derive',
#   '$',
#   '\\XQM$',
#   'intrinsic',
#   'wave',
#   'function',
#   'constituent',
#   'quark',
#   'determine',
#   'obtain',
#   'transition',
#   'probability',
#   'emission',
#   'Goldstone',
#   'boson',
#   'quark',
#   'give',
#   'reasonable',
#   'interpretation',
#   'flavor',
#   'symmetry',
#   'break',
#   'nucleon',
#   'flavor',
#   'spin',
#   'structure'],
#  ['investigate',
#   'effect',
#   'tune',
#   'phonon',
#   'energy',
#   'correlation',
#   'effect',
#   'model',
#   'electron',
#   'phonon',
#   'interaction',
#   'use',
#   'DMFT',
#   'regime',
#   'itinerant',
#   'electron',
#   'instantaneous',
#   'electron',
#   'phonon',
#   'drive',
#   'correlation',
#   'static',
#   'distortion',
#   'compete',
#   'similar',
#   'energy',
#   'scale',
#   'find',
#   'several',
#   'interesting',
#   'result',
#   'include',
#   '1',
#   'crossover',
#   'band',
#   'Mott',
#   'behavior',
#   'spectral',
#   'function',
#   'lead',
#   'hybrid',
#   'band',
#   'Mott',
#   'feature',
#   'spectral',
#   'function',
#   'phonon',
#   'frequency',
#   'slightly',
#   'large',
#   'band',
#   'width',
#   '2',
#   'since',
#   'optical',
#   'conductivity',
#   'depend',
#   'sensitively',
#   'form',
#   'spectral',
#   'function',
#   'show',
#   'regime',
#   'observable',
#   'low',
#   'frequency',
#   'form',
#   'optical',
#   'conductivity',
#   '3',
#   'resistivity',
#   'double',
#   'kondo',
#   'peak',
#   'arrangement'],
#  ['show',
#   'crystal',
#   'trap',
#   'broad',
#   'x',
#   'x',
#   'e',
#   'distribution',
#   'particle',
#   'channel',
#   'preserve',
#   'high',
#   'precision',
#   'sample',
#   'hold',
#   'distribution',
#   'steer',
#   'bent',
#   'crystal',
#   'analysis',
#   'downstream',
#   'simulation',
#   '7',
#   'tev',
#   'Large',
#   'Hadron',
#   'Collider',
#   'crystal',
#   'adapt',
#   'accelerator',
#   'lattice',
#   'trap',
#   '90',
#   'diffractively',
#   'scatter',
#   'proton',
#   'emerge',
#   'interaction',
#   'point',
#   'divergence',
#   '100',
#   'time',
#   'critical',
#   'angle',
#   'set',
#   'criterion',
#   'crystal',
#   'adaptation',
#   'improve',
#   'efficiency',
#   '~100',
#   'fold',
#   'Proton',
#   'angle',
#   'preserve',
#   'crystal',
#   'transmission',
#   'accuracy',
#   '0.1',
#   'microrad',
#   'make',
#   'feasible',
#   'crystal',
#   'application',
#   'measure',
#   'forward',
#   'proton',
#   'LHC'],
#  ['analyze',
#   'possibility',
#   'probe',
#   'non',
#   'standard',
#   'neutrino',
#   'interaction',
#   'NSI',
#   'short',
#   'detection',
#   'neutrino',
#   'produce',
#   'future',
#   'galactic',
#   'supernova',
#   'sn).we',
#   'consider',
#   'effect',
#   'NSI',
#   'neutrino',
#   'propagation',
#   'SN',
#   'envelope',
#   'within',
#   'three',
#   'neutrino',
#   'framework',
#   'pay',
#   'special',
#   'attention',
#   'inclusion',
#   'NSI',
#   'induce',
#   'resonant',
#   'conversion',
#   'may',
#   'take',
#   'place',
#   'deleptonised',
#   'inner',
#   'layer',
#   'study',
#   'possibility',
#   'detect',
#   'NSI',
#   'effect',
#   'Megaton',
#   'water',
#   'Cherenkov',
#   'detector',
#   'either',
#   'modulation',
#   'effect',
#   '$',
#   '\\bar\\nu_e$',
#   'spectrum',
#   'due',
#   'passage',
#   'shock',
#   'wave',
#   'SN',
#   'envelope',
#   'ii',
#   'time',
#   'dependence',
#   'electron',
#   'fraction',
#   'iii',
#   'Earth',
#   'matter',
#   'effect',
#   'finally',
#   'possible',
#   'detectability',
#   'neutronization',
#   '$',
#   '\\nu_e$',
#   'burst',
#   'find',
#   '$',
#   '\\bar\\nu_e$',
#   'spectrum',
#   'exhibit',
#   'dramatic',
#   'feature',
#   'due',
#   'internal',
#   'NSI',
#   'induce',
#   'resonant',
#   'conversion',
#   'occur',
#   'non',
#   'universal',
#   'NSI',
#   'strength',
#   'small',
#   'flavor',
#   'change',
#   'NSI',
#   'few$\\time',
#   '10^{-5}$.'],
#  ['perform',
#   'rigorous',
#   'theoretical',
#   'convergence',
#   'analysis',
#   'discrete',
#   'dipole',
#   'approximation',
#   'DDA',
#   'prove',
#   'error',
#   'measured',
#   'quantity',
#   'bound',
#   'sum',
#   'linear',
#   'quadratic',
#   'term',
#   'size',
#   'dipole',
#   'latter',
#   'range',
#   'DDA',
#   'applicability',
#   'moreover',
#   'linear',
#   'term',
#   'significantly',
#   'small',
#   'cubically',
#   'non',
#   'cubically',
#   'shape',
#   'scatterer',
#   'therefore',
#   'small',
#   'error',
#   'cubically',
#   'shape',
#   'particle',
#   'much',
#   'small',
#   'non',
#   'cubically',
#   'shape',
#   'relative',
#   'importance',
#   'linear',
#   'term',
#   'decrease',
#   'increase',
#   'size',
#   'hence',
#   'convergence',
#   'DDA',
#   'large',
#   'enough',
#   'scatterer',
#   'quadratic',
#   'common',
#   'range',
#   'd.',
#   'Extensive',
#   'numerical',
#   'simulation',
#   'carry',
#   'wide',
#   'range',
#   'd.',
#   'finally',
#   'discuss',
#   'number',
#   'new',
#   'development',
#   'DDA',
#   'consequence',
#   'convergence'],
#  ['supplement',
#   'paper',
#   'arXiv',
#   'q',
#   'bio/0701050',
#   'contain',
#   'text',
#   'correspondence',
#   'send',
#   'Nature',
#   '1990'],
#  ['propose',
#   'extrapolation',
#   'technique',
#   'allow',
#   'accuracy',
#   'improvement',
#   'discrete',
#   'dipole',
#   'approximation',
#   'computation',
#   'performance',
#   'technique',
#   'study',
#   'empirically',
#   'base',
#   'extensive',
#   'simulation',
#   '5',
#   'test',
#   'case',
#   'use',
#   'many',
#   'different',
#   'discretization',
#   'quality',
#   'extrapolation',
#   'improve',
#   'refining',
#   'discretization',
#   'reach',
#   'extraordinary',
#   'performance',
#   'especially',
#   'cubically',
#   'shape',
#   'particle',
#   'two',
#   'order',
#   'magnitude',
#   'decrease',
#   'error',
#   'demonstrate',
#   'also',
#   'propose',
#   'estimate',
#   'extrapolation',
#   'error',
#   'prove',
#   'reliable',
#   'finally',
#   'propose',
#   'simple',
#   'method',
#   'directly',
#   'separate',
#   'shape',
#   'discretization',
#   'error',
#   'illustrate',
#   'one',
#   'test',
#   'case'],
#  ['multisite',
#   'phosphorylation',
#   'dephosphorylation',
#   'cycle',
#   'motif',
#   'repeatedly',
#   'use',
#   'cell',
#   'signaling',
#   'motif',
#   'generate',
#   'variety',
#   'dynamic',
#   'behavior',
#   'like',
#   'bistability',
#   'ultrasensitivity',
#   'without',
#   'direct',
#   'positive',
#   'feedback',
#   'paper',
#   'study',
#   'number',
#   'positive',
#   'steady',
#   'state',
#   'general',
#   'multisite',
#   'phosphorylation',
#   'dephosphorylation',
#   'cycle',
#   'number',
#   'positive',
#   'steady',
#   'state',
#   'vary',
#   'change',
#   'biological',
#   'parameter',
#   'show',
#   'analytically',
#   '1',
#   'parameter',
#   'range',
#   'least',
#   'n+1',
#   'n',
#   'even',
#   'n',
#   'n',
#   'odd',
#   'steady',
#   'state',
#   '2',
#   'never',
#   '2n-1',
#   'steady',
#   'state',
#   'particular',
#   'imply',
#   'n=2',
#   'include',
#   'single',
#   'level',
#   'MAPK',
#   'cascade',
#   'three',
#   'steady',
#   'state',
#   '3',
#   'parameter',
#   'near',
#   'standard',
#   'Michaelis',
#   'Menten',
#   'quasi',
#   'steady',
#   'state',
#   'condition',
#   'n+1',
#   'steady',
#   'state',
#   '4',
#   'parameter',
#   'far',
#   'standard',
#   'Michaelis',
#   'Menten',
#   'quasi',
#   'steady',
#   'state',
#   'condition',
#   'one',
#   'steady',
#   'state'],
#  ['manuscript',
#   'investigate',
#   'capability',
#   'Discrete',
#   'Dipole',
#   'Approximation',
#   'DDA',
#   'simulate',
#   'scatter',
#   'particle',
#   'much',
#   'large',
#   'wavelength',
#   'incident',
#   'light',
#   'describe',
#   'optimize',
#   'publicly',
#   'available',
#   'DDA',
#   'computer',
#   'program',
#   'process',
#   'large',
#   'number',
#   'dipole',
#   'require',
#   'simulation',
#   'numerical',
#   'simulation',
#   'light',
#   'scatter',
#   'sphere',
#   'size',
#   'parameter',
#   'x',
#   '160',
#   '40',
#   'refractive',
#   'index',
#   'm=1.05',
#   '2',
#   'respectively',
#   'present',
#   'compare',
#   'exact',
#   'result',
#   'Mie',
#   'theory',
#   'error',
#   'integral',
#   'angle',
#   'resolve',
#   'scatter',
#   'quantity',
#   'generally',
#   'increase',
#   'show',
#   'systematic',
#   'dependence',
#   'x.',
#   'Computational',
#   'time',
#   'increase',
#   'steeply',
#   'x',
#   'reach',
#   'value',
#   '2',
#   'week',
#   'cluster',
#   '64',
#   'processor',
#   'main',
#   'distinctive',
#   'feature',
#   'computer',
#   'program',
#   'ability',
#   'parallelize',
#   'single',
#   'DDA',
#   'simulation',
#   'cluster',
#   'computer',
#   'allow',
#   'simulate',
#   'light',
#   'scatter',
#   'large',
#   'particle',
#   'like',
#   'one',
#   'consider',
#   'manuscript',
#   'current',
#   'limitation',
#   'possible',
#   'way',
#   'improvement',
#   'discuss'],
#  ['present',
#   'review',
#   'discrete',
#   'dipole',
#   'approximation',
#   'DDA',
#   'general',
#   'method',
#   'simulate',
#   'light',
#   'scatter',
#   'arbitrarily',
#   'shape',
#   'particle',
#   'put',
#   'method',
#   'historical',
#   'context',
#   'discuss',
#   'recent',
#   'development',
#   'take',
#   'viewpoint',
#   'general',
#   'framework',
#   'base',
#   'integral',
#   'equation',
#   'electric',
#   'field',
#   'review',
#   'theory',
#   'DDA',
#   'numerical',
#   'aspect',
#   'latter',
#   'critical',
#   'importance',
#   'practical',
#   'application',
#   'method',
#   'finally',
#   'position',
#   'DDA',
#   'among',
#   'method',
#   'light',
#   'scatter',
#   'simulation',
#   'show',
#   'possible',
#   'future',
#   'development',
#   'discuss'],
#  ['quadratic',
#   'pion',
#   'scalar',
#   'radius',
#   '\\la',
#   'r^2\\ra^\\pi_s',
#   'play',
#   'important',
#   'role',
#   'present',
#   'precise',
#   'determination',
#   '\\pi\\pi',
#   'scattering',
#   'recently',
#   "Yndur\\'ain",
#   'use',
#   'omn\\`es',
#   'representation',
#   'null',
#   'isospin(I',
#   'non',
#   'strange',
#   'pion',
#   'scalar',
#   'form',
#   'factor',
#   'obtain',
#   '\\la',
#   'r^2\\ra^\\pi_s=0.75\\pm',
#   '0.07',
#   'fm^2',
#   'value',
#   'large',
#   'one',
#   'calculate',
#   'solve',
#   'corresponding',
#   'Muskhelishvili',
#   'omn\\`es',
#   'equation',
#   '\\la',
#   'r^2\\ra^\\pi_s=0.61\\pm',
#   '0.04',
#   'fm^2',
#   'large',
#   'discrepancy',
#   'value',
#   'give',
#   'precision',
#   'result',
#   'reanalyze',
#   "Yndur\\'ain",
#   "'s",
#   'method',
#   'show',
#   'impose',
#   'continuity',
#   'result',
#   'pion',
#   'scalar',
#   'form',
#   'factor',
#   'tiny',
#   'change',
#   'input',
#   '\\pi\\pi',
#   'phase',
#   'shift',
#   'zero',
#   'form',
#   'factor',
#   'wave',
#   'I=0',
#   'T',
#   'matrix',
#   'require',
#   'account',
#   'result',
#   'value',
#   '\\la',
#   'r^2\\ra_s^\\pi=0.65\\pm',
#   '0.05',
#   'fm^2',
#   'main',
#   'source',
#   'error',
#   'determination',
#   'present',
#   'experimental',
#   'uncertainty',
#   'low',
#   'energy',
#   'S',
#   'wave',
#   'I=0',
#   '\\pi\\pi',
#   'phase',
#   'shift',
#   'another',
#   'important',
#   'contribution',
#   'error',
#   'yet',
#   'settle',
#   'asymptotic',
#   'behaviour',
#   'phase',
#   'scalar',
#   'form',
#   'factor',
#   'QCD'],
#  ['case',
#   'freeness',
#   'monotonic',
#   'independence',
#   'notion',
#   'conditional',
#   'freeness',
#   'meaningful',
#   'complex',
#   'value',
#   'state',
#   'replace',
#   'positive',
#   'conditional',
#   'expectation',
#   'framework',
#   'paper',
#   'present',
#   'several',
#   'positivity',
#   'result',
#   'version',
#   'central',
#   'limit',
#   'theorem',
#   'analogue',
#   'conditionally',
#   'free',
#   'r',
#   'transform',
#   'construct',
#   'mean',
#   'multilinear',
#   'function',
#   'serie']]

# %% [markdown]
# ### List with every word

# %%
# create lists with every value without double lists

words_values = [word for sublist in filtered_all_words for word in sublist]

print(words_values)

authors_values = [author for sublist in all_authors for author in sublist]

categories_values = [category for sublist in all_categories for category in sublist]

title_values = [title for sublist in all_title_words for title in sublist]
# Out:
# ['fully', 'differential', 'calculation', 'perturbative', 'quantum', 'chromodynamic', 'present', 'production', 'massive', 'photon', 'pair', 'hadron', 'collider', 'next', 'lead', 'order', 'perturbative', 'contribution', 'quark', 'antiquark', 'gluon-(anti)quark', 'gluon', 'gluon', 'subprocesse', 'include', 'well', 'order', 'resummation', 'initial', 'state', 'gluon', 'radiation', 'valid', 'next', 'next', 'lead', 'logarithmic', 'accuracy', 'region', 'phase', 'space', 'specify', 'calculation', 'reliable', 'good', 'agreement', 'demonstrate', 'datum', 'Fermilab', 'Tevatron', 'prediction', 'make', 'detailed', 'test', 'CDF', 'datum', 'prediction', 'show', 'distribution', 'diphoton', 'pair', 'produce', 'energy', 'Large', 'Hadron', 'Collider', 'LHC', 'distribution', 'diphoton', 'pair', 'decay', 'Higgs', 'boson', 'contrast', 'produce', 'QCD', 'process', 'LHC', 'show', 'enhance', 'sensitivity', 'signal', 'obtain', 'judicious', 'selection', 'event', 'describe', 'new', 'algorithm', '$', 'k,\\ell)$-pebble', 'game', 'color', 'use', 'obtain', 'characterization', 'family', '$', 'k,\\ell)$-sparse', 'graph', 'algorithmic', 'solution', 'family', 'problem', 'concern', 'tree', 'decomposition', 'graph', 'special', 'instance', 'sparse', 'graph', 'appear', 'rigidity', 'theory', 'receive', 'increase', 'attention', 'recent', 'year', 'particular', 'colored', 'pebble', 'generalize', 'strengthen', 'previous', 'result', 'Lee', 'Streinu', 'give', 'new', 'proof', 'Tutte', 'Nash', 'Williams', 'characterization', 'arboricity', 'also', 'present', 'new', 'decomposition', 'certify', 'sparsity', 'base', '$', 'k,\\ell)$-pebble', 'game', 'color', 'work', 'also', 'expose', 'connection', 'pebble', 'game', 'algorithm', 'previous', 'sparse', 'graph', 'algorithm', 'Gabow', 'Gabow', 'Westermann', 'Hendrickson', 'evolution', 'Earth', 'Moon', 'system', 'describe', 'dark', 'matter', 'field', 'fluid', 'model', 'propose', 'Meeting', 'Division', 'Particle', 'Field', '2004', 'American', 'Physical', 'Society', 'current', 'behavior', 'Earth', 'Moon', 'system', 'agree', 'model', 'well', 'general', 'pattern', 'evolution', 'Moon', 'Earth', 'system', 'describe', 'model', 'agree', 'geological', 'fossil', 'evidence', 'close', 'distance', 'Moon', 'Earth', '259000', 'km', '4.5', 'billion', 'year', 'ago', 'far', 'beyond', 'Roche', "'s", 'limit', 'result', 'suggest', 'tidal', 'friction', 'may', 'primary', 'cause', 'evolution', 'Earth', 'Moon', 'system', 'average', 'dark', 'matter', 'field', 'fluid', 'constant', 'derive', 'Earth', 'Moon', 'system', 'datum', '4.39', 'x', '10^(-22', 's^(-1)m^(-1', 'model', 'predict', 'Mars', "'s", 'rotation', 'also', 'slow', 'angular', 'acceleration', 'rate', '-4.38', 'x', '10^(-22', 'rad', 's^(-2', 'show', 'determinant', 'Stirling', 'cycle', 'number', 'count', 'unlabeled', 'acyclic', 'single', 'source', 'automata', 'proof', 'involve', 'bijection', 'automata', 'certain', 'marked', 'lattice', 'path', 'sign', 'reverse', 'involution', 'evaluate', 'determinant', 'paper', 'show', 'compute', '$', '\\Lambda_{\\alpha}$', 'norm', '$', '\\alpha\\ge', '0', '$', 'use', 'dyadic', 'grid', 'result', 'consequence', 'description', 'Hardy', 'space', '$', 'h^p(r^n)$', 'term', 'dyadic', 'special', 'atom', 'study', 'two', 'particle', 'wave', 'function', 'pair', 'atom', 'Fermi', 'gas', 'tunable', 'interaction', 'strength', 'control', 'Feshbach', 'resonance', 'Cooper', 'pair', 'wave', 'function', 'examine', 'bosonic', 'character', 'quantify', 'correction', 'Bose', 'enhancement', 'factor', 'associate', 'creation', 'annihilation', 'composite', 'particle', 'operator', 'example', 'give', 'three', 'dimensional', 'uniform', 'gas', 'two', 'definition', 'cooper', 'pair', 'wave', 'function', 'examine', 'one', 'choose', 'reflect', 'diagonal', 'long', 'range', 'order', 'ODLRO', 'another', 'one', 'correspond', 'pair', 'projection', 'BCS', 'state', 'side', 'negative', 'scatter', 'length', 'find', 'pair', 'atom', 'describe', 'ODLRO', 'bosonic', 'pair', 'project', 'definition', 'also', 'find', '$', 'k ...

# %% [markdown]
# ### Delete duplicates

# %%
list(set(words_values))
# Out:
# ['feedback',
#  'arbitrary',
#  'disc',
#  'spinor',
#  'yet',
#  'Fermilab',
#  'internal',
#  'fm^2',
#  'know',
#  'property',
#  'Streinu',
#  'significant',
#  'characterize',
#  's^(-1)m^(-1',
#  'since',
#  'explore',
#  'Muskhelishvili',
#  'divisor',
#  'observation',
#  '50',
#  'interesting',
#  'apply',
#  'order',
#  'satisfy',
#  'approach',
#  'Ikeda',
#  'Bracket',
#  'gravity',
#  'Norton',
#  'cool',
#  'interpretation',
#  'r^2\\ra_s^\\pi=0.65\\pm',
#  '-4.38',
#  'obtain',
#  'continuation',
#  'relative',
#  'reveal',
#  'example',
#  'enhance',
#  'exhibit',
#  'Carlo',
#  'prime',
#  'static',
#  '1990',
#  'agree',
#  "r\\'ev\\'esz",
#  'new',
#  'Ramond',
#  'directly',
#  'differential',
#  'parallelize',
#  'stage',
#  'hot',
#  'analogue',
#  'critical',
#  'signature',
#  'future',
#  'marked',
#  'namely',
#  '~100',
#  'vary',
#  'm=1.05',
#  'activate',
#  'singularity',
#  'numerical',
#  '3',
#  'important',
#  'send',
#  'neutrino',
#  'e',
#  'stellar',
#  'source',
#  'collider',
#  'spectral',
#  'limitation',
#  'lastly',
#  '2001',
#  'reliable',
#  'interaction',
#  'quantity',
#  'Maass',
#  'historical',
#  'basis',
#  'replace',
#  'transform',
#  'account',
#  'detection',
#  'Sarantopoulos',
#  'asymptotic',
#  'Stirling',
#  'amplitude',
#  'non',
#  'pulsation',
#  'Ono',
#  'Castell',
#  'optical',
#  'contraction',
#  'unknown',
#  'algebra',
#  'J',
#  'make',
#  'common',
#  'isometric',
#  'contain',
#  '10^{-5}$.',
#  'itinerant',
#  '.001',
#  'Moon',
#  'version',
#  'three',
#  'set',
#  'BCS',
#  '1',
#  'appear',
#  'figure',
#  'subsequently',
#  'function',
#  'boson',
#  'rigidity',
#  'great',
#  'energy',
#  'conversion',
#  'electric',
#  'diffractively',
#  'standard',
#  'shift',
#  'arcsec',
#  'operation',
#  'employ',
#  'arrangement',
#  'particular',
#  'polarize',
#  'subject',
#  'graph',
#  'detailed',
#  'criterion',
#  'bound',
#  '5$.',
#  'definition',
#  'biological',
#  'constant',
#  'spectator',
#  '1991',
#  'matter',
#  'ensure',
#  '\\nu_e$',
#  'p\\geq5',
#  'character',
#  'scatterer',
#  'form',
#  'symmetric',
#  'infinite',
#  'magnetic',
#  'strange',
#  'ODLRO',
#  'element',
#  'bent',
#  'sphere',
#  'passive',
#  'concern',
#  'two',
#  'operator',
#  'divergence',
#  'incident',
#  'subprocesse',
#  'catalytic',
#  'unbiased',
#  'Siegel',
#  'history',
#  'ferrimagnetic',
#  'fb(-1',
#  'integrator',
#  'outer',
#  'tool',
#  'superstring',
#  'manifold',
#  '10^(-22',
#  'isentropic',
#  'involution',
#  'diagram',
#  'Meeting',
#  'origin',
#  "'s",
#  'Cayley',
#  'presence',
#  'compare',
#  'radius',
#  'later',
#  'Hilbert',
#  'term',
#  'generalize',
#  'current',
#  'scheme',
#  'pull',
#  'complexity',
#  'detector',
#  'aspect',
#  'a)^{-1',
#  'calculate',
#  'PEPII',
#  'Matsubara',
#  'dwarf',
#  'review',
#  'expectation',
#  'trace',
#  'consider',
#  'Hardy',
#  'narrow',
#  'superspace',
#  'concentration',
#  'weight',
#  'conditionally',
#  'loop',
#  'Polar',
#  'Physical',
#  'rotation',
#  'coherent',
#  'simulation',
#  'gas',
#  '40',
#  'pure',
#  'pattern',
#  'structure',
#  'line',
#  'possibly',
#  'diquark',
#  'k,\\ell)$-sparse',
#  'correction',
#  'many',
#  '100',
#  'accretion',
#  'lie',
#  'main',
#  'resolve',
#  'BABAR',
#  'loop-)space',
#  'emit',
#  'product',
#  'crossover',
#  'investigate',
#  'reverse',
#  'bio/0701050',
#  'hypercube',
#  'suppress',
#  'electron',
#  'Callias',
#  'edge',
#  'would',
#  'polarization',
#  'genus',
#  'diagonal',
#  'mode',
#  'young',
#  'Fourier',
#  'G',
#  'excited',
#  'whose',
#  'result',
#  'experimental',
#  'vertex',
#  'autonomous',
#  'loading',
#  'quality',
#  'approximate',
#  'molecular',
#  'originate',
#  'importance',
#  'width',
#  'tomogram',
#  'tree',
#  'quadratic',
#  'p',
#  'enzyme',
#  'modulation',
#  'develop',
#  '8',
#  'inter',
#  'intensive',
#  'limit',
#  'viewpoint',
#  'contact',
#  'author',
#  'start',
#  'similar',
#  'establish',
#  'sl_2(\\mathbb{z})$',
#  'Williams',
#  'c2d',
#  'Lieb',
#  'small',
#  'reaction',
#  'Newman',
#  'acyclic',
#  'isospin(I',
#  'arbitrarily',
#  'proof',
#  'large',
#  'however',
#  '2002',
#  'normalization',
#  '^n',
#  'plane',
#  'magnetosphere',
#  '0.8',
#  'lobe',
#  'Dipole',
#  'decomposition',
#  '160',
#  'x.',
#  'like',
#  'flavor',
#  'discuss',
#  'deg^2',
#  'understanding',
#  'ii',
#  'ten',
#  'perturb',
#  'pulse',
#  'available',
#  'pion',
#  'building',
#  'modulo',
#  'Rashba',
#  'rather',
#  'capture',
#  'lifting',
#  'region',
#  'point',
#  'factor',
#  'range',
#  'never',
#  'dimension',
#  'x',
#  'group',
#  'Menten',
#  's.',
#  'Space',
#  'Stochastic',
#  '=',
#  'mhz',
#  'd.',
#  'enough',
#  'resummation',
#  'still',
#  'Tutte',
#  'friction',
#  '2n-1',
#  'emerge',
#  'cyclic',
#  'K-',
#  'doubly',
#  'generate',
#  'adequate',
#  '-,1',
#  'f+(0)=0.727',
#  'supersymmetric',
#  'confirm',
#  'algorithm',
#  'probe',
#  'Eisentein',
#  'choose',
#  'propose',
#  'basic',
#  'general',
#  'show',
#  'thus',
#  '51',
#  'discretization',
#  'response',
#  'MIPS',
#  "Djokovi\\'{c",
#  'slow',
#  'bifurcation',
#  'due',
#  'instance',
#  'system',
#  'rad',
#  'ALMA',
#  'analytically',
#  'furthermore',
#  'unlabeled',
#  'meaningful',
#  'interface',
#  'independence',
#  'mean',
#  'signaling',
#  'quantum',
#  'lateral',
#  'bipartite',
#  'reach',
#  'arboricity',
#  'k_f',
#  'formation',
#  'ZDs',
#  'clean',
#  'real',
#  'Teller',
#  'demonstrate',
#  'sparsity',
#  'prediction',
#  'frohlich',
#  'geological',
#  'stand',
#  'practical',
#  'second',
#  'photon',
#  'gr\\"obner',
#  'Munthe',
#  'integration',
#  'compete',
#  'input',
#  'funnel',
#  'Dickson',
#  'prove',
#  'Computational',
#  'optimize',
#  'flexible',
#  'look',
#  'identify',
#  'goldstone',
#  'define',
#  'enable',
#  'follow',
#  'level',
#  'hybrid',
#  'velocity',
#  'n=2',
#  'deterministic',
#  'induce',
#  'Chen',
#  'Wynn',
#  'index',
#  'determinant',
#  'Class',
#  'h^p(r^n)$',
#  'Tevatron',
#  'vector',
#  'bima',
#  'break',
#  'clustering',
#  'tiny',
#  'program',
#  'strengthen',
#  'external',
#  'pi+',
#  'logarithmic',
#  '5',
#  'capability',
#  'symmetry',
#  'assumed',
#  'acceleration',
#  'collaboration',
#  'theorem',
#  'rival',
#  'put',
#  'family',
#  'burst',
#  'overflow',
#  'space',
#  'baryon',
#  'f(z',
#  'thereby',
#  'prescription',
#  'moreover',
#  'observable',
#  'evidence',
#  'Mott',
#  'uniform',
#  'pebble',
#  'slightly',
#  'fluid',
#  'hold',
#  'Discrete',
#  'CDF',
#  'case',
#  'decay',
#  'clarify',
#  'weakly',
#  'detectability',
#  'n=1,2,4$.',
#  'algorithmic',
#  'decrease',
#  'BR(D0',
#  'combine',
#  'occur',
#  'pair',
#  'depend',
#  'certain',
#  'article',
#  'especially',
#  'significantly',
#  'bosonic',
#  'string',
#  'year',
#  'lifetime',
#  'efficiency',
#  'fide',
#  'wave',
#  'spectrum',
#  'world',
#  'attention',
#  'suggest',
#  'solve',
#  'diphoton',
#  'adaptation',
#  'Doppler',
#  'processor',
#  'transmission',
#  'resonant',
#  'extrapolation',
#  'devise',
#  'enzymic',
#  'remarkably',
#  'circularly',
#  'measurement',
#  'reanalyze',
#  'rate',
#  '0.007',
#  'time-',
#  'simple',
#  'try',
#  'gluon-(anti)quark',
#  'meta',
#  'wide',
#  'theoretical',
#  'EX',
#  'modeling',
#  'Lsun',
#  'DDA',
#  'text',
#  'body',
#  'determined',
#  'mechanism',
#  'impact',
#  'among',
#  'scale',
#  'method',
#  'special',
#  'initial',
#  'evolve',
#  'k,\\ell)$-pebble',
#  'inability',
#  'simulate',
#  'matrix',
#  'examine',
#  'sn).we',
#  'condensate',
#  'norm',
#  '260',
#  'include',
#  'distortion',
#  'without',
#  'channel',
#  'long',
#  'Westermann',
#  'Cherenkov',
#  'structuring',
#  '\\gamma_{0}(4n)$',
#  'n+1',
#  'stripe',
#  'bring',
#  'expose',
#  'effective',
#  'bar',
#  'Stein',
#  'change',
#  'partial',
#  'spatiotemporal',
#  'phase',
#  '\\XQM$',
#  'release',
#  'dephosphorylation',
#  'underlie',
#  'underwater',
#  'get',
#  'comprehensive',
#  'lift',
#  '2',
#  'respectively',
#  'Proton',
#  'satellite',
#  '0',
#  'disk',
#  'positivity',
#  'receive',
#  'fundamental',
#  '12',
#  'massless',
#  'steeply',
#  'Wolfram',
#  'separate',
#  'call',
#  'position',
#  'quark',
#  '0.005',
#  'pasting',
#  'hadron',
#  'wall',
#  'measured',
#  'carry',
#  'iterated',
#  'precision',
#  'sometimes',
#  'record',
#  'simplified',
#  'effect',
#  'correlate',
#  'Intermediate',
#  'object',
#  'inner',
#  'Earth',
#  'distance',
#  'characterization',
#  'Serre',
#  'inequality',
#  'metal',
#  'deformation',
#  'American',
#  'Green',
#  '\\mathbb{Z}[[q]]$',
#  'central',
#  'harmonic',
#  'semi',
#  'Lehmann',
#  'Spitzer',
#  'a_f(n)q',
#  'relativistic',
#  'antiquark',
#  'cosmology',
#  'separation',
#  'underlying',
#  '0.07',
#  'technique',
#  '235',
#  'colored',
#  'Rankin',
#  'expansion',
#  'gain',
#  'different',
#  'either',
#  'use',
#  'color',
#  'indicate',
#  'tev',
#  'regime',
#  'accurate',
#  'pc',
#  'experiment',
#  'NSI',
#  'output',
#  'bijection',
#  'Bose',
#  'double',
#  'fraction',
#  'supplement',
#  'express',
#  '5.0',
#  'null',
#  'tidal',
#  'may',
#  'statistical',
#  'Sky',
#  'possibility',
#  'tunable',
#  'water',
#  'estimate',
#  'extraordinary',
#  'independent',
#  'least',
#  'sensitively',
#  '`',
#  'negative',
#  '2005',
#  'multisite',
#  'permanent',
#  'envelope',
#  'appropriate',
#  'interpret',
#  'application',
#  'state',
#  'r^2\\ra^\\pi_s=0.75\\pm',
#  'Serpens',
#  'Belle',
#  'hafnian',
#  'creation',
#  'within',
#  'correspond',
#  'stable',
#  'luminosity',
#  'canonical',
#  'population',
#  'Mie',
#  'period',
#  'well',
#  'spite',
#  'eigensystem',
#  'precise',
#  'signal',
#  'self',
#  'landau',
#  'accelerator',
#  'finite',
#  '~1000',
#  'bona',
#  'quiescence',
#  'represent',
#  'improve',
#  'formulate',
#  'physic',
#  'correspondence',
#  'illustrative',
#  'physics',
#  '\\Lambda_{\\alpha}$',
#  'high',
#  'acquire',
#  'oscillation',
#  '\\xi_{cc}^{++}$',
#  '\\q(\\sqrt{5})$.',
#  'crystal',
#  'RD',
#  'modulate',
#  'cosmological',
#  'empirically',
#  'low',
#  'commutative',
#  'representation',
#  'shock',
#  'distinctive',
#  'four',
#  'combined',
#  'LHC',
#  'Sun',
#  'conjecture',
#  'ensemble',
#  'atom',
#  'Lee',
#  '>',
#  'curtain',
#  'frequency',
#  'accuracy',
#  'hadronic',
#  'specify',
#  'class',
#  'give',
#  'radiation',
#  'transition',
#  'Hurwitz',
#  'passage',
#  'spatial',
#  '0.012',
#  'power',
#  'react',
#  '2MASS',
#  'photometry',
#  'zero',
#  'produce',
#  'behavior',
#  'dipole',
#  'l$-function',
#  'gluon',
#  'parameter',
#  'Hamiltonian',
#  'Raman',
#  'Feshbach',
#  'counterpart',
#  'temperature',
#  'finding',
#  'less',
#  'Cabibbo',
#  'allow',
#  'angular',
#  'downstream',
#  'modulus',
#  'white',
#  'oscillator',
#  'mm',
#  'dramatic',
#  'formulation',
#  'way',
#  'connection',
#  'cluster',
#  'q',
#  'al',
#  'length',
#  'project',
#  'lattice',
#  'notion',
#  'cell',
#  'annihilation',
#  'angle',
#  'fine',
#  'discrepancy',
#  'planck',
#  'Taylor',
#  'behaviour',
#  'applicability',
#  'quantify',
#  'commutation',
#  'along',
#  'peak',
#  'framework',
#  'Approximation',
#  'decompression',
#  'utilize',
#  'pseudo',
#  '30',
#  'primary',
#  'f+(q2',
#  'context',
#  'perform',
#  'contrast',
#  'QCD',
#  '1.5',
#  'Megaton',
#  'beyond',
#  'area',
#  'halpha',
#  'illustrate',
#  'describe',
#  'dependence',
#  'scatter',
#  'become',
#  'automata',
#  'adapt',
#  'computer',
#  'graphene',
#  'measure',
#  'packet',
#  'feature',
#  'composite',
#  'material',
#  'play',
#  'determine',
#  '0.85',
#  'Process',
#  'ability',
#  'turnover',
#  'Hecke',
#  'week',
#  'exponential',
#  'neutronization',
#  '0.04',
#  'free',
#  'refining',
#  'quasi',
#  'selection',
#  'Goldstone',
#  'et',
#  'S_{\\lambda+1/2}(\\Gamma_0(N),\\chi)\\cap',
#  'performance',
#  'projection',
#  'recently',
#  'generally',
#  'dynamic',
#  'continuity',
#  'Society',
#  'polaron',
#  '$',
#  'inclusion',
#  'singular',
#  'tune',
#  'lead',
#  'strongly',
#  'vehicle',
#  'fall',
#  'trap',
#  'ultrasensitivity',
#  'Carlsson',
#  'planar',
#  'determination',
#  'uncertainty',
#  'cooper',
#  'Bruinier',
#  'Division',
#  '259000',
#  'another',
#  'confidence',
#  'experimentally',
#  'rigid',
#  'ordinary',
#  'magnetization',
#  'number',
#  'sensitivity',
#  'back',
#  'tendency',
#  '2004',
#  'strength',
#  'Brillouin',
#  'monotonic',
#  'time',
#  'repeatedly',
#  'reasonable',
#  'emission',
#  'fossil',
#  'octahedral',
#  'detect',
#  'Cohen',
#  '\\sum_{n=0}^{\\infty',
#  'derive',
#  'numeric',
#  'latter',
#  'Fermi',
#  'lack',
#  'light',
#  'cartesian',
#  '3.5',
#  'Nash',
#  'provide',
#  'datum',
#  'cubically',
#  'quotient',
#  'analyze',
#  'equation',
#  'subgraph',
#  'cusp',
#  'T',
#  'manuscript',
#  'approximation',
#  'band',
#  'conditional',
#  'near',
#  'fill',
#  'far',
#  'increase',
#  'extra',
#  'motif',
#  'instability',
#  'agreement',
#  'atmosphere',
#  '0.927',
#  '\\in',
#  'base',
#  'regulator',
#  'dark',
#  'part',
#  '4',
#  'eigenform',
#  'uniformly',
#  'action',
#  'Borcherds',
#  'dipolar',
#  'noise',
#  'nue',
#  'supernova',
#  'observe',
#  'discrete',
#  '0.1',
#  'sector',
#  'think',
#  'r',
#  'hgamma',
#  '75',
#  'nonlinear',
#  'contamination',
#  'magnitude',
#  'Hya',
#  'next',
#  'highly',
#  'array',
#  'Winkler',
#  'potential',
#  'predict',
#  'bind',
#  'settle',
#  'forward',
#  'functional',
#  'km',
#  'individual',
#  'relation',
#  'Particle',
#  'ray',
#  'letter',
#  'unique',
#  'k',
#  'imaginary',
#  'massive',
#  'evaluate',
#  'closed',
#  'refractive',
#  'cascade',
#  'plastic',
#  'MAPK',
#  'classify',
#  'Hendrickson',
#  'strut',
#  'valid',
#  'quasi-2d',
#  'positive',
#  'subset',
#  'isolate',
#  'upper',
#  'polymer',
#  'judicious',
#  'holomorphic',
#  'impose',
#  'study',
#  'irac',
#  'good',
#  'intrinsic',
#  'conductivity',
#  ...]

# %%
# list with all words without duplicates

words_list = []
for i in range(len(words_values)):
    if words_values[i] not in words_list:
        words_list.append(words_values[i])

# list(set(words_values))

authors_list = []
for i in range(len(authors_values)):
    if words_values[i] not in authors_list:
        authors_list.append(words_values[i])

# list(set(words_values))

categories_list = []
for i in range(len(categories_values)):
    if words_values[i] not in categories_list:
        categories_list.append(words_values[i])

# list(set(words_values))

title_words_list = []
for i in range(len(title_values)):
    if title_values[i] not in title_words_list:
        title_words_list.append(title_values[i])

# list(set(words_values))

# %%
print(words_list)
print(title_words_list)
# Out:
# ['fully', 'differential', 'calculation', 'perturbative', 'quantum', 'chromodynamic', 'present', 'production', 'massive', 'photon', 'pair', 'hadron', 'collider', 'next', 'lead', 'order', 'contribution', 'quark', 'antiquark', 'gluon-(anti)quark', 'gluon', 'subprocesse', 'include', 'well', 'resummation', 'initial', 'state', 'radiation', 'valid', 'logarithmic', 'accuracy', 'region', 'phase', 'space', 'specify', 'reliable', 'good', 'agreement', 'demonstrate', 'datum', 'Fermilab', 'Tevatron', 'prediction', 'make', 'detailed', 'test', 'CDF', 'show', 'distribution', 'diphoton', 'produce', 'energy', 'Large', 'Hadron', 'Collider', 'LHC', 'decay', 'Higgs', 'boson', 'contrast', 'QCD', 'process', 'enhance', 'sensitivity', 'signal', 'obtain', 'judicious', 'selection', 'event', 'describe', 'new', 'algorithm', '$', 'k,\\ell)$-pebble', 'game', 'color', 'use', 'characterization', 'family', 'k,\\ell)$-sparse', 'graph', 'algorithmic', 'solution', 'problem', 'concern', 'tree', 'decomposition', 'special', 'instance', 'sparse', 'appear', 'rigidity', 'theory', 'receive', 'increase', 'attention', 'recent', 'year', 'particular', 'colored', 'pebble', 'generalize', 'strengthen', 'previous', 'result', 'Lee', 'Streinu', 'give', 'proof', 'Tutte', 'Nash', 'Williams', 'arboricity', 'also', 'certify', 'sparsity', 'base', 'work', 'expose', 'connection', 'Gabow', 'Westermann', 'Hendrickson', 'evolution', 'Earth', 'Moon', 'system', 'dark', 'matter', 'field', 'fluid', 'model', 'propose', 'Meeting', 'Division', 'Particle', 'Field', '2004', 'American', 'Physical', 'Society', 'current', 'behavior', 'agree', 'general', 'pattern', 'geological', 'fossil', 'evidence', 'close', 'distance', '259000', 'km', '4.5', 'billion', 'ago', 'far', 'beyond', 'Roche', "'s", 'limit', 'suggest', 'tidal', 'friction', 'may', 'primary', 'cause', 'average', 'constant', 'derive', '4.39', 'x', '10^(-22', 's^(-1)m^(-1', 'predict', 'Mars', 'rotation', 'slow', 'angular', 'acceleration', 'rate', '-4.38', 'rad', 's^(-2', 'determinant', 'Stirling', 'cycle', 'number', 'count', 'unlabeled', 'acyclic', 'single', 'source', 'automata', 'involve', 'bijection', 'certain', 'marked', 'lattice', 'path', 'sign', 'reverse', 'involution', 'evaluate', 'paper', 'compute', '\\Lambda_{\\alpha}$', 'norm', '\\alpha\\ge', '0', 'dyadic', 'grid', 'consequence', 'description', 'Hardy', 'h^p(r^n)$', 'term', 'atom', 'study', 'two', 'particle', 'wave', 'function', 'Fermi', 'gas', 'tunable', 'interaction', 'strength', 'control', 'Feshbach', 'resonance', 'Cooper', 'examine', 'bosonic', 'character', 'quantify', 'correction', 'Bose', 'enhancement', 'factor', 'associate', 'creation', 'annihilation', 'composite', 'operator', 'example', 'three', 'dimensional', 'uniform', 'definition', 'cooper', 'one', 'choose', 'reflect', 'diagonal', 'long', 'range', 'ODLRO', 'another', 'correspond', 'projection', 'BCS', 'side', 'negative', 'scatter', 'length', 'find', 'project', 'k_f', 'a)^{-1', '\\ge', '1', 'similar', '90', 'occupy', 'molecular', 'condensate', 'rather', 'non', 'standard', 'representation', 'canonical', 'commutation', 'relation', 'mechanic', 'know', 'polymer', 'gain', 'due', 'possible', 'planck', 'scale', 'physic', 'approach', 'follow', 'symmetric', 'sector', 'loop', 'gravity', 'cosmology', 'explore', 'different', 'aspect', 'ordinary', 'Schroedinger', 'part', 'first', 'start', 'arise', 'appropriate', 'second', 'consider', 'continuum', 'namely', 'discrete', 'try', 'recover', 'back', 'several', 'interest', 'harmonic', 'oscillator', 'free', 'simple', 'cosmological', 'formulation', 'develop', 'represent', 'material', 'application', 'dynamic', 'loading', 'numerical', 'method', 'devise', 'calculate', 'response', 'shock', 'ramp', 'compression', 'decompression', 'scalar', 'equation', 'flexible', 'robust', 'match', 'analytic', 'high', 'basic', 'couple', 'solve', 'deformation', 'induce', 'impact', 'planar', 'interface', 'capture', 'much', 'physics', 'typical', 'experiment', 'without', 'require', 'spatially', 'resolve', 'simulation', 'histo ...
# ['calculation', 'of', 'prompt', 'diphoton', 'production', 'cross', 'section', 'at', 'Tevatron', 'and', 'LHC', 'energy', 'sparsity', 'certify', 'Graph', 'Decompositions', 'the', 'evolution', 'Earth', 'Moon', 'system', 'base', 'on', 'dark', 'matter', 'field', 'fluid', 'model', 'a', 'determinant', 'stirling', 'cycle', 'number', 'count', 'unlabeled', 'acyclic', 'single', 'source', 'automata', 'from', 'dyadic', '$', '\\Lambda_{\\alpha}$', 'to', 'bosonic', 'character', 'atomic', 'Cooper', 'pair', 'across', 'resonance', 'polymer', 'Quantum', 'Mechanics', 'its', 'Continuum', 'Limit', 'numerical', 'solution', 'shock', 'ramp', 'compression', 'for', 'general', 'material', 'property', 'Spitzer', 'c2d', 'Survey', 'large', 'nearby', 'Insterstellar', 'Clouds', 'IX', 'Serpens', 'YSO', 'Population', 'as', 'Observed', 'with', 'irac', 'MIPS', 'partial', 'cube', 'structure', 'characterization', 'construction', 'computing', 'genu', '2', 'Hilbert', 'Siegel', 'modular', 'form', 'over', '\\q(\\sqrt{5})$', 'via', 'Jacquet', 'Langlands', 'correspondence', 'distribution', 'integral', 'Fourier', 'Coefficients', 'Modular', 'Half', 'Integral', 'Weight', 'Modulo', 'prime', 'p$-adic', 'Weakly', 'Holomorphic', 'Forms', 'weight', 'iterate', 'loop', 'product', 'fermionic', 'superstre', 'amplitude', 'in', 'pure', 'spinor', 'formalism', 'lifetime', 'doubly', 'charm', 'baryon', 'Spectroscopic', 'Observations', 'Intermediate', 'Polar', 'EX', 'Hydrae', 'Quiescence', 'quest', 'generalized', 'Callias', 'index', 'theorem', 'approximation', 'extinction', 'probability', 'contact', 'process', 'gr\\"obner', 'basis', 'Measurement', 'Hadronic', 'Form', 'Factor', 'D0', '>', 'K-', 'e+', 'nue', 'decay', 'molecular', 'Synchronization', 'Waves', 'Arrays', 'allosterically', 'regulate', 'enzyme', 'stochastic', 'lie', 'group', 'integrator', 'alma', 'ideal', 'probe', 'solar', 'chromosphere', 'formation', 'quasi', 'soliton', 'transverse', 'confine', 'ferromagnetic', 'film', 'medium', 'Properties', 'Polarons', 'strongly', 'Correlated', 'Systems', 'by', 'Exact', 'Diagrammatic', 'Monte', 'Carlo', 'Method', 'Placeholder', 'Substructures', 'II', 'Meta', 'Fractals', 'make', 'Box', 'Kites', 'Fill', 'Infinite', 'Dimensional', 'Skies', 'Filling', 'Dependent', 'Magnetophonon', 'Resonance', 'Graphene', 'Pfaffians', 'hafnian', 'real', 'linear', 'functional', 'understand', 'Flavor', 'Symmetry', 'Breaking', 'Nucleon', 'Spin', 'Structure', 'within', 'Chiral', 'Quark', 'Model', 'tune', 'correlation', 'effect', 'electron', 'phonon', 'interaction', 'crystal', 'channeling', 'forward', 'proton', 'preserve', 'phase', 'space', 'non', 'standard', 'neutrino', 'supernova', 'convergence', 'discrete', 'dipole', 'I.', 'theoretical', 'analysis', 'Origin', 'adaptive', 'mutant', 'quantum', 'measurement', 'ii', 'an', 'extrapolation', 'technique', 'increase', 'accuracy', 'remark', 'steady', 'state', 'multiple', 'futile', 'simulation', 'light', 'scatter', 'particle', 'much', 'than', 'wavelength', 'overview', 'recent', 'development', 'scalar', 'radius', 'pion', 'zero', 'factor', 'multilinear', 'function', 'series', 'conditionally', 'free', 'amalgamation']

# %% [markdown]
# ### Liste mit allen Attributen erstellen

# %%
def licenses_in_list(df):
    licenses_list = df['license'].tolist()
    print(licenses_list)

def doi_in_list(df):
    doi_list = df['doi'].tolist()
    print(doi_list)

def titles_in_list(df):
    title_list = df['title'].tolist()
    print(title_list)

# comment_list = []
# def comments_in_list(df):
#     for i in range(len(df)):
#         comment_list.append(df.comments[i])
#     print(comment_list)
    
def pages_in_list(df):
    pages_list = df['pages'].tolist()
    print(pages_list)

def journals_in_list(df):
    journal_list = df['journal-ref'].tolist()
    print(journal_list)

# %%
licenses_in_list(df_short)
doi_in_list(df_short)
titles_in_list(df_short)
pages_in_list(df_short)
# authors_in_list(df_short)
# categories_in_list(df_short)
journals_in_list(df_short)
# Out:
# [nan, 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/', nan, nan, nan, nan, nan, 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/', nan, nan, 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/', nan, nan, nan, nan, nan, 'http://creativecommons.org/licenses/by-nc-nd/4.0/', nan, nan, nan, nan, 'http://creativecommons.org/licenses/by-nc-nd/4.0/', nan, 'http://arxiv.org/licenses/nonexclusive-distrib/1.0/']
# ['10.1103/PhysRevD.76.013009', nan, nan, nan, nan, '10.1103/PhysRevA.75.043613', '10.1103/PhysRevD.76.044016', '10.1063/1.2975338', '10.1086/518646', nan, nan, nan, nan, nan, '10.1088/1126-6708/2007/05/034', '10.1088/0253-6102/49/4/38', '10.1111/j.1365-2966.2007.11762.x', nan, nan, '10.1103/PhysRevD.76.052005', '10.1103/PhysRevLett.99.048301', nan, '10.1007/s10509-007-9626-1', nan, '10.1007/978-1-4020-6348-0_12', nan, '10.1103/PhysRevLett.99.087402', nan, '10.1103/PhysRevD.75.094018', '10.1007/s10909-005-6013-6', '10.1016/j.physletb.2007.10.051', '10.1103/PhysRevD.76.053001', '10.1364/JOSAA.23.002578 10.1364/JOSAA.32.002407', nan, '10.1364/JOSAA.23.002592', nan, '10.1016/j.jqsrt.2007.01.033', '10.1016/j.jqsrt.2007.01.034 10.1016/j.jqsrt.2015.11.025', '10.1016/j.physletb.2007.06.023', nan]
# ['Calculation of prompt diphoton production cross sections at Tevatron and\r\n  LHC energies', 'Sparsity-certifying Graph Decompositions', 'The evolution of the Earth-Moon system based on the dark matter field\r\n  fluid model', 'A determinant of Stirling cycle numbers counts unlabeled acyclic\r\n  single-source automata', 'From dyadic $\\Lambda_{\\alpha}$ to $\\Lambda_{\\alpha}$', 'Bosonic characters of atomic Cooper pairs across resonance', 'Polymer Quantum Mechanics and its Continuum Limit', 'Numerical solution of shock and ramp compression for general material\r\n  properties', 'The Spitzer c2d Survey of Large, Nearby, Insterstellar Clouds. IX. The\r\n  Serpens YSO Population As Observed With IRAC and MIPS', 'Partial cubes: structures, characterizations, and constructions', 'Computing genus 2 Hilbert-Siegel modular forms over $\\Q(\\sqrt{5})$ via\r\n  the Jacquet-Langlands correspondence', 'Distribution of integral Fourier Coefficients of a Modular Form of Half\r\n  Integral Weight Modulo Primes', '$p$-adic Limit of Weakly Holomorphic Modular Forms of Half Integral\r\n  Weight', 'Iterated integral and the loop product', 'Fermionic superstring loop amplitudes in the pure spinor formalism', 'Lifetime of doubly charmed baryons', 'Spectroscopic Observations of the Intermediate Polar EX Hydrae in\r\n  Quiescence', 'In quest of a generalized Callias index theorem', 'Approximation for extinction probability of the contact process based on\r\n  the Gr\\"obner basis', 'Measurement of the Hadronic Form Factor in D0 --> K- e+ nue Decays', 'Molecular Synchronization Waves in Arrays of Allosterically Regulated\r\n  Enzymes', 'Stochastic Lie group integrators', 'ALMA as the ideal probe of the solar chromosphere', 'Formation of quasi-solitons in transverse confined ferromagnetic film\r\n  media', 'Spectroscopic Properties of Polarons in Strongly Correlated Systems by\r\n  Exact Diagrammatic Monte Carlo Method', 'Placeholder Substructures II: Meta-Fractals, Made of Box-Kites, Fill\r\n  Infinite-Dimensional Skies', 'Filling-Factor-Dependent Magnetophonon Resonance in Graphene', 'Pfaffians, hafnians and products of real linear functionals', 'Understanding the Flavor Symmetry Breaking and Nucleon Flavor-Spin\r\n  Structure within Chiral Quark Model', 'Tuning correlation effects with electron-phonon interactions', 'Crystal channeling of LHC forward protons with preserved distribution in\r\n  phase space', 'Probing non-standard neutrino interactions with supernova neutrinos', 'Convergence of the discrete dipole approximation. I. Theoretical\r\n  analysis', 'Origin of adaptive mutants: a quantum measurement?', 'Convergence of the discrete dipole approximation. II. An extrapolation\r\n  technique to increase the accuracy', 'A remark on the number of steady states in a multiple futile cycle', 'The discrete dipole approximation for simulation of light scattering by\r\n  particles much larger than the wavelength', 'The discrete dipole approximation: an overview and recent developments', 'Scalar radius of the pion and zeros in the form factor', 'Multilinear function series in conditionally free probability with\r\n  amalgamation']
# [37.0, nan, 23.0, 11.0, nan, 6.0, 16.0, nan, nan, 36.0, 14.0, nan, nan, 18.0, 22.0, 17.0, 10.0, 20.0, 6.0, 21.0, 5.0, 20.0, 4.0, nan, 41.0, nan, 4.0, 10.0, nan, 13.0, 11.0, 21.0, 23.0, 5.0, 17.0, 20.0, 13.0, 36.0, 18.0, nan]
# ['Phys.Rev.D76:013009,2007', nan, nan, nan, 'Illinois J. Math. 52 (2008) no.2, 681-689', nan, 'Phys.Rev.D76:044016,2007', 'Journal of Applied Physics, vol 104, 073536 (2008)', 'Astrophys.J.663:1149-1173,2007', nan, nan, nan, nan, nan, 'JHEP 0705:034,2007', 'Commun.Theor.Phys.49:993-1000,2008', 'Mon.Not.Roy.Astron.Soc.378:211-220,2007', nan, 'RIMS Kokyuroku, No.1551, pp.57-62 (2007)', 'Phys.Rev.D76:052005,2007', 'Phys. Rev. Lett. 99, 048301 (2007)', nan, 'Astrophys.Space Sci.313:197-200,2008', nan, nan, nan, 'Phys. Rev. Lett. 99, 087402 (2007)', 'Math. Res. Lett. 15 (2008), no. 2, 351--358', 'Phys.Rev.D75:094018,2007', 'J. Low. Temp. Phys. Vol. 140 pp77-89 (2005)', 'Phys.Lett.B658:7-12,2007', 'Phys.Rev.D76:053001,2007', 'J.Opt.Soc.Am.A 23, 2578-2591 (2006); Erratum: J.Opt.Soc.Am.A 32,\r\n  2407-2408 (2015)', nan, 'J.Opt.Soc.Am.A 23(10): 2592-2601 (2006)', nan, 'J.Quant.Spectrosc.Radiat.Transf. 106, 546-557 (2007)', 'J.Quant.Spectrosc.Radiat.Transf. 106, 558-589 (2007); Erratum:\r\n  J.Quant.Spectrosc.Radiat.Transf. 171, 82-83 (2016)', 'Phys.Lett.B651:139-146,2007', nan]

# %% [markdown]
# ## Words to numbers

# %%
# Erstellen eines Mappings von Wort zu Index
word_to_index = {word: idx for idx, word in enumerate(set(list_of_words))}

# Konvertieren der Wörter in Indizes
words_as_numbers = [word_to_index[word] for word in list_of_words]

# Konvertieren in einen PyTorch Tensor
words_tensor = torch.tensor(words_as_numbers, dtype=torch.long)

# Weise die Edge-Indizes dem HeteroData-Objekt zu
data['paper', 'written_by', 'author'].edge_index = words_tensor

# %%
data['paper', 'written_by', 'author'].edge_index
# Out:
# tensor([ 267,  154, 1010,  ...,  851,  372, 1038])

# %%
# # words to numbers

# author_to_index_written_by = {author: idx for idx, author in enumerate(set(list_of_authors))}
# edge_index_list_written_by = [
#     [author_to_index_written_by[author] for author in list_of_authors]
# ]

# # Konvertiere die Liste in torch.Tensor-Objekte
# edge_index_tensor_written_by = torch.tensor(edge_index_list_written_by, dtype=torch.long)

# # Weise die Edge-Indizes dem HeteroData-Objekt zu
# data['paper', 'written_by', 'author'].edge_index = edge_index_tensor_written_by

# %%
# # Kategorien in Nummern umwandeln
# category_to_index_has_category = {category: idx for idx, category in enumerate(set(list_of_categories))}
# edge_index_list_has_category = [
#     [category_to_index_has_category[category] for category in list_of_categories]
# ]

# # Konvertiere die Liste in torch.Tensor-Objekte
# edge_index_tensor_has_category = torch.tensor(edge_index_list_has_category, dtype=torch.long)

# # Weise die Edge-Indizes dem HeteroData-Objekt zu
# data['paper', 'has_category', 'category'].edge_index = edge_index_tensor_has_category

# %%
# edge_index_tensor_has_category

# %%
# # Journalnamen in Nummern umwandeln
# journal_to_index_in_journal = {journal: idx for idx, journal in enumerate(set(list_of_journals))}
# edge_index_list_in_journal = [
#     [journal_to_index_in_journal[journal] for journal in list_of_journals]
# ]

# # Konvertiere die Liste in torch.Tensor-Objekte
# edge_index_tensor_in_journal = torch.tensor(edge_index_list_in_journal, dtype=torch.long)

# # Weise die Edge-Indizes dem HeteroData-Objekt zu
# data['paper', 'in_journal', 'journal-ref'].edge_index = edge_index_tensor_in_journal

# %%
# # Wörter in Nummern umwandeln
# word_to_index_has_word = {word: idx for idx, word in enumerate(set(list_of_words))}
# edge_index_list_has_word = [
#     [word_to_index_has_word[word] for word in list_of_words]
# ]

# # Konvertiere die Liste in torch.Tensor-Objekte
# edge_index_tensor_has_word = torch.tensor(edge_index_list_has_word, dtype=torch.long)

# # Weise die Edge-Indizes dem HeteroData-Objekt zu
# data['paper', 'has_word', 'word'].edge_index = edge_index_tensor_has_word

# %%
# # word in number
# word_to_index = {word: idx for idx, word in enumerate(set(word for sublist in edge_index_list_has_titleword for word in sublist))}


# # Erstelle die Edge-Index-Listen mit den gemappten Zahlen
# edge_index_list_has_titleword = [
#     [word_to_index[word] for word in sublist] for sublist in edge_index_list_has_titleword
# ]

# # Konvertiere die Listen in torch.Tensor-Objekte
# edge_index_tensor_has_titleword = torch.tensor(edge_index_list_has_titleword, dtype=torch.long)

# # Weise die Edge-Indizes dem HeteroData-Objekt zu
# data['paper', 'has_titleword', 'word'].edge_index = edge_index_tensor_has_titleword

# %%
# data['paper', 'has_titleword', 'word'].edge_index

# %% [markdown]
# ## Create Hetero Object

# %%
data = HeteroData()
data['paper'].num_nodes = len(df_short)
data['paper'].license = licenses_list
data['paper'].doi = doi_list
data['paper'].title = title_list
data['paper'].pages = pages_list

data['author'].num_nodes = len(authors_list)
data['author'].name = authors_list

data['category'].num_nodes = len(categories_list)
data['category'].name = categories_list

data['journal'].num_nodes = len(df_short)
data['journal'].name = journal_list

data['word'].num_nodes = len(words_list)
data['word'].name = words_list

data
# Out:
# HeteroData(
#   paper={
#     num_nodes=40,
#     license=[0],
#     doi=[0],
#     title=[0],
#     pages=[40],
#   },
#   author={
#     num_nodes=73,
#     name=[73],
#   },
#   category={
#     num_nodes=49,
#     name=[49],
#   },
#   journal={
#     num_nodes=40,
#     name=[0],
#   },
#   word={
#     num_nodes=1316,
#     name=[1316],
#   }
# )

# %% [markdown]
# ### Create edges

# %%
edge_index_list_written_by = []
list_of_authors = []
list_of_titles = []

# Iteriere durch die Zeilen des DataFrames
for i in range(len(df_short)):
    # Holen der ID des Papers aus der aktuellen Zeile
    paper_title = df_short['title'][i]
    
    # Holen der Autoreninformationen aus der aktuellen Zeile
    authors_parsed = df_short['authors_parsed'][i]
    
    for j in authors_parsed:
        list_of_authors.append(j)
        list_of_titles.append(paper_title)

edge_index_list_written_by.append(list_of_titles)
edge_index_list_written_by.append(list_of_authors)


# Konvertiere die Liste in ein torch.Tensor-Objekt
# edge_index_tensor = torch.tensor(edge_index_list, dtype=torch.long).t()

# Weise die Edge-Indizes dem HeteroData-Objekt zu
data['paper', 'written_by', 'author'].edge_index = edge_index_list_written_by

# %%
edge_index_list_has_category = []
list_of_paper_cat = []
list_of_categories = []

# Iteriere durch die Zeilen des DataFrames
for i in range(len(df_short)):
    # Holen der ID des Papers aus der aktuellen Zeile
    paper_title = df_short['title'][i]
    
    # Holen der Kategorieninformationen aus der aktuellen Zeile
    categories = df_short['categories'][i]
    
    # Hier gehe ich davon aus, dass die Kategorien als Liste vorliegen
    for category in categories:
        list_of_categories.append(category)
        list_of_paper_cat.append(paper_title)

edge_index_list_has_category.append(list_of_paper_cat)
edge_index_list_has_category.append(list_of_categories)

# Weise die Edge-Indizes dem HeteroData-Objekt zu
data['paper', 'has_category', 'category'].edge_index = edge_index_list_has_category

# %%
edge_index_list_has_titleword = []
list_of_paper_titleword = []
list_of_titlewords = []

# Iteriere durch die Zeilen des DataFrames
for i in range(len(df_short)):
    # Holen der ID des Papers aus der aktuellen Zeile
    paper_title = df_short['title'][i]
    
    # Holen der Wortinformationen aus der aktuellen Zeile (hier nehmen wir die Titelwörter)
    title_words = all_title_words[i]
    
    # Hier gehe ich davon aus, dass die Titelwörter als Liste vorliegen
    for title_word in title_words:
        list_of_titlewords.append(title_word)
        list_of_paper_titleword.append(paper_title)

edge_index_list_has_titleword.append(list_of_paper_titleword)
edge_index_list_has_titleword.append(list_of_titlewords)

# Weise die Edge-Indizes dem HeteroData-Objekt zu
data['paper', 'has_titleword', 'word'].edge_index = edge_index_list_has_titleword

# %%
edge_index_list_in_journal = []
list_of_paper_journal = []
list_of_journals = []

# Iteriere durch die Zeilen des DataFrames
for i in range(len(df_short)):
    # Holen der ID des Papers aus der aktuellen Zeile
    paper_title = df_short['title'][i]
    
    # Holen des Journalnamens aus der aktuellen Zeile
    journal = df_short['journal-ref'][i]
    
    # Überprüfe, ob der Journal-Eintrag NaN ist
    if pd.notna(journal):
        list_of_journals.append(journal)
        list_of_paper_journal.append(paper_title)

# Füge nur gültige Einträge hinzu
edge_index_list_in_journal.append(list_of_paper_journal)
edge_index_list_in_journal.append(list_of_journals)

# Weise die Edge-Indizes dem HeteroData-Objekt zu
data['paper', 'in_journal', 'journal-ref'].edge_index = edge_index_list_in_journal

# %%
edge_index_list_in_journal
# Out:
# [['Calculation of prompt diphoton production cross sections at Tevatron and\r\n  LHC energies',
#   'From dyadic $\\Lambda_{\\alpha}$ to $\\Lambda_{\\alpha}$',
#   'Polymer Quantum Mechanics and its Continuum Limit',
#   'Numerical solution of shock and ramp compression for general material\r\n  properties',
#   'The Spitzer c2d Survey of Large, Nearby, Insterstellar Clouds. IX. The\r\n  Serpens YSO Population As Observed With IRAC and MIPS',
#   'Fermionic superstring loop amplitudes in the pure spinor formalism',
#   'Lifetime of doubly charmed baryons',
#   'Spectroscopic Observations of the Intermediate Polar EX Hydrae in\r\n  Quiescence',
#   'Approximation for extinction probability of the contact process based on\r\n  the Gr\\"obner basis',
#   'Measurement of the Hadronic Form Factor in D0 --> K- e+ nue Decays',
#   'Molecular Synchronization Waves in Arrays of Allosterically Regulated\r\n  Enzymes',
#   'ALMA as the ideal probe of the solar chromosphere',
#   'Filling-Factor-Dependent Magnetophonon Resonance in Graphene',
#   'Pfaffians, hafnians and products of real linear functionals',
#   'Understanding the Flavor Symmetry Breaking and Nucleon Flavor-Spin\r\n  Structure within Chiral Quark Model',
#   'Tuning correlation effects with electron-phonon interactions',
#   'Crystal channeling of LHC forward protons with preserved distribution in\r\n  phase space',
#   'Probing non-standard neutrino interactions with supernova neutrinos',
#   'Convergence of the discrete dipole approximation. I. Theoretical\r\n  analysis',
#   'Convergence of the discrete dipole approximation. II. An extrapolation\r\n  technique to increase the accuracy',
#   'The discrete dipole approximation for simulation of light scattering by\r\n  particles much larger than the wavelength',
#   'The discrete dipole approximation: an overview and recent developments',
#   'Scalar radius of the pion and zeros in the form factor'],
#  ['Phys.Rev.D76:013009,2007',
#   'Illinois J. Math. 52 (2008) no.2, 681-689',
#   'Phys.Rev.D76:044016,2007',
#   'Journal of Applied Physics, vol 104, 073536 (2008)',
#   'Astrophys.J.663:1149-1173,2007',
#   'JHEP 0705:034,2007',
#   'Commun.Theor.Phys.49:993-1000,2008',
#   'Mon.Not.Roy.Astron.Soc.378:211-220,2007',
#   'RIMS Kokyuroku, No.1551, pp.57-62 (2007)',
#   'Phys.Rev.D76:052005,2007',
#   'Phys. Rev. Lett. 99, 048301 (2007)',
#   'Astrophys.Space Sci.313:197-200,2008',
#   'Phys. Rev. Lett. 99, 087402 (2007)',
#   'Math. Res. Lett. 15 (2008), no. 2, 351--358',
#   'Phys.Rev.D75:094018,2007',
#   'J. Low. Temp. Phys. Vol. 140 pp77-89 (2005)',
#   'Phys.Lett.B658:7-12,2007',
#   'Phys.Rev.D76:053001,2007',
#   'J.Opt.Soc.Am.A 23, 2578-2591 (2006); Erratum: J.Opt.Soc.Am.A 32,\r\n  2407-2408 (2015)',
#   'J.Opt.Soc.Am.A 23(10): 2592-2601 (2006)',
#   'J.Quant.Spectrosc.Radiat.Transf. 106, 546-557 (2007)',
#   'J.Quant.Spectrosc.Radiat.Transf. 106, 558-589 (2007); Erratum:\r\n  J.Quant.Spectrosc.Radiat.Transf. 171, 82-83 (2016)',
#   'Phys.Lett.B651:139-146,2007']]

# %% [markdown]
# ### Assign weights

# %% [markdown]
# #### tf-idf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
import math

# TF-IDF Vektorizer
vectorizer = TfidfVectorizer()
corpus = [" ".join(words) for words in filtered_all_words]
tfidf_matrix = vectorizer.fit_transform(corpus)

feature_names = vectorizer.get_feature_names_out()

edge_index_list_has_word = []
list_of_paper_word = []
list_of_words = []
tfidf_weights = []

for i in range(len(df_short)):
    paper_title = df_short['title'][i]
    words = filtered_all_words[i]

    for word in words:
        if word in feature_names:  # Prüfen, ob das Wort im Vektorizer vorhanden ist, Bindewörter nicht mehr drinnen
            word_index = feature_names.tolist().index(word)
            print(word)
            print(word_index)
            tfidf_weight = tfidf_matrix[i, word_index]
            print(tfidf_weight)
            list_of_paper_word.append(paper_title)
            list_of_words.append(word)
            tfidf_weights.append(tfidf_weight)


# Zuweisung der Kanten und Gewichte
edge_index_list_has_word.append(list_of_words)
data['paper', 'has_word', 'word'].edge_index = edge_index_list_has_word
data['paper', 'has_word', 'word'].edge_attr = torch.tensor(tfidf_weights, dtype=torch.float)
# Out:
# fully
# 498
# 0.09431177509587857
# differential
# 344
# 0.07805181679480348
# calculation
# 171
# 0.14563455879198087
# perturbative
# 845
# 0.18862355019175714
# quantum
# 929
# 0.08480030922645997
# chromodynamic
# 206
# 0.09431177509587857
# present
# 889
# 0.05040273788433744
# production
# 901
# 0.09431177509587857
# massive
# 703
# 0.09431177509587857
# photon
# 851
# 0.09431177509587857
# pair
# 820
# 0.2544009276793799
# hadron
# 537
# 0.16960061845291993
# collider
# 223
# 0.15610363358960697
# next
# 766
# 0.28293532528763576
# lead
# 655
# 0.15610363358960697
# order
# 807
# 0.14563455879198087
# perturbative
# 845
# 0.18862355019175714
# contribution
# 272
# 0.07805181679480348
# quark
# 930
# 0.15610363358960697
# antiquark
# 91
# 0.09431177509587857
# gluon
# 525
# 0.3772471003835143
# gluon
# 525
# 0.3772471003835143
# subprocesse
# 1122
# 0.09431177509587857
# include
# 584
# 0.06854035092538487
# well
# 1223
# 0.07805181679480348
# order
# 807
# 0.14563455879198087
# resummation
# 990
# 0.09431177509587857
# initial
# 598
# 0.08480030922645997
# state
# 1097
# 0.06179185849372839
# gluon
# 525
# 0.3772471003835143
# radiation
# 939
# 0.09431177509587857
# valid
# 1201
# 0.09431177509587857
# next
# 766
# 0.28293532528763576
# next
# 766
# 0.28293532528763576
# lead
# 655
# 0.15610363358960697
# logarithmic
# 678
# 0.09431177509587857
# accuracy
# 52
# 0.07281727939599043
# region
# 967
# 0.07805181679480348
# phase
# 847
# 0.07805181679480348
# space
# 1073
# 0.06492425942797911
# specify
# 1080
# 0.09431177509587857
# calculation
# 171
# 0.14563455879198087
# reliable
# 973
# 0.08480030922645997
# good
# 527
# 0.09431177509587857
# agreement
# 67
# 0.07805181679480348
# demonstrate
# 319
# 0.07281727939599043
# datum
# 306
# 0.14563455879198087
# prediction
# 886
# 0.15610363358960697
# make
# 693
# 0.07805181679480348
# detailed
# 326
# 0.09431177509587857
# test
# 1149
# 0.08480030922645997
# datum
# 306
# 0.14563455879198087
# prediction
# 886
# 0.15610363358960697
# show
# 1040
# 0.0910638003853066
# distribution
# 364
# 0.15610363358960697
# diphoton
# 348
# 0.18862355019175714
# pair
# 820
# 0.2544009276793799
# produce
# 899
# 0.15610363358960697
# energy
# 400
# 0.07805181679480348
# distribution
# 364
# 0.15610363358960697
# diphoton
# 348
# 0.18862355019175714
# pair
# 820
# 0.2544009276793799
# decay
# 309
# 0.08480030922645997
# boson
# 154
# 0.08480030922645997
# contrast
# 271
# 0.09431177509587857
# produce
# 899
# 0.15610363358960697
# process
# 897
# 0.05655732109491533
# show
# 1040
# 0.0910638003853066
# enhance
# 401
# 0.09431177509587857
# sensitivity
# 1026
# 0.09431177509587857
# signal
# 1044
# 0.09431177509587857
# obtain
# 790
# 0.05655732109491533
# judicious
# 634
# 0.09431177509587857
# selection
# 1018
# 0.09431177509587857
# event
# 421
# 0.09431177509587857
# describe
# 324
# 0.06259417895662031
# new
# 764
# 0.19824147534554196
# algorithm
# 71
# 0.24527067900648042
# game
# 509
# 0.2727809995869076
# color
# 224
# 0.1635137860043203
# use
# 1199
# 0.038851122221818815
# obtain
# 790
# 0.054527523442131645
# characterization
# 199
# 0.1635137860043203
# family
# 452
# 0.18185399972460503
# graph
# 529
# 0.3270275720086406
# algorithmic
# 72
# 0.09092699986230252
# solution
# 1068
# 0.0752505986419897
# family
# 452
# 0.18185399972460503
# problem
# 896
# 0.07020392466244446
# concern
# 245
# 0.09092699986230252
# tree
# 1175
# 0.09092699986230252
# decomposition
# 310
# 0.18185399972460503
# graph
# 529
# 0.3270275720086406
# special
# 1079
# 0.0752505986419897
# instance
# 602
# 0.09092699986230252
# sparse
# 1074
# 0.2727809995869076
# graph
# 529
# 0.3270275720086406
# appear
# 92
# 0.0752505986419897
# rigidity
# 995
# 0.09092699986230252
# theory
# 1155
# 0.06259417895662031
# receive
# 957
# 0.09092699986230252
# increase
# 586
# 0.0752505986419897
# attention
# 116
# 0.0752505986419897
# recent
# 958
# 0.06608049178184731
# year
# 1240
# 0.0752505986419897
# particular
# 827
# 0.06608049178184731
# colored
# 225
# 0.09092699986230252
# pebble
# 836
# 0.36370799944921006
# generalize
# 516
# 0.08175689300216014
# strengthen
# 1112
# 0.09092699986230252
# previous
# 891
# 0.1505011972839794
# result
# 989
# 0.03774767087616512
# give
# 524
# 0.054527523442131645
# new
# 764
# 0.19824147534554196
# proof
# 906
# 0.07020392466244446
# characterization
# 199
# 0.1635137860043203
# arboricity
# 102
# 0.09092699986230252
# also
# 77
# 0.10080818112306898
# present
# 889
# 0.04859382336945428
# new
# 764
# 1241
# 0.06791925193790689
# settle
# 1034
# 0.06791925193790689
# asymptotic
# 113
# 0.06791925193790689
# behaviour
# 135
# 0.06791925193790689
# phase
# 847
# 0.16862860455255943
# scalar
# 1008
# 0.24427802619170672
# form
# 482
# 0.16292052340117674
# factor
# 450
# 0.19743915784349172
# case
# 184
# 0.16381980610975755
# freeness
# 494
# 0.3643886879896667
# monotonic
# 741
# 0.18219434399483336
# independence
# 587
# 0.18219434399483336
# notion
# 775
# 0.18219434399483336
# conditional
# 248
# 0.3643886879896667
# freeness
# 494
# 0.3643886879896667
# meaningful
# 713
# 0.18219434399483336
# complex
# 234
# 0.1507828640069312
# value
# 1202
# 0.12542265102958444
# state
# 1097
# 0.119371384019029
# replace
# 977
# 0.18219434399483336
# positive
# 874
# 0.1507828640069312
# conditional
# 248
# 0.3643886879896667
# expectation
# 433
# 0.18219434399483336
# framework
# 492
# 0.1507828640069312
# paper
# 821
# 0.10099684613395317
# present
# 889
# 0.09736953582990823
# several
# 1035
# 0.14067062609683334
# positivity
# 875
# 0.18219434399483336
# result
# 989
# 0.07563663315660644
# version
# 1208
# 0.16381980610975755
# central
# 193
# 0.18219434399483336
# limit
# 672
# 0.12542265102958444
# theorem
# 1153
# 0.16381980610975755
# analogue
# 81
# 0.16381980610975755
# conditionally
# 249
# 0.18219434399483336
# free
# 493
# 0.13240832612185535
# transform
# 1169
# 0.16381980610975755
# construct
# 262
# 0.1507828640069312
# mean
# 712
# 0.1507828640069312
# multilinear
# 748
# 0.18219434399483336
# function
# 499
# 0.11403378823677955
# serie
# 1029
# 0.18219434399483336

# %% [markdown]
# #### PMI

# %%
# Zählung der Wortvorkommen und Paarvorkommen
word_counts = Counter()
pair_counts = Counter()
total_pairs = 0

for words in filtered_all_words:
    unique_words = set(words)
    for word in unique_words:
        word_counts[word] += 1
    for word1 in unique_words:
        for word2 in unique_words:
            if word1 != word2:
                pair_counts[(word1, word2)] += 1

# Anzahl der Gesamtpaare aktualisieren
total_pairs = sum(pair_counts.values())

# Berechnung der PMI-Werte
pmi_values = {}
n_documents = len(filtered_all_words)  # Gesamtzahl der Dokumente
for (word1, word2), count in pair_counts.items():
    prob_word1 = word_counts[word1] / n_documents
    prob_word2 = word_counts[word2] / n_documents
    prob_pair = count / total_pairs
    pmi = math.log(prob_pair / (prob_word1 * prob_word2))
    pmi_values[(word1, word2)] = pmi

# Zuweisung der PMI-Kanten und Gewichte
edge_index_list_has_pmi = [[], []]
pmi_weights = []

for (word1, word2), pmi in pmi_values.items():
    edge_index_list_has_pmi[0].append(word1)
    edge_index_list_has_pmi[1].append(word2)
    pmi_weights.append(pmi)

# Konvertieren der Daten für PyTorch
# data = {}  # Ersetzen oder definieren Sie Ihr 'data'-Objekt entsprechend
data['word', 'co_occurs_with', 'word'].edge_index = edge_index_list_has_pmi
data['word', 'co_occurs_with', 'word'].edge_attr = torch.tensor(pmi_weights, dtype=torch.float)

# %% [markdown]
# #### Check results

# %%
pair_counts
# Out:
# Counter({('result', 'use'): 9,
#          ('result', 'also'): 9,
#          ('use', 'result'): 9,
#          ('also', 'result'): 9,
#          ('model', 'result'): 9,
#          ('result', 'model'): 9,
#          ('result', 'present'): 8,
#          ('present', 'result'): 8,
#          ('one', 'use'): 8,
#          ('use', 'one'): 8,
#          ('result', 'obtain'): 7,
#          ('$', 'use'): 7,
#          ('use', '$'): 7,
#          ('use', 'also'): 7,
#          ('use', 'give'): 7,
#          ('also', 'use'): 7,
#          ('obtain', 'result'): 7,
#          ('give', 'use'): 7,
#          ('paper', 'use'): 7,
#          ('result', 'show'): 7,
#          ('use', 'paper'): 7,
#          ('use', 'show'): 7,
#          ('show', 'result'): 7,
#          ('show', 'use'): 7,
#          ('form', 'use'): 7,
#          ('use', 'form'): 7,
#          ('present', 'show'): 6,
#          ('show', 'present'): 6,
#          ('result', '$'): 6,
#          ('$', 'result'): 6,
#          ('result', 'function'): 6,
#          ('function', 'result'): 6,
#          ('result', 'form'): 6,
#          ('form', 'result'): 6,
#          ('value', 'result'): 6,
#          ('result', 'value'): 6,
#          ('result', 'describe'): 5,
#          ('result', 'give'): 5,
#          ('$', 'also'): 5,
#          ('use', 'present'): 5,
#          ('use', 'obtain'): 5,
#          ('present', 'use'): 5,
#          ('describe', 'result'): 5,
#          ('also', '$'): 5,
#          ('obtain', 'use'): 5,
#          ('give', 'result'): 5,
#          ('limit', 'result'): 5,
#          ("'s", 'result'): 5,
#          ('model', 'system'): 5,
#          ('model', 'also'): 5,
#          ('result', 'limit'): 5,
#          ('result', "'s"): 5,
#          ('result', 'system'): 5,
#          ('system', 'model'): 5,
#          ('system', 'result'): 5,
#          ('also', 'model'): 5,
#          ('paper', 'result'): 5,
#          ('paper', '$'): 5,
#          ('result', 'paper'): 5,
#          ('$', 'paper'): 5,
#          ('one', 'result'): 5,
#          ('one', 'give'): 5,
#          ('result', 'one'): 5,
#          ('result', 'find'): 5,
#          ('$', 'study'): 5,
#          ('find', 'result'): 5,
#          ('find', 'interaction'): 5,
#          ('interaction', 'find'): 5,
#          ('also', 'study'): 5,
#          ('study', '$'): 5,
#          ('study', 'also'): 5,
#          ('give', 'one'): 5,
#          ('paper', 'one'): 5,
#          ('one', 'paper'): 5,
#          ('numerical', 'simulation'): 5,
#          ('simulation', 'numerical'): 5,
#          ('field', 'present'): 5,
#          ('present', 'field'): 5,
#          ('use', 'study'): 5,
#          ('study', 'use'): 5,
#          ('use', 'method'): 5,
#          ('method', 'use'): 5,
#          ('result', 'large'): 5,
#          ('large', 'result'): 5,
#          ('approximation', 'method'): 5,
#          ('method', 'approximation'): 5,
#          ('simulation', 'show'): 5,
#          ('show', 'simulation'): 5,
#          ('simulation', 'particle'): 5,
#          ('particle', 'simulation'): 5,
#          ('space', 'show'): 4,
#          ('process', 'obtain'): 4,
#          ('process', 'show'): 4,
#          ('present', 'obtain'): 4,
#          ('include', 'show'): 4,
#          ('obtain', 'process'): 4,
#          ('obtain', 'present'): 4,
#          ('show', 'space'): 4,
#          ('show', 'process'): 4,
#          ('show', 'include'): 4,
#          ('result', 'base'): 4,
#          ('$', 'obtain'): 4,
#          ('$', 'give'): 4,
#          ('use', 'base'): 4,
#          ('present', 'base'): 4,
#          ('present', 'also'): 4,
#          ('present', 'give'): 4,
#          ('base', 'result'): 4,
#          ('base', 'use'): 4,
#          ('base', 'present'): 4,
#          ('base', 'also'): 4,
#          ('describe', 'also'): 4,
#          ('also', 'present'): 4,
#          ('also', 'base'): 4,
#          ('also', 'describe'): 4,
#          ('also', 'obtain'): 4,
#          ('obtain', '$'): 4,
#          ('obtain', 'also'): 4,
#          ('obtain', 'give'): 4,
#          ('give', '$'): 4,
#          ('give', 'present'): 4,
#          ('give', 'obtain'): 4,
#          ('limit', 'model'): 4,
#          ('limit', 'also'): 4,
#          ('model', 'limit'): 4,
#          ('result', 'field'): 4,
#          ('field', 'result'): 4,
#          ('field', 'system'): 4,
#          ('system', 'field'): 4,
#          ('also', 'limit'): 4,
#          ('space', 'use'): 4,
#          ('use', 'space'): 4,
#          ('one', 'particle'): 4,
#          ('one', 'factor'): 4,
#          ('one', 'two'): 4,
#          ('one', 'dimensional'): 4,
#          ('result', 'state'): 4,
#          ('result', 'study'): 4,
#          ('particle', 'one'): 4,
#          ('particle', 'scatter'): 4,
#          ('factor', 'one'): 4,
#          ('find', 'function'): 4,
#          ('state', 'result'): 4,
#          ('scatter', 'particle'): 4,
#          ('function', 'find'): 4,
#          ('also', 'two'): 4,
#          ('two', 'one'): 4,
#          ('two', 'also'): 4,
#          ('study', 'result'): 4,
#          ('give', 'dimensional'): 4,
#          ('dimensional', 'one'): 4,
#          ('dimensional', 'give'): 4,
#          ('one', 'simple'): 4,
#          ('one', 'process'): 4,
#          ('one', 'show'): 4,
#          ('simple', 'one'): 4,
#          ('discrete', 'particle'): 4,
#          ('particle', 'discrete'): 4,
#          ('particle', 'show'): 4,
#          ('process', 'one'): 4,
#          ('show', 'one'): 4,
#          ('show', 'particle'): 4,
#          ('result', 'simulation'): 4,
#          ('result', 'high'): 4,
#          ('result', 'require'): 4,
#          ('result', 'calculate'): 4,
#          ('simulation', 'result'): 4,
#          ('simulation', 'high'): 4,
#          ('simulation', 'resolve'): 4,
#          ('high', 'result'): 4,
#          ('high', 'simulation'): 4,
#          ('require', 'result'): 4,
#          ('different', 'method'): 4,
#          ('calculate', 'result'): 4,
#          ('equation', 'method'): 4,
#          ('method', 'different'): 4,
#          ('method', 'equation'): 4,
#          ('resolve', 'simulation'): 4,
#          ('model', 'present'): 4,
#          ('model', 'function'): 4,
#          ('model', 'theoretical'): 4,
#          ('field', 'show'): 4,
#          ('present', 'model'): 4,
#          ('present', 'form'): 4,
#          ('find', 'show'): 4,
#          ('property', 'result'): 4,
#          ("'s", 'form'): 4,
#          ('result', 'property'): 4,
#          ('result', 'extend'): 4,
#          ('result', 'theoretical'): 4,
#          ('extend', 'result'): 4,
#          ('function', 'model'): 4,
#          ('show', 'field'): 4,
#          ('show', 'find'): 4,
#          ('show', 'form'): 4,
#          ('theoretical', 'model'): 4,
#          ('theoretical', 'result'): 4,
#          ('form', 'present'): 4,
#          ('form', "'s"): 4,
#          ('form', 'show'): 4,
#          ('form', 'also'): 4,
#          ('also', 'form'): 4,
#          ('one', 'calculate'): 4,
#          ('process', 'give'): 4,
#          ('calculate', 'one'): 4,
#          ('give', 'process'): 4,
#          ('one', 'number'): 4,
#          ('number', 'one'): 4,
#          ('paper', 'study'): 4,
#          ('study', 'paper'): 4,
#          ('value', 'use'): 4,
#          ('use', 'value'): 4,
#          ('one', 'method'): 4,
#          ('use', 'factor'): 4,
#          ('use', 'dimensional'): 4,
#          ('factor', 'use'): 4,
#          ('method', 'one'): 4,
#          ('dimensional', 'use'): 4,
#          ('model', 'use'): 4,
#          ('model', 'obtain'): 4,
#          ('use', 'model'): 4,
#          ('obtain', 'model'): 4,
#          ('field', 'base'): 4,
#          ('base', 'field'): 4,
#          ('value', 'present'): 4,
#          ('present', 'value'): 4,
#          ('simulation', 'approximation'): 4,
#          ('base', 'approximation'): 4,
#          ('approximation', 'simulation'): 4,
#          ('approximation', 'base'): 4,
#          ('present', 'method'): 4,
#          ('method', 'present'): 4,
#          ('shape', 'simulation'): 4,
#          ('simulation', 'shape'): 4,
#          ('simulation', 'scatter'): 4,
#          ('scatter', 'simulation'): 4,
#          ('scatter', 'show'): 4,
#          ('show', 'scatter'): 4,
#          ('simulation', 'dipole'): 4,
#          ('particle', 'dipole'): 4,
#          ('dipole', 'simulation'): 4,
#          ('dipole', 'particle'): 4,
#          ('make', 'accuracy'): 3,
#          ('calculation', 'present'): 3,
#          ('calculation', 'state'): 3,
#          ('process', 'present'): 3,
#          ('process', 'demonstrate'): 3,
#          ('present', 'calculation'): 3,
#          ('present', 'process'): 3,
#          ('present', 'datum'): 3,
#          ('present', 'state'): 3,
#          ('quark', 'obtain'): 3,
#          ('demonstrate', 'process'): 3,
#          ('datum', 'present'): 3,
#          ('contribution', 'obtain'): 3,
#          ('state', 'calculation'): 3,
#          ('state', 'present'): 3,
#          ('accuracy', 'make'): 3,
#          ('obtain', 'quark'): 3,
#          ('obtain', 'contribution'): 3,
#          ('energy', 'show'): 3,
#          ('show', 'energy'): 3,
#          ('theory', 'result'): 3,
#          ('theory', 'particular'): 3,
#          ('theory', 'recent'): 3,
#          ('theory', 'present'): 3,
#          ('theory', 'base'): 3,
#          ('result', 'theory'): 3,
#          ('result', 'particular'): 3,
#          ('result', 'problem'): 3,
#          ('result', 'recent'): 3,
#          ('result', 'work'): 3,
#          ('result', 'previous'): 3,
#          ('result', 'appear'): 3,
#          ('result', 'proof'): 3,
#          ('$', 'special'): 3,
#          ('particular', 'theory'): 3,
#          ('particular', 'result'): 3,
#          ('new', 'use'): 3,
#          ('new', 'give'): 3,
#          ('use', 'new'): 3,
#          ('use', 'problem'): 3,
#          ('problem', 'result'): 3,
#          ('problem', 'use'): 3,
#          ('recent', 'theory'): 3,
#          ('recent', 'result'): 3,
#          ('recent', 'present'): 3,
#          ('recent', 'obtain'): 3,
#          ('present', 'theory'): 3,
#          ('present', 'recent'): 3,
#          ('present', 'appear'): 3,
#          ('present', 'describe'): 3,
#          ('base', 'theory'): 3,
#          ('work', 'result'): 3,
#          ('previous', 'result'): 3,
#          ('appear', 'result'): 3,
#          ('appear', 'present'): 3,
#          ('proof', 'result'): 3,
#          ('proof', 'obtain'): 3,
#          ('describe', 'present'): 3,
#          ('special', '$'): 3,
#          ('also', 'give'): 3,
#          ('obtain', 'recent'): 3,
#          ('obtain', 'proof'): 3,
#          ('give', 'new'): 3,
#          ('give', 'also'): 3,
#          ('limit', 'system'): 3,
#          ("'s", 'constant'): 3,
#          ("'s", 'also'): 3,
#          ("'s", 'derive'): 3,
#          ('model', 'far'): 3,
#          ('model', 'field'): 3,
#          ('model', 'distance'): 3,
#          ('model', 'suggest'): 3,
#          ('model', 'datum'): 3,
#          ('model', 'derive'): 3,
#          ('result', 'far'): 3,
#          ('result', 'distance'): 3,
#          ('result', 'suggest'): 3,
#          ('result', 'datum'): 3,
#          ('result', 'x'): 3,
#          ('far', 'model'): 3,
#          ('far', 'result'): 3,
#          ('far', 'field'): 3,
#          ('far', 'suggest'): 3,
#          ('far', 'also'): 3,
#          ('field', 'model'): 3,
#          ('field', 'far'): 3,
#          ('field', 'distance'): 3,
#          ('field', 'describe'): 3,
#          ('field', 'also'): 3,
#          ('distance', 'model'): 3,
#          ('distance', 'result'): 3,
#          ('distance', 'field'): 3,
#          ('distance', 'system'): 3,
#          ('suggest', 'model'): 3,
#          ('suggest', 'result'): 3,
#          ('suggest', 'far'): 3,
#          ('datum', 'model'): 3,
#          ('datum', 'result'): 3,
#          ('datum', 'also'): 3,
#          ('x', 'result'): 3,
#          ('x', 'describe'): 3,
#          ('system', 'limit'): 3,
#          ('system', 'distance'): 3,
#          ('describe', 'field'): 3,
#          ('describe', 'x'): 3,
#          ('constant', "'s"): 3,
#          ('also', "'s"): 3,
#          ('also', 'far'): 3,
#          ('also', 'field'): 3,
#          ('also', 'datum'): 3,
#          ('derive', "'s"): 3,
#          ('derive', 'model'): 3,
#          ('single', 'number'): 3,
#          ('single', 'show'): 3,
#          ('source', 'show'): 3,
#          ('number', 'single'): 3,
#          ('number', 'show'): 3,
#          ('cycle', 'show'): 3,
#          ('show', 'single'): 3,
#          ('show', 'source'): 3,
#          ('show', 'number'): 3,
#          ('show', 'cycle'): 3,
#          ('paper', 'show'): 3,
#          ('use', 'compute'): 3,
#          ('compute', 'use'): 3,
#          ('show', 'paper'): 3,
#          ('one', '$'): 3,
#          ('one', 'order'): 3,
#          ('one', '1'): 3,
#          ('one', 'state'): 3,
#          ('one', 'describe'): 3,
#          ('one', 'also'): 3,
#          ('one', 'study'): 3,
#          ('one', 'example'): 3,
#          ('result', 'factor'): 3,
#          ('result', 'range'): 3,
#          ('result', 'interaction'): 3,
#          ('result', 'wave'): 3,
#          ('$', 'one'): 3,
#          ('$', 'wave'): 3,
#          ('order', 'one'): 3,
#          ('order', 'also'): 3,
#          ('particle', 'two'): 3,
#          ('factor', 'result'): 3,
#          ('range', 'result'): 3,
#          ('range', 'also'): 3,
#          ('range', 'study'): 3,
#          ('find', 'study'): 3,
#          ('find', 'wave'): 3,
#          ('three', 'study'): 3,
#          ('interaction', 'result'): 3,
#          ('interaction', 'scatter'): 3,
#          ('interaction', 'wave'): 3,
#          ('1', 'one'): 3,
#          ('state', 'one'): 3,
#          ('state', 'function'): 3,
#          ('scatter', 'interaction'): 3,
#          ('function', 'state'): 3,
#          ('function', 'study'): 3,
#          ('function', 'give'): 3,
#          ('describe', 'one'): 3,
#          ('also', 'one'): 3,
#          ('also', 'order'): 3,
#          ('also', 'range'): 3,
#          ('also', 'correspond'): 3,
#          ('two', 'particle'): 3,
#          ('two', 'study'): 3,
#          ('two', 'dimensional'): 3,
#          ('study', 'one'): 3,
#          ('study', 'range'): 3,
#          ('study', 'find'): 3,
#          ('study', 'three'): 3,
#          ('study', 'function'): 3,
#          ('study', 'two'): 3,
#          ('study', 'wave'): 3,
#          ('give', 'function'): 3,
#          ('give', 'wave'): 3,
#          ('example', 'one'): 3,
#          ('correspond', 'also'): 3,
#          ('wave', 'result'): 3,
#          ('wave', '$'): 3,
#          ('wave', 'find'): 3,
#          ('wave', 'interaction'): 3,
#          ('wave', 'study'): 3,
#          ('wave', 'give'): 3,
#          ('dimensional', 'two'): 3,
#          ('limit', 'paper'): 3,
#          ('limit', 'several'): 3,
#          ('theory', 'one'): 3,
#          ('theory', 'particle'): 3,
#          ('theory', 'possible'): 3,
#          ('theory', 'process'): 3,
#          ('theory', 'relation'): 3,
#          ('theory', 'show'): 3,
#          ('paper', 'limit'): 3,
#          ('paper', 'particular'): 3,
#          ('paper', 'process'): 3,
#          ('paper', 'relation'): 3,
#          ('paper', 'derive'): 3,
#          ('one', 'theory'): 3,
#          ('one', 'possible'): 3,
#          ('one', 'different'): 3,
#          ('one', 'particular'): 3,
#          ('one', 'non'): 3,
#          ('one', 'include'): 3,
#          ('one', 'explore'): 3,
#          ('model', 'due'): 3,
#          ('model', 'different'): 3,
#          ('model', 'process'): 3,
#          ('model', 'recent'): 3,
#          ('model', 'several'): 3,
#          ('model', 'include'): 3,
#          ('model', 'show'): 3,
#          ('particle', 'theory'): 3,
#          ('particle', 'possible'): 3,
#          ('due', 'model'): 3,
#          ('possible', 'theory'): 3,
#          ('possible', 'one'): 3,
#          ('possible', 'particle'): 3,
#          ('possible', 'consider'): 3,
#          ('possible', 'show'): 3,
#          ('different', 'one'): 3,
#          ('different', 'model'): 3,
#          ('different', 'two'): 3,
#          ('particular', 'paper'): 3,
#          ('particular', 'one'): 3,
#          ('particular', 'show'): 3,
#          ('non', 'one'): 3,
#          ('non', 'show'): 3,
#          ('process', 'theory'): 3,
#          ('process', 'paper'): 3,
#          ('process', 'model'): 3,
#          ('recent', 'model'): 3,
#          ('several', 'limit'): 3,
#          ('several', 'model'): 3,
#          ('several', 'show'): 3,
#          ('relation', 'theory'): 3,
#          ('relation', 'paper'): 3,
#          ('system', 'show'): 3,
#          ('consider', 'possible'): 3,
#          ('consider', 'show'): 3,
#          ('include', 'one'): 3,
#          ('include', 'model'): 3,
#          ('two', 'different'): 3,
#          ('two', 'show'): 3,
#          ('show', 'theory'): 3,
#          ('show', 'model'): 3,
#          ('show', 'possible'): 3,
#          ('show', 'particular'): 3,
#          ('show', 'non'): 3,
#          ('show', 'several'): 3,
#          ('show', 'system'): 3,
#          ('show', 'consider'): 3,
#          ('show', 'two'): 3,
#          ('derive', 'paper'): 3,
#          ('explore', 'one'): 3,
#          ('effect', 'find'): 3,
#          ('effect', 'interaction'): 3,
#          ('dynamic', 'simulation'): 3,
#          ('dynamic', 'resolve'): 3,
#          ('model', 'high'): 3,
#          ('model', 'calculation'): 3,
#          ('model', 'find'): 3,
#          ('result', 'numerical'): 3,
#          ('result', 'calculation'): 3,
#          ('result', 'application'): 3,
#          ('result', 'method'): 3,
#          ('result', 'resolve'): 3,
#          ('numerical', 'result'): 3,
#          ('numerical', 'much'): 3,
#          ('numerical', 'experiment'): 3,
#          ('numerical', 'resolve'): 3,
#          ('simulation', 'dynamic'): 3,
#          ('simulation', 'require'): 3,
#          ('simulation', 'much'): 3,
#          ('simulation', 'interaction'): 3,
#          ('simulation', 'application'): 3,
#          ('simulation', 'method'): 3,
#          ('simulation', 'accuracy'): 3,
#          ('high', 'model'): 3,
#          ('require', 'simulation'): 3,
#          ('require', 'resolve'): 3,
#          ('calculation', 'model'): 3,
#          ('calculation', 'result'): 3,
#          ('different', 'state'): 3,
#          ('find', 'effect'): 3,
#          ('find', 'model'): 3,
#          ('much', 'numerical'): 3,
#          ('much', 'simulation'): 3,
#          ('calculate', 'method'): 3,
#          ('interaction', 'effect'): 3,
#          ('interaction', 'simulation'): 3,
#          ('application', 'result'): 3,
#          ('application', 'simulation'): 3,
#          ('state', 'different'): 3,
#          ('state', 'method'): 3,
#          ('experiment', 'numerical'): 3,
#          ('method', 'result'): 3,
#          ('method', 'simulation'): 3,
#          ('method', 'calculate'): 3,
#          ('method', 'state'): 3,
#          ('accuracy', 'simulation'): 3,
#          ('resolve', 'dynamic'): 3,
#          ('resolve', 'result'): 3,
#          ('resolve', 'numerical'): 3,
#          ('resolve', 'require'): 3,
#          ('model', 'property'): 3,
#          ('model', 'observation'): 3,
#          ('model', 'form'): 3,
#          ('field', 'observe'): 3,
#          ('point', 'result'): 3,
#          ('point', 'high'): 3,
#          ('point', 'also'): 3,
#          ('present', 'compare'): 3,
#          ('present', 'function'): 3,
#          ('present', 'theoretical'): 3,
#          ('present', 'system'): 3,
#          ('present', 'discuss'): 3,
#          ('find', 'form'): 3,
#          ('x', 'show'): 3,
#          ('property', 'model'): 3,
#          ('property', 'also'): 3,
#          ('analysis', 'result'): 3,
#          ('analysis', 'show'): 3,
#          ('analysis', 'theoretical'): 3,
#          ('analysis', 'high'): 3,
#          ('study', 'extend'): 3,
#          ('study', 'form'): 3,
#          ("'s", 'low'): 3,
#          ('observation', 'model'): 3,
#          ('observation', 'result'): 3,
#          ('result', 'point'): 3,
#          ('result', 'analysis'): 3,
#          ('result', 'observation'): 3,
#          ('result', 'compare'): 3,
#          ('result', 'several'): 3,
#          ('result', 'observe'): 3,
#          ('result', 'low'): 3,
#          ('extend', 'study'): 3,
#          ('extend', 'form'): 3,
#          ('extend', 'also'): 3,
#          ('compare', 'present'): 3,
#          ('compare', 'result'): 3,
#          ('several', 'result'): 3,
#          ('several', 'function'): 3,
#          ('function', 'present'): 3,
#          ('function', 'several'): 3,
#          ('function', 'show'): 3,
#          ('show', 'x'): 3,
#          ('show', 'analysis'): 3,
#          ('show', 'function'): 3,
#          ('show', 'observe'): 3,
#          ('show', 'even'): 3,
#          ('show', 'high'): 3,
#          ('show', 'discuss'): 3,
#          ('show', 'low'): 3,
#          ('observe', 'field'): 3,
#          ('observe', 'result'): 3,
#          ('observe', 'show'): 3,
#          ('observe', 'system'): 3,
#          ('theoretical', 'present'): 3,
#          ('theoretical', 'analysis'): 3,
#          ('theoretical', 'also'): 3,
#          ('even', 'show'): 3,
#          ('system', 'present'): 3,
#          ('system', 'observe'): 3,
#          ('form', 'model'): 3,
#          ('form', 'find'): 3,
#          ('form', 'study'): 3,
#          ('form', 'extend'): 3,
#          ('form', 'low'): 3,
#          ('high', 'point'): 3,
#          ('high', 'analysis'): 3,
#          ('high', 'show'): 3,
#          ('discuss', 'present'): 3,
#          ('discuss', 'show'): 3,
#          ('also', 'point'): 3,
#          ('also', 'property'): 3,
#          ('also', 'extend'): 3,
#          ('also', 'theoretical'): 3,
#          ('low', "'s"): 3,
#          ('low', 'result'): 3,
#          ('low', 'show'): 3,
#          ('low', 'form'): 3,
#          ("'s", 'one'): 3,
#          ('paper', 'obtain'): 3,
#          ('paper', 'give'): 3,
#          ('one', "'s"): 3,
#          ('one', 'obtain'): 3,
#          ('result', 'process'): 3,
#          ('result', 'mean'): 3,
#          ('process', 'result'): 3,
#          ('calculate', 'obtain'): 3,
#          ('mean', 'result'): 3,
#          ('obtain', 'paper'): 3,
#          ('obtain', 'one'): 3,
#          ('obtain', 'calculate'): 3,
#          ('give', 'paper'): 3,
#          ('form', 'paper'): 3,
#          ('form', '$'): 3,
#          ('paper', 'form'): 3,
#          ('paper', 'number'): 3,
#          ('one', 'present'): 3,
#          ('field', 'use'): 3,
#          ('$', 'form'): 3,
#          ('number', 'paper'): 3,
#          ('number', 'use'): 3,
#          ('possible', 'present'): 3,
#          ('use', 'field'): 3,
#          ('use', 'number'): 3,
#          ('present', 'one'): 3,
#          ('present', 'possible'): 3,
#          ('form', 'integral'): 3,
#          ("'s", 'use'): 3,
#          ('paper', 'integral'): 3,
#          ('result', 'integral'): 3,
#          ('result', 'main'): 3,
#          ('integral', 'form'): 3,
#          ('integral', 'paper'): 3,
#          ('integral', 'result'): 3,
#          ('integral', 'use'): 3,
#          ('integral', 'application'): 3,
#          ('use', "'s"): 3,
#          ('use', 'integral'): 3,
#          ('use', 'odd'): 3,
#          ('application', 'integral'): 3,
#          ('odd', 'use'): 3,
#          ('main', 'result'): 3,
#          ('form', 'value'): 3,
#          ('limit', 'value'): 3,
#          ('value', 'form'): 3,
#          ('value', 'limit'): 3,
#          ('value', 'also'): 3,
#          ('value', 'obtain'): 3,
#          ('integral', 'base'): 3,
#          ('series', 'use'): 3,
#          ('point', 'use'): 3,
#          ('use', 'series'): 3,
#          ('use', 'point'): 3,
#          ('use', 'linear'): 3,
#          ('base', 'integral'): 3,
#          ('linear', 'use'): 3,
#          ('also', 'value'): 3,
#          ('obtain', 'value'): 3,
#          ('theory', 'integral'): 3,
#          ('theory', 'discuss'): 3,
#          ('integral', 'theory'): 3,
#          ('integral', 'discuss'): 3,
#          ('discuss', 'theory'): 3,
#          ('discuss', 'integral'): 3,
#          ('paper', 'state'): 3,
#          ('use', 'calculate'): 3,
#          ('use', 'two'): 3,
#          ('calculate', 'use'): 3,
#          ('state', 'paper'): 3,
#          ('method', 'two'): 3,
#          ('method', 'dimensional'): 3,
#          ('two', 'use'): 3,
#          ('two', 'method'): 3,
#          ('dimensional', 'method'): 3,
#          ('one', 'value'): 3,
#          ('one', 'large'): 3,
#          ('one', 'level'): 3,
#          ('value', 'one'): 3,
#          ('value', 'large'): 3,
#          ('model', 'large'): 3,
#          ('numerical', 'large'): 3,
#          ('matrix', 'use'): 3,
#          ('theoretical', 'large'): 3,
#          ('non', 'use'): 3,
#          ('non', 'large'): 3,
#          ('use', 'matrix'): 3,
#          ('use', 'non'): 3,
#          ('use', 'large'): 3,
#          ('use', 'include'): 3,
#          ('use', 'level'): 3,
#          ('large', 'one'): 3,
#          ('large', 'value'): 3,
#          ('large', 'model'): 3,
#          ('large', 'numerical'): 3,
#          ('large', 'theoretical'): 3,
#          ('large', 'non'): 3,
#          ('large', 'use'): 3,
#          ('include', 'use'): 3,
#          ('level', 'one'): 3,
#          ('level', 'use'): 3,
#          ('model', 'emission'): 3,
#          ('present', 'large'): 3,
#          ('present', 'time'): 3,
#          ('result', 'time'): 3,
#          ('large', 'present'): 3,
#          ('time', 'present'): 3,
#          ('time', 'result'): 3,
#          ('emission', 'model'): 3,
#          ('use', 'find'): 3,
#          ('use', 'function'): 3,
#          ('find', 'use'): 3,
#          ('function', 'use'): 3,
#          ('give', 'show'): 3,
#          ('show', 'give'): 3,
#          ('use', 'process'): 3,
#          ('use', 'approximation'): 3,
#          ('process', 'use'): 3,
#          ('give', 'method'): 3,
#          ('approximation', 'use'): 3,
#          ('method', 'give'): 3,
#          ('shape', 'use'): 3,
#          ('model', 'electron'): 3,
#          ('result', 'electron'): 3,
#          ('use', 'shape'): 3,
#          ('use', 'electron'): 3,
#          ('electron', 'model'): 3,
#          ('electron', 'result'): 3,
#          ('electron', 'use'): 3,
#          ('result', 'investigate'): 3,
#          ('investigate', 'result'): 3,
#          ('investigate', 'show'): 3,
#          ('field', 'approximation'): 3,
#          ('simulation', 'base'): 3,
#          ('simulation', 'analysis'): 3,
#          ('base', 'simulation'): 3,
#          ('base', 'show'): 3,
#          ('analysis', 'simulation'): 3,
#          ('show', 'investigate'): 3,
#          ('show', 'base'): 3,
#          ('show', 'approximation'): 3,
#          ('show', 'wave'): 3,
#          ('approximation', 'field'): 3,
#          ('approximation', 'show'): 3,
#          ('wave', 'show'): 3,
#          ('present', 'equation'): 3,
#          ('present', 'approximation'): 3,
#          ('present', 'free'): 3,
#          ('present', 'simulate'): 3,
#          ('equation', 'present'): 3,
#          ('equation', 'show'): 3,
#          ('approximation', 'present'): 3,
#          ('far', 'dynamic'): 3,
#          ('call', 'use'): 3,
#          ('base', 'method'): 3,
#          ('free', 'present'): 3,
#          ('show', 'equation'): 3,
#          ('show', 'dynamic'): 3,
#          ('show', 'method'): 3,
#          ('show', 'simulate'): 3,
#          ('thus', 'dynamic'): 3,
#          ('dynamic', 'far'): 3,
#          ('dynamic', 'show'): 3,
#          ('dynamic', 'thus'): 3,
#          ('dynamic', 'use'): 3,
#          ('method', 'base'): 3,
#          ('method', 'show'): 3,
#          ('simulate', 'present'): 3,
#          ('simulate', 'show'): 3,
#          ('use', 'call'): 3,
#          ('use', 'dynamic'): 3,
#          ('demonstrate', 'also'): 3,
#          ('also', 'demonstrate'): 3,
#          ('model', 'frequency'): 3,
#          ('frequency', 'model'): 3,
#          ('frequency', 'result'): 3,
#          ('feature', 'result'): 3,
#          ('result', 'frequency'): 3,
#          ('result', 'feature'): 3,
#          ('shape', 'decrease'): 3,
#          ('shape', 'numerical'): 3,
#          ('decrease', 'shape'): 3,
#          ('decrease', 'simulation'): 3,
#          ('numerical', 'shape'): 3,
#          ('numerical', 'light'): 3,
#          ('numerical', 'scatter'): 3,
#          ('numerical', 'show'): 3,
#          ('simulation', 'decrease'): 3,
#          ('simulation', 'light'): 3,
#          ('use', 'structure'): 3,
#          ('use', 'behavior'): 3,
#          ('use', 'wave'): 3,
#          ('light', 'numerical'): 3,
#          ('light', 'simulation'): 3,
#          ('light', 'scatter'): 3,
#          ('light', 'show'): 3,
#          ('structure', 'use'): 3,
#          ('interaction', 'show'): 3,
#          ('behavior', 'use'): 3,
#          ('behavior', 'show'): 3,
#          ('scatter', 'numerical'): 3,
#          ('scatter', 'light'): 3,
#          ('show', 'numerical'): 3,
#          ('show', 'light'): 3,
#          ('show', 'interaction'): 3,
#          ('show', 'behavior'): 3,
#          ('wave', 'use'): 3,
#          ('electron', 'phonon'): 3,
#          ('electron', 'optical'): 3,
#          ('phonon', 'electron'): 3,
#          ('phonon', 'optical'): 3,
#          ('optical', 'electron'): 3,
#          ('optical', 'phonon'): 3,
#          ('one', '2'): 3,
#          ('number', '2'): 3,
#          ('2', 'one'): 3,
#          ('2', 'number'): 3,
#          ('effect', 'electron'): 3,
#          ('use', '1'): 3,
#          ('electron', 'effect'): 3,
#          ('1', 'use'): 3,
#          ('use', 'low'): 3,
#          ('low', 'use'): 3,
#          ('large', 'show'): 3,
#          ('2', 'show'): 3,
#          ('show', 'large'): 3,
#          ('show', '2'): 3,
#          ('shape', 'discrete'): 3,
#          ('shape', 'particle'): 3,
#          ('shape', 'dipole'): 3,
#          ('shape', 'finally'): 3,
#          ('shape', 'approximation'): 3,
#          ('numerical', 'particle'): 3,
#          ('numerical', 'DDA'): 3,
#          ('numerical', 'discuss'): 3,
#          ('numerical', 'dipole'): 3,
#          ('discrete', 'shape'): 3,
#          ('discrete', 'simulation'): 3,
#          ('discrete', 'dipole'): 3,
#          ('discrete', 'finally'): 3,
#          ('discrete', 'approximation'): 3,
#          ('simulation', 'discrete'): 3,
#          ('simulation', 'DDA'): 3,
#          ('simulation', 'discuss'): 3,
#          ('simulation', 'error'): 3,
#          ('simulation', 'finally'): 3,
#          ('particle', 'shape'): 3,
#          ('particle', 'numerical'): 3,
#          ('particle', 'DDA'): 3,
#          ('particle', 'discuss'): 3,
#          ('particle', 'error'): 3,
#          ('particle', 'finally'): 3,
#          ('particle', 'approximation'): 3,
#          ('DDA', 'numerical'): 3,
#          ('DDA', 'simulation'): 3,
#          ('DDA', 'particle'): 3,
#          ('DDA', 'discuss'): 3,
#          ('DDA', 'dipole'): 3,
#          ('discuss', 'numerical'): 3,
#          ('discuss', 'simulation'): 3,
#          ('discuss', 'particle'): 3,
#          ('discuss', 'DDA'): 3,
#          ('discuss', 'dipole'): 3,
#          ('error', 'simulation'): 3,
#          ('error', 'particle'): 3,
#          ('error', 'dipole'): 3,
#          ('error', 'large'): 3,
#          ('dipole', 'shape'): 3,
#          ('dipole', 'numerical'): 3,
#          ('dipole', 'discrete'): 3,
#          ('dipole', 'DDA'): 3,
#          ('dipole', 'discuss'): 3,
#          ('dipole', 'error'): 3,
#          ('dipole', 'finally'): 3,
#          ('dipole', 'approximation'): 3,
#          ('large', 'error'): 3,
#          ('finally', 'shape'): 3,
#          ('finally', 'discrete'): 3,
#          ('finally', 'simulation'): 3,
#          ('finally', 'particle'): 3,
#          ('finally', 'dipole'): 3,
#          ('finally', 'approximation'): 3,
#          ('approximation', 'shape'): 3,
#          ('approximation', 'discrete'): 3,
#          ('approximation', 'particle'): 3,
#          ('approximation', 'dipole'): 3,
#          ('approximation', 'finally'): 3,
#          ('one', 'error'): 3,
#          ('error', 'one'): 3,
#          ('space', 'agreement'): 2,
#          ('make', 'LHC'): 2,
#          ('make', 'calculation'): 2,
#          ('make', 'distribution'): 2,
#          ('make', 'Collider'): 2,
#          ('make', 'phase'): 2,
#          ('make', 'state'): 2,
#          ('make', 'Hadron'): 2,
#          ('make', 'show'): 2,
#          ('make', 'Large'): 2,
#          ('LHC', 'make'): 2,
#          ('LHC', 'distribution'): 2,
#          ('LHC', 'Collider'): 2,
#          ('LHC', 'accuracy'): 2,
#          ('LHC', 'Hadron'): 2,
#          ('LHC', 'show'): 2,
#          ('LHC', 'Large'): 2,
#          ('order', 'pair'): 2,
#          ('order', 'test'): 2,
#          ('order', 'quark'): 2,
#          ('order', 'demonstrate'): 2,
#          ('order', 'reliable'): 2,
#          ('order', 'contribution'): 2,
#          ('order', 'prediction'): 2,
#          ('order', 'state'): 2,
#          ('order', 'include'): 2,
#          ('order', 'accuracy'): 2,
#          ('order', 'obtain'): 2,
#          ('pair', 'order'): 2,
#          ('pair', 'state'): 2,
#          ('calculation', 'make'): 2,
#          ('calculation', 'collider'): 2,
#          ('calculation', 'datum'): 2,
#          ('calculation', 'phase'): 2,
#          ('calculation', 'decay'): 2,
#          ('calculation', 'accuracy'): 2,
#          ('calculation', 'obtain'): 2,
#          ('collider', 'calculation'): 2,
#          ('collider', 'present'): 2,
#          ('collider', 'datum'): 2,
#          ('collider', 'decay'): 2,
#          ('test', 'order'): 2,
#          ('test', 'demonstrate'): 2,
#          ('test', 'reliable'): 2,
#          ('test', 'accuracy'): 2,
#          ('lead', 'state'): 2,
#          ('lead', 'include'): 2,
#          ('lead', 'energy'): 2,
#          ('lead', 'show'): 2,
#          ('region', 'process'): 2,
#          ('region', 'present'): 2,
#          ('region', 'demonstrate'): 2,
#          ('region', 'datum'): 2,
#          ('region', 'initial'): 2,
#          ('region', 'obtain'): 2,
#          ('region', 'show'): 2,
#          ('agreement', 'space'): 2,
#          ('agreement', 'well'): 2,
#          ('agreement', 'present'): 2,
#          ('agreement', 'produce'): 2,
#          ('agreement', 'prediction'): 2,
#          ('agreement', 'show'): 2,
#          ('well', 'agreement'): 2,
#          ('well', 'present'): 2,
#          ('well', 'datum'): 2,
#          ('well', 'produce'): 2,
#          ('well', 'prediction'): 2,
#          ('QCD', 'present'): 2,
#          ('QCD', 'contribution'): 2,
#          ('QCD', 'phase'): 2,
#          ('QCD', 'obtain'): 2,
#          ('QCD', 'energy'): 2,
#          ('QCD', 'show'): 2,
#          ('process', 'region'): 2,
#          ('process', 'differential'): 2,
#          ('process', 'quark'): 2,
#          ('process', 'include'): 2,
#          ('process', 'initial'): 2,
#          ('process', 'boson'): 2,
#          ('process', 'quantum'): 2,
#          ('present', 'collider'): 2,
#          ('present', 'region'): 2,
#          ('present', 'agreement'): 2,
#          ('present', 'well'): 2,
#          ...})

# %%
df_pmi = pd.DataFrame({
    'weights': pmi_weights,
})
df_pmi.nsmallest(50, "weights")
# Out:
#          weights
# 12725  -9.352387
# 12953  -9.352387
# 111441 -9.337461
# 111644 -9.337461
# 4762   -9.183310
# 5573   -9.183310
# 111187 -9.091503
# 111926 -9.091503
# 61471  -9.052282
# 61907  -9.052282
# 117663 -9.052282
# 120646 -9.052282
# 95794  -9.042232
# 96677  -9.042232
# 27747  -9.011460
# 29367  -9.011460
# 41704  -9.000989
# 41727  -9.000989
# 62703  -9.000989
# 63694  -9.000989
# 68730  -9.000989
# 71244  -9.000989
# 83354  -9.000989
# 84544  -9.000989
# 114338 -9.000989
# 114547 -9.000989
# 13227  -8.957971
# 13253  -8.957971
# 14400  -8.957971
# 16140  -8.957971
# 41514  -8.924449
# 41578  -8.924449
# 45083  -8.924449
# 45760  -8.924449
# 47091  -8.924449
# 47676  -8.924449
# 51656  -8.924449
# 54325  -8.924449
# 82812  -8.895628
# 83333  -8.895628
# 27735  -8.877929
# 27838  -8.877929
# 32817  -8.859910
# 39161  -8.859910
# 76194  -8.841561
# 79094  -8.841561
# 81576  -8.841561
# 82788  -8.841561
# 22599  -8.829139
# 25495  -8.829139

# %%
df_pmi.weights.hist()
# Out:
# <Axes: >

# %%
len(edge_index_list_has_word[0])
# Out:
# 2437

# %%
node_types, edge_types = data.metadata()

# %%
print(node_types)
print(edge_types)
# Out:
# ['paper', 'author', 'category', 'journal', 'word']
# [('paper', 'written_by', 'author'), ('paper', 'has_category', 'category'), ('paper', 'has_titleword', 'word'), ('paper', 'in_journal', 'journal-ref'), ('paper', 'has_word', 'word'), ('word', 'co_occurs_with', 'word')]

# %%
import numpy as np

# %%
einzigartige_werte = []
for element in edge_index_list_has_word[0]:
    if element not in einzigartige_werte:
        einzigartige_werte.append(element)

len(einzigartige_werte)
# Out:
# 1055

# %%
data.edge_attrs
# Out:
# <bound method BaseData.edge_attrs of HeteroData(
#   paper={
#     num_nodes=40,
#     license=[0],
#     doi=[0],
#     title=[0],
#     pages=[40],
#   },
#   author={
#     num_nodes=73,
#     name=[73],
#   },
#   category={
#     num_nodes=49,
#     name=[49],
#   },
#   journal={
#     num_nodes=40,
#     name=[0],
#   },
#   word={
#     num_nodes=1316,
#     name=[1316],
#   },
#   (paper, written_by, author)={ edge_index=[2] },
#   (paper, has_category, category)={ edge_index=[2] },
#   (paper, has_titleword, word)={ edge_index=[2] },
#   (paper, in_journal, journal-ref)={ edge_index=[2] },
#   (paper, has_word, word)={
#     edge_index=[1],
#     edge_attr=[2437],
#   },
#   (word, co_occurs_with, word)={
#     edge_index=[2],
#     edge_attr=[129666],
#   }
# )>

# %%
# Kanten Paper without weights

# edge_index_list_has_word = []
# list_of_paper_word = []
# list_of_words = []

# # Iteriere durch die Zeilen des DataFrames
# for i in range(len(df_short)):
#     # Holen der ID des Papers aus der aktuellen Zeile
#     paper_title = df_short['title'][i]
    
#     # Holen der Wortinformationen aus der aktuellen Zeile
#     words = all_words[i]
    
#     # Hier gehe ich davon aus, dass die Wörter als Liste vorliegen
#     for word in words:
#         list_of_words.append(word)
#         list_of_paper_word.append(paper_title)

# edge_index_list_has_word.append(list_of_paper_word)
# edge_index_list_has_word.append(list_of_words)

# # Weise die Edge-Indizes dem HeteroData-Objekt zu
# data['paper', 'has_word', 'word'].edge_index = edge_index_list_has_word

# %%
data.edge_attrs
# Out:
# <bound method BaseData.edge_attrs of HeteroData(
#   paper={
#     num_nodes=40,
#     license=[0],
#     doi=[0],
#     title=[0],
#     pages=[40],
#   },
#   author={
#     num_nodes=73,
#     name=[73],
#   },
#   category={
#     num_nodes=49,
#     name=[49],
#   },
#   journal={
#     num_nodes=40,
#     name=[0],
#   },
#   word={
#     num_nodes=1316,
#     name=[1316],
#   },
#   (paper, written_by, author)={ edge_index=[2] },
#   (paper, has_category, category)={ edge_index=[2] },
#   (paper, has_titleword, word)={ edge_index=[2] },
#   (paper, in_journal, journal-ref)={ edge_index=[2] },
#   (paper, has_word, word)={
#     edge_index=[1],
#     edge_attr=[2437],
#   },
#   (word, co_occurs_with, word)={
#     edge_index=[2],
#     edge_attr=[129666],
#   }
# )>

# %% [markdown]
# # Visualization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from collections import Counter
from math import log
import torch
import networkx as nx
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Ihr DataFrame und die Spalte 'abstract'
abstracts = df[:100]['abstract'].tolist()

counter = CountVectorizer(stop_words='english')
count_matrix = counter.fit_transform(abstracts)

# Verwenden Sie die entsprechende Methode je nach Ihrer scikit-learn Version
try:
    features = counter.get_feature_names_out()
except AttributeError:
    features = counter.get_feature_names()

abstracts_counter = pd.Series(count_matrix.toarray().sum(axis=0), 
                              index=features).sort_values(ascending=False)

bar_graph = abstracts_counter[:50].plot(kind='bar', figsize=(18,8), alpha=1, fontsize=17, rot=90, edgecolor='black', linewidth=2,
            title='Word Counts in Abstracts')
bar_graph.set_xlabel('Words')
bar_graph.set_ylabel('Occurrences')
bar_graph.title.set_size(18)
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import math
import itertools

# Angenommen, df ist Ihr DataFrame mit einer Spalte 'document' für Dokumente
documents = df['title'][:1].tolist()

# Berechnung der TF-IDF-Werte
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
feature_names = tfidf_vectorizer.get_feature_names_out()

# Erstellung des Graphen
G = nx.Graph()

# Hinzufügen von Dokument- und Wortknoten
for doc_id, doc in enumerate(documents):
    G.add_node(f'doc_{doc_id}', type='document')

for word in feature_names:
    G.add_node(word, type='word')

# Hinzufügen von Dokument-Wort-Kanten mit TF-IDF-Gewichtungen
for doc_id in range(tfidf_matrix.shape[0]):
    for word_id in tfidf_matrix[doc_id].nonzero()[1]:
        tfidf_weight = tfidf_matrix[doc_id, word_id]
        G.add_edge(f'doc_{doc_id}', feature_names[word_id], weight=tfidf_weight)
        print(f"doc_id: {doc_id}, word_id: {feature_names[word_id]}, weight: {tfidf_weight}")
        
# Berechnung der PMI-Werte für Wort-Wort-Kanten
word_counts = Counter(np.array(tfidf_matrix.sum(axis=0)).flatten())
total_count = sum(word_counts.values())
word_pairs = itertools.combinations(feature_names, 2)

for word1, word2 in word_pairs:
    count_word1 = word_counts[word1]
    count_word2 = word_counts[word2]
    count_word1_word2 = (tfidf_matrix[:, feature_names.tolist().index(word1)] 
                         + tfidf_matrix[:, feature_names.tolist().index(word2)]).sum()
    pmi = math.log((count_word1_word2 * total_count) / (count_word1 * count_word2), 2)
    if pmi > 0:
        G.add_edge(word1, word2, weight=pmi)

# Zeige den Graphen an, deaktiviere die Verarbeitung von LaTeX-Symbolen
plt.rcParams['text.usetex'] = False

# circular_layout sonst Zahl zu groß für Visualisierung von pmi, davor spring genommen
pos = nx.circular_layout(G)  # Layout des Graphen
nx.draw(G, pos, with_labels=True, font_size=6, node_size=100, node_color='lightblue', font_color='black', font_weight='bold', edge_color='gray')

# # Gewichte der Kanten holen
# edge_weights = nx.get_edge_attributes(G, 'weight')
# # Kanten-Labels zeichnen
# nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_weights, font_size=5)

plt.title("Graph Representation of the ArXiv Dataset")
plt.show()
# Out:
# doc_id: 0, word_id: energies, weight: 0.3333333333333333
# doc_id: 0, word_id: lhc, weight: 0.3333333333333333
# doc_id: 0, word_id: tevatron, weight: 0.3333333333333333
# doc_id: 0, word_id: sections, weight: 0.3333333333333333
# doc_id: 0, word_id: cross, weight: 0.3333333333333333
# doc_id: 0, word_id: production, weight: 0.3333333333333333
# doc_id: 0, word_id: diphoton, weight: 0.3333333333333333
# doc_id: 0, word_id: prompt, weight: 0.3333333333333333
# doc_id: 0, word_id: calculation, weight: 0.3333333333333333
# C:\Users\F22RatHen\AppData\Local\Temp\ipykernel_20204\1328852984.py:45: RuntimeWarning: divide by zero encountered in scalar divide
#   pmi = math.log((count_word1_word2 * total_count) / (count_word1 * count_word2), 2)
