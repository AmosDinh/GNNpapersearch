# %%
! pip install torch==2.1.0  torchvision==0.16.0 torchtext==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121
# import torch
#os.environ['TORCH'] = torch.__version__
#print(torch.__version__)
#torch_version = '2.0.0+cu118'

#!pip install pyg_lib torch_scatter torch_sparse torch_cluster -f https://data.pyg.org/whl/torch-2.1.0+${CUDA}.html # torch_spline_conv
! pip install torch_geometric
! pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.1.0+cu121.html
#!pip install torch_sparse -f https://data.pyg.org/whl/torch-2.1.0+${CUDA}.html
#!pip install torch_scatter -f https://data.pyg.org/whl/torch-2.1.0+${CUDA}.html
#!pip install pyg_lib -f https://data.pyg.org/whl/torch-2.1.0+${CUDA}.html
! pip install sentence-transformers
! pip install torcheval
! pip install matplotlib
! pip install pandas
! pip install tensorboard
! pip install weaviate-client
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch==2.1.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision==0.16.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (0.16.0+cu121)
# Requirement already satisfied: torchtext==0.16.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (0.16.0+cpu)
# Requirement already satisfied: torchaudio==2.1.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch==2.1.0) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch==2.1.0) (4.8.0)
# Requirement already satisfied: sympy in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch==2.1.0) (1.12)
# Requirement already satisfied: networkx in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch==2.1.0) (3.0)
# Requirement already satisfied: jinja2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch==2.1.0) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch==2.1.0) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torchvision==0.16.0) (1.24.1)
# Requirement already satisfied: requests in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torchvision==0.16.0) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torchvision==0.16.0) (9.3.0)
# Requirement already satisfied: tqdm in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torchtext==0.16.0) (4.64.1)
# Requirement already satisfied: torchdata==0.7.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torchtext==0.16.0) (0.7.0)
# Requirement already satisfied: urllib3>=1.25 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torchdata==0.7.0->torchtext==0.16.0) (1.26.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from jinja2->torch==2.1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->torchvision==0.16.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->torchvision==0.16.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->torchvision==0.16.0) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sympy->torch==2.1.0) (1.3.0)
# Requirement already satisfied: colorama in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tqdm->torchtext==0.16.0) (0.4.6)
# Requirement already satisfied: torch_geometric in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (2.4.0)
# Requirement already satisfied: tqdm in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (4.64.1)
# Requirement already satisfied: numpy in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (1.24.1)
# Requirement already satisfied: scipy in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: jinja2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (2.28.1)
# Requirement already satisfied: pyparsing in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (1.3.2)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->torch_geometric) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->torch_geometric) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from scikit-learn->torch_geometric) (3.2.0)
# Requirement already satisfied: colorama in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tqdm->torch_geometric) (0.4.6)
# Looking in links: https://data.pyg.org/whl/torch-2.1.0+cu121.html
# ERROR: Could not find a version that satisfies the requirement pyg_lib (from versions: none)
# ERROR: No matching distribution found for pyg_lib
# Requirement already satisfied: sentence-transformers in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: torchvision in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (0.16.0+cu121)
# Requirement already satisfied: numpy in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (1.24.1)
# Requirement already satisfied: scikit-learn in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: filelock in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: requests in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.0)
# Requirement already satisfied: jinja2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.1)
# Requirement already satisfied: click in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torchvision->sentence-transformers) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: torcheval in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (0.0.7)
# Requirement already satisfied: typing-extensions in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from torcheval) (4.8.0)
# Requirement already satisfied: matplotlib in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: tensorboard in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (2.15.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (1.24.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (4.23.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (2.28.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)
# Collecting weaviate-client
#   Downloading weaviate_client-3.25.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting requests<3.0.0,>=2.30.0 (from weaviate-client)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting validators<1.0.0,>=0.21.2 (from weaviate-client)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting authlib<2.0.0,>=1.2.1 (from weaviate-client)
#   Downloading Authlib-1.2.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting cryptography>=3.2 (from authlib<2.0.0,>=1.2.1->weaviate-client)
#   Downloading cryptography-41.0.5-cp37-abi3-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\i551663\appdata\local\miniconda3\envs\nlp\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (2022.12.7)
# Collecting cffi>=1.12 (from cryptography>=3.2->authlib<2.0.0,>=1.2.1->weaviate-client)
#   Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=3.2->authlib<2.0.0,>=1.2.1->weaviate-client)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      ------------------------------------ - 112.6/118.7 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 118.7/118.7 kB 2.3 MB/s eta 0:00:00
# Downloading weaviate_client-3.25.3-py3-none-any.whl (120 kB)
#    ---------------------------------------- 0.0/120.3 kB ? eta -:--:--
#    ---------------------------------------- 120.3/120.3 kB 6.9 MB/s eta 0:00:00
# Downloading Authlib-1.2.1-py2.py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.3 kB ? eta -:--:--
#    ---------------------------------------- 215.3/215.3 kB 6.6 MB/s eta 0:00:00
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading cryptography-41.0.5-cp37-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------- ------------------------------ 0.6/2.7 MB 19.5 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.7 MB 18.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 18.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 17.0 MB/s eta 0:00:00
# Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#    --------------------------------------- 181.6/181.6 kB 11.4 MB/s eta 0:00:00
# Installing collected packages: validators, requests, pycparser, cffi, cryptography, authlib, weaviate-client
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# Successfully installed authlib-1.2.1 cffi-1.16.0 cryptography-41.0.5 pycparser-2.21 requests-2.31.0 validators-0.22.0 weaviate-client-3.25.3
