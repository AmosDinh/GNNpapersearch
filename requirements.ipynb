# %%
! pip install torch==2.1.0  torchvision==0.16.0 torchtext==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121
! pip install torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.1.0+cu121.html
! pip install torch_geometric
! pip install sentence-transformers
! pip install torcheval
! pip install matplotlib
! pip install pandas
! pip install tensorboard
! pip install weaviate-client
! pip install ordered_set
! pip install gensim

! pip install -U pip setuptools wheel
! pip install -U spacy
! python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.1.0
#   Using cached https://download.pytorch.org/whl/cu121/torch-2.1.0%2Bcu121-cp310-cp310-win_amd64.whl (2473.9 MB)
# Collecting torchvision==0.16.0
#   Using cached https://download.pytorch.org/whl/cu121/torchvision-0.16.0%2Bcu121-cp310-cp310-win_amd64.whl (5.8 MB)
# Collecting torchtext==0.16.0
#   Using cached https://download.pytorch.org/whl/torchtext-0.16.0%2Bcpu-cp310-cp310-win_amd64.whl (1.9 MB)
# Collecting torchaudio==2.1.0
#   Using cached https://download.pytorch.org/whl/cu121/torchaudio-2.1.0%2Bcu121-cp310-cp310-win_amd64.whl (4.0 MB)
# Collecting filelock (from torch==2.1.0)
#   Using cached https://download.pytorch.org/whl/filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: typing-extensions in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch==2.1.0) (4.9.0)
# Collecting sympy (from torch==2.1.0)
#   Using cached https://download.pytorch.org/whl/sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch==2.1.0)
#   Using cached https://download.pytorch.org/whl/networkx-3.0-py3-none-any.whl (2.0 MB)
# Collecting jinja2 (from torch==2.1.0)
#   Using cached https://download.pytorch.org/whl/Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting fsspec (from torch==2.1.0)
#   Using cached https://download.pytorch.org/whl/fsspec-2023.4.0-py3-none-any.whl (153 kB)
# Collecting numpy (from torchvision==0.16.0)
#   Using cached https://download.pytorch.org/whl/numpy-1.24.1-cp310-cp310-win_amd64.whl (14.8 MB)
# Collecting requests (from torchvision==0.16.0)
#   Using cached https://download.pytorch.org/whl/requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision==0.16.0)
#   Using cached https://download.pytorch.org/whl/Pillow-9.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
# Collecting tqdm (from torchtext==0.16.0)
#   Using cached https://download.pytorch.org/whl/tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting torchdata==0.7.0 (from torchtext==0.16.0)
#   Using cached https://download.pytorch.org/whl/torchdata-0.7.0-cp310-cp310-win_amd64.whl (1.3 MB)
# Collecting urllib3>=1.25 (from torchdata==0.7.0->torchtext==0.16.0)
#   Using cached https://download.pytorch.org/whl/urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.1.0)
#   Using cached https://download.pytorch.org/whl/MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl (17 kB)
# Collecting charset-normalizer<3,>=2 (from requests->torchvision==0.16.0)
#   Using cached https://download.pytorch.org/whl/charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5 (from requests->torchvision==0.16.0)
#   Using cached https://download.pytorch.org/whl/idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17 (from requests->torchvision==0.16.0)
#   Using cached https://download.pytorch.org/whl/certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting mpmath>=0.19 (from sympy->torch==2.1.0)
#   Using cached https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: colorama in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tqdm->torchtext==0.16.0) (0.4.6)
# Installing collected packages: mpmath, urllib3, tqdm, sympy, pillow, numpy, networkx, MarkupSafe, idna, fsspec, filelock, charset-normalizer, certifi, requests, jinja2, torch, torchvision, torchdata, torchaudio, torchtext
# Successfully installed MarkupSafe-2.1.3 certifi-2022.12.7 charset-normalizer-2.1.1 filelock-3.9.0 fsspec-2023.4.0 idna-3.4 jinja2-3.1.2 mpmath-1.3.0 networkx-3.0 numpy-1.24.1 pillow-9.3.0 requests-2.28.1 sympy-1.12 torch-2.1.0+cu121 torchaudio-2.1.0+cu121 torchdata-0.7.0 torchtext-0.16.0+cpu torchvision-0.16.0+cu121 tqdm-4.64.1 urllib3-1.26.13
# Looking in links: https://data.pyg.org/whl/torch-2.1.0+cu121.html
# Collecting torch_scatter
#   Using cached https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_scatter-2.1.2%2Bpt21cu121-cp310-cp310-win_amd64.whl (3.4 MB)
# Collecting torch_sparse
#   Using cached https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_sparse-0.6.18%2Bpt21cu121-cp310-cp310-win_amd64.whl (2.1 MB)
# Collecting torch_cluster
#   Using cached https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_cluster-1.6.3%2Bpt21cu121-cp310-cp310-win_amd64.whl (1.6 MB)
# Collecting torch_spline_conv
#   Using cached https://data.pyg.org/whl/torch-2.1.0%2Bcu121/torch_spline_conv-1.2.2%2Bpt21cu121-cp310-cp310-win_amd64.whl (485 kB)
# Collecting scipy (from torch_sparse)
#   Using cached scipy-1.12.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from scipy->torch_sparse) (1.24.1)
# Using cached scipy-1.12.0-cp310-cp310-win_amd64.whl (46.2 MB)
# Installing collected packages: torch_spline_conv, torch_scatter, scipy, torch_sparse, torch_cluster
# Successfully installed scipy-1.12.0 torch_cluster-1.6.3+pt21cu121 torch_scatter-2.1.2+pt21cu121 torch_sparse-0.6.18+pt21cu121 torch_spline_conv-1.2.2+pt21cu121
# Collecting torch_geometric
#   Using cached torch_geometric-2.4.0-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: tqdm in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch_geometric) (4.64.1)
# Requirement already satisfied: numpy in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch_geometric) (1.24.1)
# Requirement already satisfied: scipy in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch_geometric) (1.12.0)
# Requirement already satisfied: jinja2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch_geometric) (2.28.1)
# Collecting pyparsing (from torch_geometric)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting scikit-learn (from torch_geometric)
#   Using cached scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch_geometric) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->torch_geometric) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->torch_geometric) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->torch_geometric) (2022.12.7)
# Collecting joblib>=1.2.0 (from scikit-learn->torch_geometric)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->torch_geometric)
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: colorama in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tqdm->torch_geometric) (0.4.6)
# Using cached torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl (10.6 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, pyparsing, joblib, scikit-learn, torch_geometric
# Successfully installed joblib-1.3.2 pyparsing-3.1.1 scikit-learn-1.4.0 threadpoolctl-3.2.0 torch_geometric-2.4.0
# Collecting sentence-transformers
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)
#   Using cached transformers-4.37.1-py3-none-any.whl.metadata (129 kB)
# Requirement already satisfied: tqdm in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: torchvision in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from sentence-transformers) (0.16.0+cu121)
# Requirement already satisfied: numpy in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from sentence-transformers) (1.24.1)
# Requirement already satisfied: scikit-learn in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from sentence-transformers) (1.4.0)
# Requirement already satisfied: scipy in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from sentence-transformers) (1.12.0)
# Collecting nltk (from sentence-transformers)
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting sentencepiece (from sentence-transformers)
#   Using cached sentencepiece-0.1.99-cp310-cp310-win_amd64.whl (977 kB)
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers)
#   Using cached huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.9.0)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.4.0->sentence-transformers)
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Collecting pyyaml>=5.1 (from huggingface-hub>=0.4.0->sentence-transformers)
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.0)
# Requirement already satisfied: jinja2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Using cached regex-2023.12.25-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<0.19,>=0.14 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Using cached tokenizers-0.15.1-cp310-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Using cached safetensors-0.4.2-cp310-none-win_amd64.whl.metadata (3.9 kB)
# Collecting click (from nltk->sentence-transformers)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torchvision->sentence-transformers) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Using cached huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
# Using cached transformers-4.37.1-py3-none-any.whl (8.4 MB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Using cached regex-2023.12.25-cp310-cp310-win_amd64.whl (269 kB)
# Using cached safetensors-0.4.2-cp310-none-win_amd64.whl (269 kB)
# Using cached tokenizers-0.15.1-cp310-none-win_amd64.whl (2.2 MB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Installing collected packages: sentencepiece, safetensors, regex, pyyaml, fsspec, click, nltk, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
# Successfully installed click-8.1.7 fsspec-2023.12.2 huggingface-hub-0.20.3 nltk-3.8.1 pyyaml-6.0.1 regex-2023.12.25 safetensors-0.4.2 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.15.1 transformers-4.37.1
# Collecting torcheval
#   Using cached torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from torcheval) (4.9.0)
# Using cached torcheval-0.0.7-py3-none-any.whl (179 kB)
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7
# Collecting matplotlib
#   Using cached matplotlib-3.8.2-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.47.2-cp310-cp310-win_amd64.whl.metadata (160 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.8.2-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.47.2-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.47.2 kiwisolver-1.4.5 matplotlib-3.8.2
# Collecting pandas
#   Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.0 pytz-2023.3.post1 tzdata-2023.4
# Collecting tensorboard
#   Using cached tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Using cached grpcio-1.60.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard)
#   Using cached google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard)
#   Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Using cached Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tensorboard) (1.24.1)
# Collecting protobuf<4.24,>=3.19.6 (from tensorboard)
#   Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tensorboard) (2.28.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tensorboard) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tensorboard) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard)
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
# Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Using cached grpcio-1.60.0-cp310-cp310-win_amd64.whl (3.7 MB)
# Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl (422 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, pyasn1, protobuf, oauthlib, markdown, grpcio, cachetools, absl-py, rsa, requests-oauthlib, pyasn1-modules, google-auth, google-auth-oauthlib, tensorboard
# Successfully installed absl-py-2.1.0 cachetools-5.3.2 google-auth-2.27.0 google-auth-oauthlib-1.2.0 grpcio-1.60.0 markdown-3.5.2 oauthlib-3.2.2 protobuf-4.23.4 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.15.1 tensorboard-data-server-0.7.2 werkzeug-3.0.1
# Collecting weaviate-client
#   Using cached weaviate_client-3.26.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting requests<3.0.0,>=2.30.0 (from weaviate-client)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting validators<1.0.0,>=0.21.2 (from weaviate-client)
#   Using cached validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting authlib<2.0.0,>=1.2.1 (from weaviate-client)
#   Using cached Authlib-1.3.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting cryptography (from authlib<2.0.0,>=1.2.1->weaviate-client)
#   Using cached cryptography-42.0.0-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client) (2022.12.7)
# Collecting cffi>=1.12 (from cryptography->authlib<2.0.0,>=1.2.1->weaviate-client)
#   Using cached cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.2.1->weaviate-client)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Using cached weaviate_client-3.26.2-py3-none-any.whl (120 kB)
# Using cached Authlib-1.3.0-py2.py3-none-any.whl (223 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached validators-0.22.0-py3-none-any.whl (26 kB)
# Using cached cryptography-42.0.0-cp39-abi3-win_amd64.whl (2.9 MB)
# Using cached cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
# Installing collected packages: validators, requests, pycparser, cffi, cryptography, authlib, weaviate-client
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# Successfully installed authlib-1.3.0 cffi-1.16.0 cryptography-42.0.0 pycparser-2.21 requests-2.31.0 validators-0.22.0 weaviate-client-3.26.2
# Collecting ordered_set
#   Using cached ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Installing collected packages: ordered_set
# Successfully installed ordered_set-4.1.0
# Collecting gensim
#   Using cached gensim-4.3.2-cp310-cp310-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from gensim) (1.24.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from gensim) (1.12.0)
# Collecting smart-open>=1.8.1 (from gensim)
#   Using cached smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Using cached gensim-4.3.2-cp310-cp310-win_amd64.whl (24.0 MB)
# Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-4.3.2 smart-open-6.4.0
# Requirement already satisfied: pip in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (23.3.1)
# Collecting pip
#   Using cached pip-23.3.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: setuptools in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (68.2.2)
# Collecting setuptools
#   Using cached setuptools-69.0.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: wheel in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (0.41.2)
# Collecting wheel
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Using cached pip-23.3.2-py3-none-any.whl (2.1 MB)
# Using cached setuptools-69.0.3-py3-none-any.whl (819 kB)
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# ERROR: To modify pip, please run the following command:
# C:\Users\Ilgar\anaconda3\envs\test8\python.exe -m pip install -U pip setuptools wheel
# Collecting spacy
#   Using cached spacy-3.7.2-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.10-cp310-cp310-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.8-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.9-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy)
#   Using cached thinc-8.2.2-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.4.8-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy)
#   Using cached weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy)
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy) (2.31.0)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.5.3-py3-none-any.whl.metadata (65 kB)
# Requirement already satisfied: jinja2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy) (1.24.1)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.6 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached pydantic_core-2.14.6-cp310-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy)
#   Using cached blis-0.7.11-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy)
#   Using cached confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy)
#   Using cached cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from jinja2->spacy) (2.1.3)
# Using cached spacy-3.7.2-cp310-cp310-win_amd64.whl (12.1 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.8-cp310-cp310-win_amd64.whl (39 kB)
# Using cached murmurhash-1.0.10-cp310-cp310-win_amd64.whl (25 kB)
# Using cached preshed-3.0.9-cp310-cp310-win_amd64.whl (122 kB)
# Using cached pydantic-2.5.3-py3-none-any.whl (381 kB)
# Using cached pydantic_core-2.14.6-cp310-none-win_amd64.whl (1.9 MB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.4.8-cp310-cp310-win_amd64.whl (481 kB)
# Using cached thinc-8.2.2-cp310-cp310-win_amd64.whl (1.5 MB)
# Using cached wasabi-1.1.2-py3-none-any.whl (27 kB)
# Using cached weasel-0.3.4-py3-none-any.whl (50 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached blis-0.7.11-cp310-cp310-win_amd64.whl (6.6 MB)
# Using cached cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
# Using cached confection-0.1.4-py3-none-any.whl (35 kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, pydantic-core, murmurhash, langcodes, cloudpathlib, catalogue, blis, annotated-types, typer, srsly, pydantic, preshed, confection, weasel, thinc, spacy
# Successfully installed annotated-types-0.6.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.5.3 pydantic-core-2.14.6 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.2 typer-0.9.0 wasabi-1.1.2 weasel-0.3.4
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 435.7 kB/s eta 0:00:30
#      ---------------------------------------- 0.1/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.4/12.8 MB 2.9 MB/s eta 0:00:05
#      -- ------------------------------------- 0.7/12.8 MB 3.6 MB/s eta 0:00:04
#      -- ------------------------------------- 1.0/12.8 MB 4.0 MB/s eta 0:00:03
#      --- ------------------------------------ 1.2/12.8 MB 4.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.5/12.8 MB 4.5 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/12.8 MB 4.6 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/12.8 MB 4.8 MB/s eta 0:00:03
#      ------- -------------------------------- 2.3/12.8 MB 4.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.5/12.8 MB 4.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/12.8 MB 5.0 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 5.0 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.3/12.8 MB 5.1 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.6/12.8 MB 5.1 MB/s eta 0:00:02
#      ------------ --------------------------- 3.9/12.8 MB 5.2 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 5.3 MB/s eta 0:00:02
#      -------------- ------------------------- 4.5/12.8 MB 5.3 MB/s eta 0:00:02
#      -------------- ------------------------- 4.8/12.8 MB 5.4 MB/s eta 0:00:02
#      --------------- ------------------------ 5.1/12.8 MB 5.4 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.4/12.8 MB 5.5 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 5.5 MB/s eta 0:00:02
#      ------------------ --------------------- 5.8/12.8 MB 5.4 MB/s eta 0:00:02
#      ------------------- -------------------- 6.1/12.8 MB 5.4 MB/s eta 0:00:02
#      -------------------- ------------------- 6.4/12.8 MB 5.5 MB/s eta 0:00:02
#      --------------------- ------------------ 6.7/12.8 MB 5.5 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/12.8 MB 5.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.3/12.8 MB 5.6 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.6/12.8 MB 5.6 MB/s eta 0:00:01
#      ------------------------ --------------- 7.9/12.8 MB 5.6 MB/s eta 0:00:01
#      ------------------------- -------------- 8.2/12.8 MB 5.6 MB/s eta 0:00:01
#      -------------------------- ------------- 8.5/12.8 MB 5.6 MB/s eta 0:00:01
#      --------------------------- ------------ 8.8/12.8 MB 5.7 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.1/12.8 MB 5.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.3/12.8 MB 5.7 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 5.7 MB/s eta 0:00:01
#      ------------------------------- -------- 9.9/12.8 MB 5.7 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 5.7 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 6.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.8/12.8 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 6.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.4/12.8 MB 6.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 6.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 6.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.3)
# Requirement already satisfied: jinja2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ilgar\anaconda3\envs\test8\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
